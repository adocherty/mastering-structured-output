# %% [markdown]
# ## Using LangChain to get structured outputs

# %% [markdown]
# ## Setup

# %%
import pickle
import pandas as pd
import tabulate
from scipy import stats
from langchain.prompts import ChatPromptTemplate
from langchain_anthropic import ChatAnthropic
from langchain_ollama import ChatOllama
from langchain_fireworks import ChatFireworks

from pydantic_structure_definitions import *

from experiment_xml import (
    pydantic_to_xml_instructions,
    run_xml_experiment,
    load_single_experiment,
    load_experiment_summary,
    analyse_xml_experiment,
)

# %%
ANTHROPIC_API_KEY = "<API KEY>"
FIREWORKS_API_KEY = "<API KEY>"

# %%
import streamlit as st

LANGSMITH_API_KEY = st.secrets["api_keys"]["LANGSMITH_API_KEY"]
ANTHROPIC_API_KEY = st.secrets["api_keys"]["ANTHROPIC_API_KEY"]
FIREWORKS_API_KEY = st.secrets["api_keys"]["FIREWORKS_API_KEY"]

# %%
experiment_date = "28-02-25"
experiment_num = "6"
n_iter = 1

# %% [markdown]
# Let's start by creating a LLM model to run our structured output queries. Use a temperature of 0 to improve structured output generation (but at the cost of "creativity").

# %% [markdown]
# ### Model setup

# %%
# LLM parameters
# temperature = 0.0
timeout = 30
num_ctx = 8192
num_predict = 4096

# %%
llm_models = []
llm_models_with_anthropic = []
for ii, temperature in enumerate([0, 0.8]):
    llm_models_ii = {
        "Ollama_llama32": ChatOllama(
            model="llama3.2",
            temperature=temperature,
            num_ctx=num_ctx,
            num_thread=1,
            num_predict=num_predict,
        ),
        "Ollama_nemotron": ChatOllama(
            model="nemotron-mini",
            temperature=temperature,
            num_ctx=num_ctx,
            num_thread=1,
            num_predict=num_predict,
        ),
        "Ollama_phi3": ChatOllama(
            model="phi3",
            temperature=temperature,
            num_ctx=num_ctx,
            num_thread=1,
            num_predict=num_predict,
        ),
        "Ollama_phi4": ChatOllama(
            model="phi4",
            temperature=temperature,
            num_ctx=num_ctx,
            num_thread=1,
            num_predict=num_predict,
        ),
        "Ollama_deepseekr1": ChatOllama(
            model="deepseek-r1",
            temperature=temperature,
            num_ctx=num_ctx,
            num_thread=1,
            num_predict=num_predict,
        ),
        "fireworks_llama31": ChatFireworks(
            model_name="accounts/fireworks/models/llama-v3p1-70b-instruct",
            api_key=FIREWORKS_API_KEY,
            temperature=temperature,
            timeout=timeout,
        ),
        "fireworks_llama32": ChatFireworks(
            model_name="accounts/fireworks/models/llama-v3p2-3b-instruct",
            api_key=FIREWORKS_API_KEY,
            temperature=temperature,
            timeout=timeout,
        ),
        "fireworks_llama33": ChatFireworks(
            model_name="accounts/fireworks/models/llama-v3p3-70b-instruct",
            api_key=FIREWORKS_API_KEY,
            temperature=temperature,
            timeout=timeout,
        ),
        "fireworks_qwen25": ChatFireworks(
            model_name="accounts/fireworks/models/qwen2p5-72b-instruct",
            api_key=FIREWORKS_API_KEY,
            temperature=temperature,
            timeout=timeout,
        ),
    }
    llm_models_with_anthropic_ii = {
        **llm_models_ii,
        "Anthropic_Sonnet_35": ChatAnthropic(
            model="claude-3-5-sonnet-20241022",
            api_key=ANTHROPIC_API_KEY,
            timeout=timeout,
            temperature=temperature,
        ),
        "Anthropic_Haiku_35": ChatAnthropic(
            model="claude-3-5-haiku-20241022",
            api_key=ANTHROPIC_API_KEY,
            timeout=timeout,
            temperature=temperature,
        ),
        "Anthropic_Haiku_3": ChatAnthropic(
            model="claude-3-haiku-20240307",
            api_key=ANTHROPIC_API_KEY,
            timeout=timeout,
            temperature=temperature,
        ),
    }
    llm_models.append(llm_models_ii)
    llm_models_with_anthropic.append(llm_models_with_anthropic_ii)

# %% [markdown]
# ### Problem setup and prompt

# %%
test_science_prompt_txt = """
You are a professional science writer tasked with responding to members of
the general public who write in asking questions about science.
Write an article responding to a writer's question for publication in a
science magazine intended for a general readership with a high-school education.
You should write clearly and compellingly, include all relavent context,
and provide motivating stories where applicable.

Your response must be less than 200 words.

The question given to you is the following:
{question}
"""

questions = [
    "What is the oldest recorded fossil?",
    "What is a black hole?",
    "How far away is the sun?",
    "Which other planet in the Solar System has a surface gravity closest to that of the Earth?",
    "Eris, Haumea, Makemake and Ceres are all examples of what?",
    "Why does earth have seasons? Do other planets exhibit seasons too?",
    "What causes the aurora borealis?",
    "Why is the sky blue?",
    "How do bees communicate?",
    "What is the smallest unit of life?",
    "How do plants make their own food?",
    "Why do we dream?",
    "What is the theory of relativity?",
    "How do volcanoes erupt?",
    "What is the speed of light?",
    "How do magnets work?",
    "What is the purpose of DNA?",
    "What are the different types of galaxies?",
    "Why do some animals hibernate?",
    "How do vaccines work?",
]

# %%
prompt_direct = ChatPromptTemplate.from_template(test_science_prompt_txt)

prompt_system_format = ChatPromptTemplate.from_messages(
    [
        (
            "system",
            "Return a publishable article in the requested format.\n{format_instructions}",
        ),
        ("human", test_science_prompt_txt),
    ]
)

prompt_system_plus_reminder_format = ChatPromptTemplate.from_messages(
    [
        (
            "system",
            "Return a publishable article in the requested format.\n{format_instructions}",
        ),
        (
            "human",
            test_science_prompt_txt + "\nYour response must be in valid XML.",
        ),
    ]
)

prompt_user_format = ChatPromptTemplate.from_template(
    test_science_prompt_txt + "\n{format_instructions}"
)

# %% [markdown]
# ### Schema using Pydantic XML

# %%
structured_formats_xml = [
    dict(pydantic=schema, format_instructions=pydantic_to_xml_instructions(schema))
    for schema in [
        ArticleResponse1XML,
        ArticleResponse1nointXML,
        ArticleResponse2XML,
        ArticleResponse3XML,
        ArticleResponse4XML,
    ]
]

structured_formats_xml_alt = [
    dict(pydantic=schema, format_instructions=pydantic_to_xml_instructions(schema))
    for schema in [
        ArticleResponse1XML,
        ArticleResponse2XMLalt,
        ArticleResponse3XML,
        ArticleResponse4XMLalt,
    ]
]

# %%
print(pydantic_to_xml_instructions(ArticleResponse2XMLalt))
# Out:
# You must respond only in XML using the following schema.
# Do not provide any output outside the first and last XML tags.
#
# <article>
#   <!--Structured article for publication answering a reader's question-->
#   <title>
#     {Title of the article - must be type str}
#   </title>
#   <answer>
#     {Answer the writer's question - must be type str}
#   </answer>
# <further_questions>
#   <!--A list of related questions of interest to the readers-->
# <!-- Next list element -->
#   <further_question>
#     {A related question of interest to readers - must be type str}
#   </further_question>
# <!-- First list element -->
#   <further_question>
#     {A related question of interest to readers - must be type str}
#   </further_question>
# <!-- Etc -->
#   <further_question>
#   ...
#   </further_question>
# </further_questions>
# </article>

# %%
from langchain.output_parsers import XMLOutputParser

xml_output_parsers = [
    XMLOutputParser(name="article", tags=["article", "title", "answer", "number"]),
    XMLOutputParser(
        name="article", tags=["article", "title", "answer", "further_question"]
    ),
    XMLOutputParser(
        name="article",
        tags=[
            "article",
            "title",
            "historical_event_1",
            "year",
            "event",
            "historical_event_2",
            "year",
            "event",
        ],
    ),
    XMLOutputParser(
        name="article", tags=["article", "title", "historical_event", "year", "event"]
    ),
]
structured_formats_output_parser_xml = [
    dict(pydantic=schema, format_instructions=op.get_format_instructions())
    for schema, op in zip(
        [
            ArticleResponse1nointXML,
            ArticleResponse2XML,
            ArticleResponse3XML,
            ArticleResponse4XML,
        ],
        xml_output_parsers,
    )
]

# %% [markdown]
# ## Experiment

# %%
hypotheses = [
    "1. Do small models including Phi3 and Nemotron improve their output by providing more explicit instructions on the format at the end of the prompt?",
    "2. Do output parsers perform worse for all models?",
    "3. What is the performance of the models using user parsers?",
]

# %% [markdown]
# ### Experiment run

# %% [markdown]
# User prompt

# %%
if "structure_support_by_model_sys" not in locals():
    structure_support_by_model_sys = {}

_ = run_xml_experiment(
    prompt_system_format,
    questions,
    llm_models_with_anthropic[0],
    structured_formats_xml,
    n_iter=1,
    results_out=structure_support_by_model_sys,
    save_file_name=f"exp{experiment_num}_xml_output_sys_{experiment_date}.pkl",
)
# Out:
# Model: Ollama_llama32  Output: ArticleResponse1XML   Pos: 1
# e.ee..e...eeeee.eeee
# Model: Ollama_llama32  Output: ArticleResponse1nointXML   Pos: 2
# ......e.............
# Model: Ollama_llama32  Output: ArticleResponse2XML   Pos: 3
# ....................
# Model: Ollama_llama32  Output: ArticleResponse3XML   Pos: 4
# .....e..............
# Model: Ollama_llama32  Output: ArticleResponse4XML   Pos: 5
# ....e...............
# Model: Ollama_nemotron  Output: ArticleResponse1XML   Pos: 6
# eeee..eeeeeeeeeeeeee
# Model: Ollama_nemotron  Output: ArticleResponse1nointXML   Pos: 7
# eeee..eeee.eeeeeeeee
# Model: Ollama_nemotron  Output: ArticleResponse2XML   Pos: 8
# eeee.eeeeeeeeeeeeeee
# Model: Ollama_nemotron  Output: ArticleResponse3XML   Pos: 9
# eeee.eeeeeeeeeeeeeee
# Model: Ollama_nemotron  Output: ArticleResponse4XML   Pos: 10
# eeee.eeeeeeeeeeeeeee
# Model: Ollama_phi3  Output: ArticleResponse1XML   Pos: 11
# e.eee..eee....ee...e
# Model: Ollama_phi3  Output: ArticleResponse1nointXML   Pos: 12
# ..eeee.......ee.....
# Model: Ollama_phi3  Output: ArticleResponse2XML   Pos: 13
# ..eeeee.e.e..e.....e
# Model: Ollama_phi3  Output: ArticleResponse3XML   Pos: 14
# eeeee.eeeee.eeee.ee.
# Model: Ollama_phi3  Output: ArticleResponse4XML   Pos: 15
# e..eee..e..e.eee.eee
# Model: Ollama_phi4  Output: ArticleResponse1XML   Pos: 16
# ...e................
# Model: Ollama_phi4  Output: ArticleResponse1nointXML   Pos: 17
# ....................
# Model: Ollama_phi4  Output: ArticleResponse2XML   Pos: 18
# ....................
# Model: Ollama_phi4  Output: ArticleResponse3XML   Pos: 19
# ....................
# Model: Ollama_phi4  Output: ArticleResponse4XML   Pos: 20
# ....................
# Model: Ollama_deepseekr1  Output: ArticleResponse1XML   Pos: 21
# ..e..e.ee.........ee
# Model: Ollama_deepseekr1  Output: ArticleResponse1nointXML   Pos: 22
# ...e.eee..ee......ee
# Model: Ollama_deepseekr1  Output: ArticleResponse2XML   Pos: 23
# ...e...e..e........e
# Model: Ollama_deepseekr1  Output: ArticleResponse3XML   Pos: 24
# ...e............e...
# Model: Ollama_deepseekr1  Output: ArticleResponse4XML   Pos: 25
# ...eee.....e........
# Model: fireworks_llama31  Output: ArticleResponse1XML   Pos: 26
# ..e..e..e.....e.....
# Model: fireworks_llama31  Output: ArticleResponse1nointXML   Pos: 27
# ....................
# Model: fireworks_llama31  Output: ArticleResponse2XML   Pos: 28
# ....................
# Model: fireworks_llama31  Output: ArticleResponse3XML   Pos: 29
# ....................
# Model: fireworks_llama31  Output: ArticleResponse4XML   Pos: 30
# ..........e.........
# Model: fireworks_llama32  Output: ArticleResponse1XML   Pos: 31
# eee...e..eee.ee..eee
# Model: fireworks_llama32  Output: ArticleResponse1nointXML   Pos: 32
# ...........e........
# Model: fireworks_llama32  Output: ArticleResponse2XML   Pos: 33
# ....................
# Model: fireworks_llama32  Output: ArticleResponse3XML   Pos: 34
# ....................
# Model: fireworks_llama32  Output: ArticleResponse4XML   Pos: 35
# ....................
# Model: fireworks_llama33  Output: ArticleResponse1XML   Pos: 36
# ....................
# Model: fireworks_llama33  Output: ArticleResponse1nointXML   Pos: 37
# ....................
# Model: fireworks_llama33  Output: ArticleResponse2XML   Pos: 38
# ....................
# Model: fireworks_llama33  Output: ArticleResponse3XML   Pos: 39
# ....................
# Model: fireworks_llama33  Output: ArticleResponse4XML   Pos: 40
# ....................
# Model: fireworks_qwen25  Output: ArticleResponse1XML   Pos: 41
# ....................
# Model: fireworks_qwen25  Output: ArticleResponse1nointXML   Pos: 42
# ....................
# Model: fireworks_qwen25  Output: ArticleResponse2XML   Pos: 43
# ....................
# Model: fireworks_qwen25  Output: ArticleResponse3XML   Pos: 44
# ....................
# Model: fireworks_qwen25  Output: ArticleResponse4XML   Pos: 45
# ....................
# Model: Anthropic_Sonnet_35  Output: ArticleResponse1XML   Pos: 46
# ....................
# Model: Anthropic_Sonnet_35  Output: ArticleResponse1nointXML   Pos: 47
# ....................
# Model: Anthropic_Sonnet_35  Output: ArticleResponse2XML   Pos: 48
# ....................
# Model: Anthropic_Sonnet_35  Output: ArticleResponse3XML   Pos: 49
# ....................
# Model: Anthropic_Sonnet_35  Output: ArticleResponse4XML   Pos: 50
# ....................
# Model: Anthropic_Haiku_35  Output: ArticleResponse1XML   Pos: 51
# .........e..........
# Model: Anthropic_Haiku_35  Output: ArticleResponse1nointXML   Pos: 52
# ....................
# Model: Anthropic_Haiku_35  Output: ArticleResponse2XML   Pos: 53
# ....................
# Model: Anthropic_Haiku_35  Output: ArticleResponse3XML   Pos: 54
# ....................
# Model: Anthropic_Haiku_35  Output: ArticleResponse4XML   Pos: 55
# ....................
# Model: Anthropic_Haiku_3  Output: ArticleResponse1XML   Pos: 56
# .....e..e.....e.e..e
# Model: Anthropic_Haiku_3  Output: ArticleResponse1nointXML   Pos: 57
# ....................
# Model: Anthropic_Haiku_3  Output: ArticleResponse2XML   Pos: 58
# ....................
# Model: Anthropic_Haiku_3  Output: ArticleResponse3XML   Pos: 59
# ....................
# Model: Anthropic_Haiku_3  Output: ArticleResponse4XML   Pos: 60
# ....................

# %% [markdown]
# System prompt

# %%
if "structure_support_by_model_user" not in locals():
    structure_support_by_model_user = {}

_ = run_xml_experiment(
    prompt_user_format,
    questions,
    llm_models_with_anthropic[0],
    structured_formats_xml,
    n_iter=n_iter,
    results_out=structure_support_by_model_user,
    save_file_name=f"exp{experiment_num}_xml_output_user_{experiment_date}.pkl",
)
# Out:
# Model: Ollama_llama32  Output: ArticleResponse1XML   Pos: 1
# .eee.e........e.....
# Model: Ollama_llama32  Output: ArticleResponse1nointXML   Pos: 2
# ...........e........
# Model: Ollama_llama32  Output: ArticleResponse2XML   Pos: 3
# ....................
# Model: Ollama_llama32  Output: ArticleResponse3XML   Pos: 4
# ....................
# Model: Ollama_llama32  Output: ArticleResponse4XML   Pos: 5
# ee.e.e..e.e......e..
# Model: Ollama_nemotron  Output: ArticleResponse1XML   Pos: 6
# e.eeeeeee.e.eee..eee
# Model: Ollama_nemotron  Output: ArticleResponse1nointXML   Pos: 7
# ee.ee.ee....eeee.e.e
# Model: Ollama_nemotron  Output: ArticleResponse2XML   Pos: 8
# eeeee.e.ee..eee..e.e
# Model: Ollama_nemotron  Output: ArticleResponse3XML   Pos: 9
# e..ee.............e.
# Model: Ollama_nemotron  Output: ArticleResponse4XML   Pos: 10
# ...ee.ee......e....e
# Model: Ollama_phi3  Output: ArticleResponse1XML   Pos: 11
# ....e..e......ee...e
# Model: Ollama_phi3  Output: ArticleResponse1nointXML   Pos: 12
# ...e.e...e....ee....
# Model: Ollama_phi3  Output: ArticleResponse2XML   Pos: 13
# .e..e.....ee........
# Model: Ollama_phi3  Output: ArticleResponse3XML   Pos: 14
# ...eee.e.......e.eee
# Model: Ollama_phi3  Output: ArticleResponse4XML   Pos: 15
# eeee..eeeeeee.eeeeee
# Model: Ollama_phi4  Output: ArticleResponse1XML   Pos: 16
# ...e................
# Model: Ollama_phi4  Output: ArticleResponse1nointXML   Pos: 17
# ....................
# Model: Ollama_phi4  Output: ArticleResponse2XML   Pos: 18
# ....................
# Model: Ollama_phi4  Output: ArticleResponse3XML   Pos: 19
# ....................
# Model: Ollama_phi4  Output: ArticleResponse4XML   Pos: 20
# ....................
# Model: Ollama_deepseekr1  Output: ArticleResponse1XML   Pos: 21
# ..e..e.............e
# Model: Ollama_deepseekr1  Output: ArticleResponse1nointXML   Pos: 22
# ...e..e.............
# Model: Ollama_deepseekr1  Output: ArticleResponse2XML   Pos: 23
# e....eee.....ee.....
# Model: Ollama_deepseekr1  Output: ArticleResponse3XML   Pos: 24
# ..e...ee.........ee.
# Model: Ollama_deepseekr1  Output: ArticleResponse4XML   Pos: 25
# ...e.e.e............
# Model: fireworks_llama31  Output: ArticleResponse1XML   Pos: 26
# e.e..e..e.....e.....
# Model: fireworks_llama31  Output: ArticleResponse1nointXML   Pos: 27
# ....................
# Model: fireworks_llama31  Output: ArticleResponse2XML   Pos: 28
# ....................
# Model: fireworks_llama31  Output: ArticleResponse3XML   Pos: 29
# ....................
# Model: fireworks_llama31  Output: ArticleResponse4XML   Pos: 30
# ....................
# Model: fireworks_llama32  Output: ArticleResponse1XML   Pos: 31
# eeee.ee......ee....e
# Model: fireworks_llama32  Output: ArticleResponse1nointXML   Pos: 32
# ....................
# Model: fireworks_llama32  Output: ArticleResponse2XML   Pos: 33
# ....................
# Model: fireworks_llama32  Output: ArticleResponse3XML   Pos: 34
# ....................
# Model: fireworks_llama32  Output: ArticleResponse4XML   Pos: 35
# ...e................
# Model: fireworks_llama33  Output: ArticleResponse1XML   Pos: 36
# ....................
# Model: fireworks_llama33  Output: ArticleResponse1nointXML   Pos: 37
# ....................
# Model: fireworks_llama33  Output: ArticleResponse2XML   Pos: 38
# ....................
# Model: fireworks_llama33  Output: ArticleResponse3XML   Pos: 39
# ...............e....
# Model: fireworks_llama33  Output: ArticleResponse4XML   Pos: 40
# .e..................
# Model: fireworks_qwen25  Output: ArticleResponse1XML   Pos: 41
# ....................
# Model: fireworks_qwen25  Output: ArticleResponse1nointXML   Pos: 42
# ....................
# Model: fireworks_qwen25  Output: ArticleResponse2XML   Pos: 43
# ....................
# Model: fireworks_qwen25  Output: ArticleResponse3XML   Pos: 44
# ....................
# Model: fireworks_qwen25  Output: ArticleResponse4XML   Pos: 45
# ....................
# Model: Anthropic_Sonnet_35  Output: ArticleResponse1XML   Pos: 46
# ....................
# Model: Anthropic_Sonnet_35  Output: ArticleResponse1nointXML   Pos: 47
# ....................
# Model: Anthropic_Sonnet_35  Output: ArticleResponse2XML   Pos: 48
# ....................
# Model: Anthropic_Sonnet_35  Output: ArticleResponse3XML   Pos: 49
# ....................
# Model: Anthropic_Sonnet_35  Output: ArticleResponse4XML   Pos: 50
# ....................
# Model: Anthropic_Haiku_35  Output: ArticleResponse1XML   Pos: 51
# ....................
# Model: Anthropic_Haiku_35  Output: ArticleResponse1nointXML   Pos: 52
# ....................
# Model: Anthropic_Haiku_35  Output: ArticleResponse2XML   Pos: 53
# ....................
# Model: Anthropic_Haiku_35  Output: ArticleResponse3XML   Pos: 54
# ....................
# Model: Anthropic_Haiku_35  Output: ArticleResponse4XML   Pos: 55
# ....................
# Model: Anthropic_Haiku_3  Output: ArticleResponse1XML   Pos: 56
# ..e..........ee.ee..
# Model: Anthropic_Haiku_3  Output: ArticleResponse1nointXML   Pos: 57
# ....................
# Model: Anthropic_Haiku_3  Output: ArticleResponse2XML   Pos: 58
# ....................
# Model: Anthropic_Haiku_3  Output: ArticleResponse3XML   Pos: 59
# ....................
# Model: Anthropic_Haiku_3  Output: ArticleResponse4XML   Pos: 60
# ....................

# %% [markdown]
# Output parsers

# %%
if "structure_support_by_model_parsers" not in locals():
    structure_support_by_model_parsers = {}

_ = run_xml_experiment(
    prompt_system_format,
    questions,
    llm_models_with_anthropic[0],
    structured_formats_output_parser_xml,
    n_iter=n_iter,
    results_out=structure_support_by_model_parsers,
    save_file_name=f"exp{experiment_num}_xml_output_parser_{experiment_date}.pkl",
)
# Out:
# Model: Ollama_llama32  Output: ArticleResponse1nointXML   Pos: 1
# eeeeeeeeeee.eee.eeee
# Model: Ollama_llama32  Output: ArticleResponse2XML   Pos: 2
# eee.eee.eeeeeeeeeeee
# Model: Ollama_llama32  Output: ArticleResponse3XML   Pos: 3
# eeeeeeeeeeeeeeeeeeee
# Model: Ollama_llama32  Output: ArticleResponse4XML   Pos: 4
# eeeeeeeeeeeeeeeeeeee
# Model: Ollama_nemotron  Output: ArticleResponse1nointXML   Pos: 5
# eeeeeeeeeeeeeeeeeeee
# Model: Ollama_nemotron  Output: ArticleResponse2XML   Pos: 6
# eeeeeeeeeeeeeeeeeeee
# Model: Ollama_nemotron  Output: ArticleResponse3XML   Pos: 7
# eeeeeeeeeeeeeeeeeeee
# Model: Ollama_nemotron  Output: ArticleResponse4XML   Pos: 8
# eeeeeeeeeeeeeeeeeeee
# Model: Ollama_phi3  Output: ArticleResponse1nointXML   Pos: 9
# eeeeeee.eeeeeeeeeeee
# Model: Ollama_phi3  Output: ArticleResponse2XML   Pos: 10
# e.eeeeeeeeeee.e.eeee
# Model: Ollama_phi3  Output: ArticleResponse3XML   Pos: 11
# eeeeeeeeeeeeeeeeeeee
# Model: Ollama_phi3  Output: ArticleResponse4XML   Pos: 12
# eeeeeeeeeeeeeeeeeeee
# Model: Ollama_phi4  Output: ArticleResponse1nointXML   Pos: 13
# .e.....ee.e.e..e....
# Model: Ollama_phi4  Output: ArticleResponse2XML   Pos: 14
# ....................
# Model: Ollama_phi4  Output: ArticleResponse3XML   Pos: 15
# .....eeee.......e...
# Model: Ollama_phi4  Output: ArticleResponse4XML   Pos: 16
# eeeeeeeeeeeeeeeeeeee
# Model: Ollama_deepseekr1  Output: ArticleResponse1nointXML   Pos: 17
# eeee.eeee.eeeeeeeeee
# Model: Ollama_deepseekr1  Output: ArticleResponse2XML   Pos: 18
# eeee.eeeeeee..ee..ee
# Model: Ollama_deepseekr1  Output: ArticleResponse3XML   Pos: 19
# eeeeeeeeeeeeeeeeeeee
# Model: Ollama_deepseekr1  Output: ArticleResponse4XML   Pos: 20
# eeeeeeeeeeeeeeeeeeee
# Model: fireworks_llama31  Output: ArticleResponse1nointXML   Pos: 21
# .e.eee..ee.ee.eeeeee
# Model: fireworks_llama31  Output: ArticleResponse2XML   Pos: 22
# ....e......e....e...
# Model: fireworks_llama31  Output: ArticleResponse3XML   Pos: 23
# ee...e.e.e.e...ee..e
# Model: fireworks_llama31  Output: ArticleResponse4XML   Pos: 24
# eeeeeeeeeeeeeeeeeeee
# Model: fireworks_llama32  Output: ArticleResponse1nointXML   Pos: 25
# eeeeeeeeeeeeeeeeeeee
# Model: fireworks_llama32  Output: ArticleResponse2XML   Pos: 26
# eeeeeeeeeeeeeeeeeeee
# Model: fireworks_llama32  Output: ArticleResponse3XML   Pos: 27
# eeeeeeeeeeeeeeeeeeee
# Model: fireworks_llama32  Output: ArticleResponse4XML   Pos: 28
# eeeeeeeeeeeeeeeeeeee
# Model: fireworks_llama33  Output: ArticleResponse1nointXML   Pos: 29
# e..eeee.eeeeeeeee.ee
# Model: fireworks_llama33  Output: ArticleResponse2XML   Pos: 30
# ....................
# Model: fireworks_llama33  Output: ArticleResponse3XML   Pos: 31
# .eeeeeeeeeeeeeeeeeee
# Model: fireworks_llama33  Output: ArticleResponse4XML   Pos: 32
# eeeeeeeeeeeeeeeeeeee
# Model: fireworks_qwen25  Output: ArticleResponse1nointXML   Pos: 33
# ....................
# Model: fireworks_qwen25  Output: ArticleResponse2XML   Pos: 34
# ....................
# Model: fireworks_qwen25  Output: ArticleResponse3XML   Pos: 35
# ....................
# Model: fireworks_qwen25  Output: ArticleResponse4XML   Pos: 36
# eeeeeeeeeeeeeeeeeeee
# Model: Anthropic_Sonnet_35  Output: ArticleResponse1nointXML   Pos: 37
# ....................
# Model: Anthropic_Sonnet_35  Output: ArticleResponse2XML   Pos: 38
# ....................
# Model: Anthropic_Sonnet_35  Output: ArticleResponse3XML   Pos: 39
# e.......e.....e.....
# Model: Anthropic_Sonnet_35  Output: ArticleResponse4XML   Pos: 40
# eeeeeeeeeeeeeeeeeeee
# Model: Anthropic_Haiku_35  Output: ArticleResponse1nointXML   Pos: 41
# eeeeeeeeeeeeeeeeeeee
# Model: Anthropic_Haiku_35  Output: ArticleResponse2XML   Pos: 42
# ....................
# Model: Anthropic_Haiku_35  Output: ArticleResponse3XML   Pos: 43
# ....................
# Model: Anthropic_Haiku_35  Output: ArticleResponse4XML   Pos: 44
# eeeeeeeeeeeeeeeeeeee
# Model: Anthropic_Haiku_3  Output: ArticleResponse1nointXML   Pos: 45
# ee..eee.eeeeee.e.eee
# Model: Anthropic_Haiku_3  Output: ArticleResponse2XML   Pos: 46
# ....................
# Model: Anthropic_Haiku_3  Output: ArticleResponse3XML   Pos: 47
# ..........e..e...e..
# Model: Anthropic_Haiku_3  Output: ArticleResponse4XML   Pos: 48
# eeeeeeeeeeeeeeeeeeee

# %% [markdown]
# Save all models

# %%
namespace = locals()
all_model_outputs = [k for k in namespace.keys() if k.startswith("structure_support")]

with open(file=f"exp{experiment_num}_all_models_{experiment_date}.pkl", mode="wb") as f:
    data = dict(
        hypotheses=hypotheses,
        temperature=temperature,
        num_ctx=num_ctx,
        num_predict=num_predict,
        questions=questions,
        prompt=prompt_direct,
        models={k: namespace[k] for k in all_model_outputs},
    )
    pickle.dump(data, f)

# %% [markdown]
# ### Results table

# %% [markdown]
# Load models

# %%
# Temperature 0 - sys, user, parsers experiment
# Includes Anthropic models
namespace = locals()
load_experiment_summary(experiment_num, experiment_date, namespace)

# %%
results_list = {
    "sys": structure_support_by_model_sys,
    "user": structure_support_by_model_user,
    "parsers": structure_support_by_model_parsers,
}

df_results = {}
for name, ss_results in results_list.items():
    df_results[name] = pd.DataFrame.from_dict(
        {
            tuple(mname.split("_", maxsplit=1)): {
                tname: ss_results[mname][tname]["valid"] * 100
                for tname in ss_results[mname].keys()
            }
            for mname in ss_results.keys()
        },
        orient="index",
    )
    display(name)
# Out:
# 'sys'
# 'user'
# 'parsers'

# %%
df = pd.concat(df_results).reorder_levels([1, 2, 0], axis=0).sort_index(axis=0)

with open(
    file=f"exp{experiment_num}_summary_df_{experiment_date}.json", mode="wb"
) as f:
    df.to_json(f)

# %%
df_orig = df.copy()

# %% [markdown]
# Reanalyse

# %%
structure_support_by_model_parsers_new = analyse_xml_experiment(
    structure_support_by_model_parsers, structured_formats_output_parser_xml
)
structure_support_by_model_user_new = analyse_xml_experiment(
    structure_support_by_model_user, structured_formats_output_parser_xml
)
structure_support_by_model_sys_new = analyse_xml_experiment(
    structure_support_by_model_sys, structured_formats_output_parser_xml
)
# Out:
# Model: Ollama_llama32  Structure: ArticleResponse1nointXML   Pos: 1
# eeeeee..ee..e.e...ee
# Model: Ollama_llama32  Structure: ArticleResponse2XML   Pos: 2
# .e..eee..e.eeeee.e.e
# Model: Ollama_llama32  Structure: ArticleResponse3XML   Pos: 3
# eeeeeeeeeeeeeeeeeeee
# Model: Ollama_llama32  Structure: ArticleResponse4XML   Pos: 4
# eeeeeeeeeeeeeeeeeeee
# Model: Ollama_nemotron  Structure: ArticleResponse1nointXML   Pos: 5
# eeeeeeeeeeeeeeeeeeee
# Model: Ollama_nemotron  Structure: ArticleResponse2XML   Pos: 6
# eeeeeeeeeeeeeeeeeeee
# Model: Ollama_nemotron  Structure: ArticleResponse3XML   Pos: 7
# eeeeeeeeeeeeeeeeeeee
# Model: Ollama_nemotron  Structure: ArticleResponse4XML   Pos: 8
# eeeeeeeeeeeeeeeeeeee
# Model: Ollama_phi3  Structure: ArticleResponse1nointXML   Pos: 9
# eeeeeee.eeeeeeeeeeee
# Model: Ollama_phi3  Structure: ArticleResponse2XML   Pos: 10
# e.eeeeeeeeeee.e.eee.
# Model: Ollama_phi3  Structure: ArticleResponse3XML   Pos: 11
# eeeeeeeeeeeeeeeeeeee
# Model: Ollama_phi3  Structure: ArticleResponse4XML   Pos: 12
# eeeeeeeeeeeeeeeeeeee
# Model: Ollama_phi4  Structure: ArticleResponse1nointXML   Pos: 13
# ....................
# Model: Ollama_phi4  Structure: ArticleResponse2XML   Pos: 14
# ....................
# Model: Ollama_phi4  Structure: ArticleResponse3XML   Pos: 15
# .....eeee.......e...
# Model: Ollama_phi4  Structure: ArticleResponse4XML   Pos: 16
# eeeeeeeeeeeeeeeeeeee
# Model: Ollama_deepseekr1  Structure: ArticleResponse1nointXML   Pos: 17
# eeee.eeee.eeeeeeeeee
# Model: Ollama_deepseekr1  Structure: ArticleResponse2XML   Pos: 18
# eeee.eeeeeee..ee..ee
# Model: Ollama_deepseekr1  Structure: ArticleResponse3XML   Pos: 19
# eeeeeeeeeeeeeeeeeee.
# Model: Ollama_deepseekr1  Structure: ArticleResponse4XML   Pos: 20
# eeeeeeeeeeeeeeeeeeee
# Model: fireworks_llama31  Structure: ArticleResponse1nointXML   Pos: 21
# .e.eee..ee.ee.eeeeee
# Model: fireworks_llama31  Structure: ArticleResponse2XML   Pos: 22
# ....................
# Model: fireworks_llama31  Structure: ArticleResponse3XML   Pos: 23
# ....................
# Model: fireworks_llama31  Structure: ArticleResponse4XML   Pos: 24
# eeeeeeeeeeeeeeeeeeee
# Model: fireworks_llama32  Structure: ArticleResponse1nointXML   Pos: 25
# eeeeeeeeeeeeeeeeeeee
# Model: fireworks_llama32  Structure: ArticleResponse2XML   Pos: 26
# eeeeeeeeeeeeeeeeeeee
# Model: fireworks_llama32  Structure: ArticleResponse3XML   Pos: 27
# eeeeeeeeeeeeeeeeeeee
# Model: fireworks_llama32  Structure: ArticleResponse4XML   Pos: 28
# eeeeeeeeeeeeeeeeeeee
# Model: fireworks_llama33  Structure: ArticleResponse1nointXML   Pos: 29
# e..eeee.eeeeeeeee.ee
# Model: fireworks_llama33  Structure: ArticleResponse2XML   Pos: 30
# ....................
# Model: fireworks_llama33  Structure: ArticleResponse3XML   Pos: 31
# .eeeeeeeeeeeeeeeeeee
# Model: fireworks_llama33  Structure: ArticleResponse4XML   Pos: 32
# eeeeeeeeeeeeeeeeeeee
# Model: fireworks_qwen25  Structure: ArticleResponse1nointXML   Pos: 33
# ....................
# Model: fireworks_qwen25  Structure: ArticleResponse2XML   Pos: 34
# ....................
# Model: fireworks_qwen25  Structure: ArticleResponse3XML   Pos: 35
# ....................
# Model: fireworks_qwen25  Structure: ArticleResponse4XML   Pos: 36
# eeeeeeeeeeeeeeeeeeee
# Model: Anthropic_Sonnet_35  Structure: ArticleResponse1nointXML   Pos: 37
# ....................
# Model: Anthropic_Sonnet_35  Structure: ArticleResponse2XML   Pos: 38
# ....................
# Model: Anthropic_Sonnet_35  Structure: ArticleResponse3XML   Pos: 39
# e.......e.....e.....
# Model: Anthropic_Sonnet_35  Structure: ArticleResponse4XML   Pos: 40
# eeeeeeeeeeeeeeeeeeee
# Model: Anthropic_Haiku_35  Structure: ArticleResponse1nointXML   Pos: 41
# ....................
# Model: Anthropic_Haiku_35  Structure: ArticleResponse2XML   Pos: 42
# ....................
# Model: Anthropic_Haiku_35  Structure: ArticleResponse3XML   Pos: 43
# ....................
# Model: Anthropic_Haiku_35  Structure: ArticleResponse4XML   Pos: 44
# eeeeeeeeeeeeeeeeeeee
# Model: Anthropic_Haiku_3  Structure: ArticleResponse1nointXML   Pos: 45
# ee..eee.ee.eee.e.eee
# Model: Anthropic_Haiku_3  Structure: ArticleResponse2XML   Pos: 46
# ....................
# Model: Anthropic_Haiku_3  Structure: ArticleResponse3XML   Pos: 47
# ..........e..e...e..
# Model: Anthropic_Haiku_3  Structure: ArticleResponse4XML   Pos: 48
# eeeeeeeeeeeeeeeeeeee
# Model: Ollama_llama32  Structure: ArticleResponse1nointXML   Pos: 1
# ...........e........
# Model: Ollama_llama32  Structure: ArticleResponse2XML   Pos: 2
# ....................
# Model: Ollama_llama32  Structure: ArticleResponse3XML   Pos: 3
# ....................
# Model: Ollama_llama32  Structure: ArticleResponse4XML   Pos: 4
# ee.e.e..e.e......e..
# Model: Ollama_nemotron  Structure: ArticleResponse1nointXML   Pos: 5
# ee.ee.ee....eeee.e.e
# Model: Ollama_nemotron  Structure: ArticleResponse2XML   Pos: 6
# eeeee.e.ee..eee..e.e
# Model: Ollama_nemotron  Structure: ArticleResponse3XML   Pos: 7
# e..ee.............e.
# Model: Ollama_nemotron  Structure: ArticleResponse4XML   Pos: 8
# ...ee.ee......e....e
# Model: Ollama_phi3  Structure: ArticleResponse1nointXML   Pos: 9
# ...e.e...e....ee....
# Model: Ollama_phi3  Structure: ArticleResponse2XML   Pos: 10
# .e..e.....ee........
# Model: Ollama_phi3  Structure: ArticleResponse3XML   Pos: 11
# ...eee.e.......e.eee
# Model: Ollama_phi3  Structure: ArticleResponse4XML   Pos: 12
# eeee..eeeeeee.eeeeee
# Model: Ollama_phi4  Structure: ArticleResponse1nointXML   Pos: 13
# ....................
# Model: Ollama_phi4  Structure: ArticleResponse2XML   Pos: 14
# ....................
# Model: Ollama_phi4  Structure: ArticleResponse3XML   Pos: 15
# ....................
# Model: Ollama_phi4  Structure: ArticleResponse4XML   Pos: 16
# ....................
# Model: Ollama_deepseekr1  Structure: ArticleResponse1nointXML   Pos: 17
# ...e..e.............
# Model: Ollama_deepseekr1  Structure: ArticleResponse2XML   Pos: 18
# e....eee.....ee.....
# Model: Ollama_deepseekr1  Structure: ArticleResponse3XML   Pos: 19
# ..e...ee.........ee.
# Model: Ollama_deepseekr1  Structure: ArticleResponse4XML   Pos: 20
# ...e.e.e............
# Model: fireworks_llama31  Structure: ArticleResponse1nointXML   Pos: 21
# ....................
# Model: fireworks_llama31  Structure: ArticleResponse2XML   Pos: 22
# ....................
# Model: fireworks_llama31  Structure: ArticleResponse3XML   Pos: 23
# ....................
# Model: fireworks_llama31  Structure: ArticleResponse4XML   Pos: 24
# ....................
# Model: fireworks_llama32  Structure: ArticleResponse1nointXML   Pos: 25
# ....................
# Model: fireworks_llama32  Structure: ArticleResponse2XML   Pos: 26
# ....................
# Model: fireworks_llama32  Structure: ArticleResponse3XML   Pos: 27
# ....................
# Model: fireworks_llama32  Structure: ArticleResponse4XML   Pos: 28
# ...e................
# Model: fireworks_llama33  Structure: ArticleResponse1nointXML   Pos: 29
# ....................
# Model: fireworks_llama33  Structure: ArticleResponse2XML   Pos: 30
# ....................
# Model: fireworks_llama33  Structure: ArticleResponse3XML   Pos: 31
# ...............e....
# Model: fireworks_llama33  Structure: ArticleResponse4XML   Pos: 32
# .e..................
# Model: fireworks_qwen25  Structure: ArticleResponse1nointXML   Pos: 33
# ....................
# Model: fireworks_qwen25  Structure: ArticleResponse2XML   Pos: 34
# ....................
# Model: fireworks_qwen25  Structure: ArticleResponse3XML   Pos: 35
# ....................
# Model: fireworks_qwen25  Structure: ArticleResponse4XML   Pos: 36
# ....................
# Model: Anthropic_Sonnet_35  Structure: ArticleResponse1nointXML   Pos: 37
# ....................
# Model: Anthropic_Sonnet_35  Structure: ArticleResponse2XML   Pos: 38
# ....................
# Model: Anthropic_Sonnet_35  Structure: ArticleResponse3XML   Pos: 39
# ....................
# Model: Anthropic_Sonnet_35  Structure: ArticleResponse4XML   Pos: 40
# ....................
# Model: Anthropic_Haiku_35  Structure: ArticleResponse1nointXML   Pos: 41
# ....................
# Model: Anthropic_Haiku_35  Structure: ArticleResponse2XML   Pos: 42
# ....................
# Model: Anthropic_Haiku_35  Structure: ArticleResponse3XML   Pos: 43
# ....................
# Model: Anthropic_Haiku_35  Structure: ArticleResponse4XML   Pos: 44
# ....................
# Model: Anthropic_Haiku_3  Structure: ArticleResponse1nointXML   Pos: 45
# ....................
# Model: Anthropic_Haiku_3  Structure: ArticleResponse2XML   Pos: 46
# ....................
# Model: Anthropic_Haiku_3  Structure: ArticleResponse3XML   Pos: 47
# ....................
# Model: Anthropic_Haiku_3  Structure: ArticleResponse4XML   Pos: 48
# ....................
# Model: Ollama_llama32  Structure: ArticleResponse1nointXML   Pos: 1
# ......e.............
# Model: Ollama_llama32  Structure: ArticleResponse2XML   Pos: 2
# ....................
# Model: Ollama_llama32  Structure: ArticleResponse3XML   Pos: 3
# .....e..............
# Model: Ollama_llama32  Structure: ArticleResponse4XML   Pos: 4
# ....e...............
# Model: Ollama_nemotron  Structure: ArticleResponse1nointXML   Pos: 5
# eeee..eeee.eeeeeeeee
# Model: Ollama_nemotron  Structure: ArticleResponse2XML   Pos: 6
# eeee.eeeeeeeeeeeeeee
# Model: Ollama_nemotron  Structure: ArticleResponse3XML   Pos: 7
# eeee.eeeeeeeeeeeeeee
# Model: Ollama_nemotron  Structure: ArticleResponse4XML   Pos: 8
# eeee.eeeeeeeeeeeeeee
# Model: Ollama_phi3  Structure: ArticleResponse1nointXML   Pos: 9
# ..eeee.......ee.....
# Model: Ollama_phi3  Structure: ArticleResponse2XML   Pos: 10
# ..eeeee.e.e..e.....e
# Model: Ollama_phi3  Structure: ArticleResponse3XML   Pos: 11
# eeeee.eeeee.eeee.ee.
# Model: Ollama_phi3  Structure: ArticleResponse4XML   Pos: 12
# e..eee..e..e.eee.eee
# Model: Ollama_phi4  Structure: ArticleResponse1nointXML   Pos: 13
# ....................
# Model: Ollama_phi4  Structure: ArticleResponse2XML   Pos: 14
# ....................
# Model: Ollama_phi4  Structure: ArticleResponse3XML   Pos: 15
# ....................
# Model: Ollama_phi4  Structure: ArticleResponse4XML   Pos: 16
# ....................
# Model: Ollama_deepseekr1  Structure: ArticleResponse1nointXML   Pos: 17
# ...e.eee..ee......ee
# Model: Ollama_deepseekr1  Structure: ArticleResponse2XML   Pos: 18
# ...e...e..e........e
# Model: Ollama_deepseekr1  Structure: ArticleResponse3XML   Pos: 19
# ...e............e...
# Model: Ollama_deepseekr1  Structure: ArticleResponse4XML   Pos: 20
# ...eee.....e........
# Model: fireworks_llama31  Structure: ArticleResponse1nointXML   Pos: 21
# ....................
# Model: fireworks_llama31  Structure: ArticleResponse2XML   Pos: 22
# ....................
# Model: fireworks_llama31  Structure: ArticleResponse3XML   Pos: 23
# ....................
# Model: fireworks_llama31  Structure: ArticleResponse4XML   Pos: 24
# ..........e.........
# Model: fireworks_llama32  Structure: ArticleResponse1nointXML   Pos: 25
# ...........e........
# Model: fireworks_llama32  Structure: ArticleResponse2XML   Pos: 26
# ....................
# Model: fireworks_llama32  Structure: ArticleResponse3XML   Pos: 27
# ....................
# Model: fireworks_llama32  Structure: ArticleResponse4XML   Pos: 28
# ....................
# Model: fireworks_llama33  Structure: ArticleResponse1nointXML   Pos: 29
# ....................
# Model: fireworks_llama33  Structure: ArticleResponse2XML   Pos: 30
# ....................
# Model: fireworks_llama33  Structure: ArticleResponse3XML   Pos: 31
# ....................
# Model: fireworks_llama33  Structure: ArticleResponse4XML   Pos: 32
# ....................
# Model: fireworks_qwen25  Structure: ArticleResponse1nointXML   Pos: 33
# ....................
# Model: fireworks_qwen25  Structure: ArticleResponse2XML   Pos: 34
# ....................
# Model: fireworks_qwen25  Structure: ArticleResponse3XML   Pos: 35
# ....................
# Model: fireworks_qwen25  Structure: ArticleResponse4XML   Pos: 36
# ....................
# Model: Anthropic_Sonnet_35  Structure: ArticleResponse1nointXML   Pos: 37
# ....................
# Model: Anthropic_Sonnet_35  Structure: ArticleResponse2XML   Pos: 38
# ....................
# Model: Anthropic_Sonnet_35  Structure: ArticleResponse3XML   Pos: 39
# ....................
# Model: Anthropic_Sonnet_35  Structure: ArticleResponse4XML   Pos: 40
# ....................
# Model: Anthropic_Haiku_35  Structure: ArticleResponse1nointXML   Pos: 41
# ....................
# Model: Anthropic_Haiku_35  Structure: ArticleResponse2XML   Pos: 42
# ....................
# Model: Anthropic_Haiku_35  Structure: ArticleResponse3XML   Pos: 43
# ....................
# Model: Anthropic_Haiku_35  Structure: ArticleResponse4XML   Pos: 44
# ....................
# Model: Anthropic_Haiku_3  Structure: ArticleResponse1nointXML   Pos: 45
# ....................
# Model: Anthropic_Haiku_3  Structure: ArticleResponse2XML   Pos: 46
# ....................
# Model: Anthropic_Haiku_3  Structure: ArticleResponse3XML   Pos: 47
# ....................
# Model: Anthropic_Haiku_3  Structure: ArticleResponse4XML   Pos: 48
# ....................

# %%
results_list = {
    "unordered": results_new,
    "ordered": structure_support_by_model_parsers,
}

df_results = {}
for name, ss_results in results_list.items():
    df_results[name] = pd.DataFrame.from_dict(
        {
            tuple(mname.split("_", maxsplit=1)): {
                tname: ss_results[mname][tname]["valid"] * 100
                for tname in ss_results[mname].keys()
            }
            for mname in ss_results.keys()
        },
        orient="index",
    )
    display(name)
# Out:
# 'unordered'
# 'ordered'

# %%
df_new = pd.concat(df_results).reorder_levels([1, 2, 0], axis=0).sort_index(axis=0)

# %%
import tabulate

print(
    tabulate.tabulate(
        df_new.reset_index(), headers="keys", tablefmt="pipe", showindex=False
    )
)
# Out:
# | level_0   | level_1    | level_2   |   ArticleResponse1nointXML |   ArticleResponse2XML |   ArticleResponse3XML |   ArticleResponse4XML |
# |:----------|:-----------|:----------|---------------------------:|----------------------:|----------------------:|----------------------:|
# | Anthropic | Haiku_3    | ordered   |                         25 |                   100 |                    85 |                     0 |
# | Anthropic | Haiku_3    | unordered |                         30 |                   100 |                    85 |                     0 |
# | Anthropic | Haiku_35   | ordered   |                          0 |                   100 |                   100 |                     0 |
# | Anthropic | Haiku_35   | unordered |                        100 |                   100 |                   100 |                     0 |
# | Anthropic | Sonnet_35  | ordered   |                        100 |                   100 |                    85 |                     0 |
# | Anthropic | Sonnet_35  | unordered |                        100 |                   100 |                    85 |                     0 |
# | Ollama    | deepseekr1 | ordered   |                         10 |                    25 |                     0 |                     0 |
# | Ollama    | deepseekr1 | unordered |                         10 |                    25 |                     5 |                     0 |
# | Ollama    | llama32    | ordered   |                         10 |                    10 |                     0 |                     0 |
# | Ollama    | llama32    | unordered |                         40 |                    40 |                     0 |                     0 |
# | Ollama    | nemotron   | ordered   |                          0 |                     0 |                     0 |                     0 |
# | Ollama    | nemotron   | unordered |                          0 |                     0 |                     0 |                     0 |
# | Ollama    | phi3       | ordered   |                          5 |                    15 |                     0 |                     0 |
# | Ollama    | phi3       | unordered |                          5 |                    20 |                     0 |                     0 |
# | Ollama    | phi4       | ordered   |                         70 |                   100 |                    75 |                     0 |
# | Ollama    | phi4       | unordered |                        100 |                   100 |                    75 |                     0 |
# | fireworks | llama31    | ordered   |                         30 |                    85 |                    55 |                     0 |
# | fireworks | llama31    | unordered |                         30 |                   100 |                   100 |                     0 |
# | fireworks | llama32    | ordered   |                          0 |                     0 |                     0 |                     0 |
# | fireworks | llama32    | unordered |                          0 |                     0 |                     0 |                     0 |
# | fireworks | llama33    | ordered   |                         20 |                   100 |                     5 |                     0 |
# | fireworks | llama33    | unordered |                         20 |                   100 |                     5 |                     0 |
# | fireworks | qwen25     | ordered   |                        100 |                   100 |                   100 |                     0 |
# | fireworks | qwen25     | unordered |                        100 |                   100 |                   100 |                     0 |

# %% [markdown]
# Let's combine these results over structures to have more power to determine the hypothesis

# %%
from hypothesis_testing import wilson_score_ci

# %%
results_list = {
    "sys": structure_support_by_model_sys_new,
    "user": structure_support_by_model_user_new,
}


def format_ci(p, num_total):
    avg, lb, ub = wilson_score_ci(p * num_total, num_total)
    return f"{lb*100:.1f}% — {ub*100:.0f}% "
    # return f"{avg*100:.0f}%"  # ±{max(avg-lb, ub-avg)*100:.0f}"


df_results = {}
for name, ss_results in results_list.items():
    df_results[name] = {
        tuple(mname.split("_", maxsplit=1)): format_ci(
            pd.Series(
                [
                    ss_results[mname][tname]["valid"]
                    for tname in ss_results[mname].keys()
                ]
            ).mean(),
            20 * len(ss_results[mname].keys()),
        )
        for mname in ss_results.keys()
    }

pd.DataFrame.from_dict(df_results)
# Out:
#                                 sys           user
# Ollama    llama32      89.5% — 99%    81.5% — 95%
#           nemotron      3.5% — 15%    45.3% — 67%
#           phi3         35.7% — 57%    46.6% — 68%
#           phi4        95.4% — 100%   95.4% — 100%
#           deepseekr1   67.2% — 85%    70.0% — 87%
# fireworks llama31     93.3% — 100%   95.4% — 100%
#           llama32     93.3% — 100%   93.3% — 100%
#           llama33     95.4% — 100%    91.3% — 99%
#           qwen25      95.4% — 100%   95.4% — 100%
# Anthropic Sonnet_35   95.4% — 100%   95.4% — 100%
#           Haiku_35    95.4% — 100%   95.4% — 100%
#           Haiku_3     95.4% — 100%   95.4% — 100%

# %% [markdown]
# Approximate confidence interval

# %%
print(
    tabulate.tabulate(
        pd.DataFrame.from_dict(df_results).reset_index(),
        headers="keys",
        tablefmt="pipe",
        showindex=False,
    )
)
# Out:
# | level_0   | level_1    | sys          | user         |
# |:----------|:-----------|:-------------|:-------------|
# | Ollama    | llama32    | 75.6% — 90%  | 79.0% — 92%  |
# | Ollama    | nemotron   | 4.1% — 15%   | 40.4% — 60%  |
# | Ollama    | phi3       | 37.5% — 57%  | 51.2% — 70%  |
# | Ollama    | phi4       | 94.6% — 100% | 94.6% — 100% |
# | Ollama    | deepseekr1 | 66.8% — 83%  | 72.2% — 87%  |
# | fireworks | llama31    | 88.8% — 98%  | 88.8% — 98%  |
# | fireworks | llama32    | 79.0% — 92%  | 82.6% — 94%  |
# | fireworks | llama33    | 96.3% — 100% | 93.0% — 99%  |
# | fireworks | qwen25     | 96.3% — 100% | 96.3% — 100% |
# | Anthropic | Sonnet_35  | 96.3% — 100% | 96.3% — 100% |
# | Anthropic | Haiku_35   | 94.6% — 100% | 96.3% — 100% |
# | Anthropic | Haiku_3    | 88.8% — 98%  | 88.8% — 98%  |

# %% [markdown]
# ### Error analysis

# %% [markdown]
# Extract all error messages & count

# %%
def analyse_errors_from_results(ss_results, method="code", combined=False):
    error_counts = {}
    for mname in ss_results.keys():
        error_counts[mname] = {}
        for tname in ss_results[mname].keys():
            # Count errors by failure code above
            if method == "code":
                error_types = pd.Series(
                    output["error_type"]
                    for output in ss_results[mname][tname]["outputs"]
                )
                error_codes = error_types.value_counts()

                for e_name, e_count in error_codes.items():
                    if combined:
                        error_counts[mname][e_name] = (
                            error_counts[mname].get(e_name, 0) + e_count
                        )
                    else:
                        error_counts[mname][(tname, e_name)] = e_count

            elif method == "parse":
                # Count errors by parsing error message
                errors = (
                    output["error_message"]
                    for output in ss_results[mname][tname]["outputs"]
                )
                for error in errors:
                    if error is None:
                        continue
                    if error.lower().find("opening and ending tag mismatch") >= 0:
                        error_str = "XML tag mismatch"
                    elif error.lower().find("extracterror") >= 0:
                        error_str = "Missing main tags"
                    elif error.lower().find("input should be a valid integer") >= 0:
                        error_str = "Validation error (int)"
                    elif error.lower().find("premature end of data in tag") >= 0:
                        error_str = "Premature end"
                    elif error.lower().find("field required") >= 0:
                        error_str = "Missing field"
                    elif error.lower().find("expected '>'") >= 0:
                        error_str = "Tag malformed"
                    elif (
                        error.lower().find("extra content at the end of the document")
                        >= 0
                    ):
                        error_str = "Tag malformed"
                    elif error.find("BadGatewayError") >= 0:
                        error_str = "Connection error"
                    elif error.find("XMLSyntaxError") >= 0:
                        error_str = "Other syntax error"
                    else:
                        error_str = error

                    if combined:
                        error_counts[mname][error_str] = (
                            error_counts[mname].get(error_str, 0) + 1
                        )

                    else:
                        error_counts[mname][(tname, error_str)] = (
                            error_counts[mname].get((tname, error_str), 0) + 1
                        )

            else:
                raise NameError(f"Method {method} not supported")

    return pd.DataFrame.from_dict(error_counts, orient="index")

# %%
analyse_errors_from_results(
    structure_support_by_model_parsers, method="parse", combined=True
).fillna(0).sort_index(axis=1)
# Out:
#                      Connection error  \
# Ollama_llama32                    0.0
# Ollama_phi3                       0.0
# Ollama_phi4                       0.0
# Ollama_deepseekr1                 0.0
# fireworks_llama31                 1.0
# fireworks_llama33                 0.0
# fireworks_qwen25                  0.0
# Anthropic_Sonnet_35               0.0
# Anthropic_Haiku_35                0.0
# Anthropic_Haiku_3                 0.0
# Ollama_nemotron                   0.0
# fireworks_llama32                 0.0
#
#                      InternalServerError, Error code: 529 - {'type': 'error', 'error': {'type': 'overloaded_error', 'message': 'Overloaded'}}  \
# Ollama_llama32                                                     0.0
# Ollama_phi3                                                        0.0
# Ollama_phi4                                                        0.0
# Ollama_deepseekr1                                                  0.0
# fireworks_llama31                                                  0.0
# fireworks_llama33                                                  0.0
# fireworks_qwen25                                                   0.0
# Anthropic_Sonnet_35                                                0.0
# Anthropic_Haiku_35                                                 0.0
# Anthropic_Haiku_3                                                  5.0
# Ollama_nemotron                                                    0.0
# fireworks_llama32                                                  0.0
#
#                      Missing field  Missing main tags  Other syntax error  \
# Ollama_llama32                66.0                6.0                 0.0
# Ollama_phi3                   30.0               15.0                 3.0
# Ollama_phi4                   31.0                0.0                 0.0
# Ollama_deepseekr1             19.0               35.0                 3.0
# fireworks_llama31             45.0                0.0                 0.0
# fireworks_llama33             55.0                0.0                 0.0
# fireworks_qwen25              20.0                0.0                 0.0
# Anthropic_Sonnet_35           20.0                0.0                 0.0
# Anthropic_Haiku_35            40.0                0.0                 0.0
# Anthropic_Haiku_3             33.0                0.0                 0.0
# Ollama_nemotron                0.0               80.0                 0.0
# fireworks_llama32              0.0               80.0                 0.0
#
#                      Premature end  Tag malformed  XML tag mismatch
# Ollama_llama32                 0.0            0.0               4.0
# Ollama_phi3                    0.0            1.0              27.0
# Ollama_phi4                    0.0            0.0               0.0
# Ollama_deepseekr1              3.0            0.0              13.0
# fireworks_llama31              0.0            0.0               0.0
# fireworks_llama33              0.0            0.0               0.0
# fireworks_qwen25               0.0            0.0               0.0
# Anthropic_Sonnet_35            0.0            0.0               3.0
# Anthropic_Haiku_35             0.0            0.0               0.0
# Anthropic_Haiku_3              0.0            0.0               0.0
# Ollama_nemotron                0.0            0.0               0.0
# fireworks_llama32              0.0            0.0               0.0

# %%
analyse_errors_from_results(
    structure_support_by_model_user, method="parse", combined=True
).fillna(0).sort_index(axis=1)
# Out:
#                    Connection error  Missing field  Missing main tags  \
# Ollama_llama32                  0.0            8.0                0.0
# Ollama_nemotron                 0.0            1.0               44.0
# Ollama_phi4                     0.0            0.0                0.0
# Ollama_deepseekr1               0.0            7.0                3.0
# fireworks_llama31               1.0            0.0                0.0
# fireworks_llama32               0.0            0.0                1.0
# Anthropic_Haiku_3               0.0            0.0                0.0
# Ollama_phi3                     0.0            5.0                4.0
# fireworks_llama33               1.0            0.0                0.0
#
#                    Other syntax error  Tag malformed  Validation error (int)  \
# Ollama_llama32                    0.0            0.0                     5.0
# Ollama_nemotron                   0.0            0.0                     5.0
# Ollama_phi4                       0.0            0.0                     1.0
# Ollama_deepseekr1                 5.0            0.0                     2.0
# fireworks_llama31                 0.0            0.0                     4.0
# fireworks_llama32                 0.0            0.0                     9.0
# Anthropic_Haiku_3                 0.0            0.0                     5.0
# Ollama_phi3                       3.0            4.0                     0.0
# fireworks_llama33                 0.0            0.0                     0.0
#
#                    XML tag mismatch
# Ollama_llama32                  0.0
# Ollama_nemotron                 0.0
# Ollama_phi4                     0.0
# Ollama_deepseekr1               2.0
# fireworks_llama31               0.0
# fireworks_llama32               0.0
# Anthropic_Haiku_3               0.0
# Ollama_phi3                    23.0
# fireworks_llama33               1.0

# %%
structure_support_by_model_parsers.keys()
# Out:
# dict_keys(['Ollama_llama32', 'Ollama_nemotron', 'Ollama_phi3', 'Ollama_phi4', 'Ollama_deepseekr1', 'fireworks_llama31', 'fireworks_llama32', 'fireworks_llama33', 'fireworks_qwen25', 'Anthropic_Sonnet_35', 'Anthropic_Haiku_35', 'Anthropic_Haiku_3'])

# %%
from experiment_xml import extract_substring

# %%
output_xml = extract_substring(
    structure_support_by_model_parsers["Anthropic_Haiku_3"]["ArticleResponse1nointXML"][
        "outputs"
    ][10]["raw"].content,
    "<article>",
    "</article>",
)

# %%
print(output_xml)
# Out:
# <article>
# <title>How Plants Make Their Own Food</title>
# <number>1</number>
# <answer>
# Plants are amazing living things that can create their own food through a process called photosynthesis. Using just sunlight, water, and carbon dioxide, plants are able to produce the nutrients they need to grow and thrive.
#
# Here's how it works: Plants have special structures called chloroplasts that contain chlorophyll, a green pigment that absorbs sunlight. During photosynthesis, the chloroplasts use the energy from sunlight to convert carbon dioxide and water into glucose, a type of sugar that the plant can use for energy.
#
# This process is like a plant's version of cooking or baking - they are essentially "making" their own food from basic raw ingredients. And just like our food, this glucose provides the plant with the nutrients it needs to grow its roots, stems, leaves, and flowers.
#
# So the next time you see a lush green plant, remember that it is engaged in a remarkable feat of natural chemistry, turning sunlight, air, and water into its own sustenance. Isn't nature amazing?
# </answer>
# </article>

# %%
if 1:
    for output in structure_support_by_model_parsers["Anthropic_Haiku_35"][
        "ArticleResponse3XML"
    ]["outputs"]:
        if output["error_type"] == "ok":
            print(output["error_message"], "\n")
            if output["raw"] is not None:
                print(output["raw"].content)
            print()
# Out:
# None
#
# <?xml version="1.0" encoding="UTF-8"?>
# <article>
#     <title>Tracing Life's Ancient Roots: The Oldest Known Fossil</title>
#
#     <historical_event_1>
#         <year>3.5 billion years ago</year>
#         <event>Researchers discovered stromatolite fossils in Western Australia's Pilbara region, representing some of the earliest evidence of life on Earth. These layered rock formations were created by ancient microorganisms called cyanobacteria, which formed complex microbial mats in shallow marine environments.</event>
#     </historical_event_1>
#
#     <historical_event_2>
#         <year>4.28 billion years ago</year>
#         <event>Microscopic graphite deposits found in Quebec, Canada, suggest potential microbial life existed even earlier. These carbon-based remnants hint at primitive biological processes occurring near the planet's earliest geological periods, though scientists continue to debate their definitive biological origin.</event>
#     </historical_event_2>
# </article>
#
# None
#
# <?xml version="1.0" encoding="UTF-8"?>
# <article>
#     <title>Black Holes: Cosmic Monsters of Infinite Darkness</title>
#
#     <historical_event_1>
#         <year>1915</year>
#         <event>Albert Einstein's theory of general relativity first mathematically predicted the possibility of regions in space where gravity becomes so intense that nothing, not even light, could escape</event>
#     </historical_event_1>
#
#     <historical_event_2>
#         <year>2019</year>
#         <event>The first direct image of a black hole was captured by the Event Horizon Telescope, revealing a massive dark center surrounded by a glowing ring of superheated gas in the galaxy M87</event>
#     </historical_event_2>
#
#     A black hole is a cosmic region in space where gravity is so powerful that nothing can escape its gravitational pull—not matter, not light, not even time itself. Imagine a place where the laws of physics break down, where a star has collapsed in on itself, creating a point of infinite density called a singularity.
#
#     These celestial phenomena form when massive stars die, compressing their entire mass into an incredibly small space. Their gravitational force is so extreme that anything crossing the "event horizon"—the point of no return—gets irreversibly pulled inward, creating a mysterious cosmic abyss that continues to fascinate scientists and capture the public imagination.
# </article>
#
# None
#
# <?xml version="1.0" encoding="UTF-8"?>
# <article>
#     <title>Our Nearest Star: Understanding the Sun's Distance</title>
#
#     <historical_event_1>
#         <year>1672</year>
#         <event>First scientific measurement of the distance to the sun by Jean Richer and Giovanni Cassini, using parallax observations from different locations on Earth</event>
#     </historical_event_1>
#
#     <historical_event_2>
#         <year>1961</year>
#         <event>NASA's development of more precise radar and laser measurement techniques dramatically improved our understanding of the sun's exact distance</event>
#     </historical_event_2>
#
#     The sun is approximately 93 million miles (149.6 million kilometers) from Earth—a distance astronomers call one "astronomical unit" (AU). To put this immense distance into perspective, if you could drive a car at highway speed non-stop, it would take about 177 years to reach the sun.
#
#     Light, traveling at 186,000 miles per second, takes roughly 8 minutes and 20 seconds to journey from the sun to Earth. This means when you look at the sun, you're actually seeing it as it was 8 minutes ago.
#
#     Modern scientific instruments have measured this distance with incredible precision, allowing us to understand our place in the solar system and appreciate the vast scales of space that surround our small blue planet.
# </article>
#
# None
#
# <?xml version="1.0" encoding="UTF-8"?>
# <article>
#     <title>Gravity's Planetary Cousins: Finding Earth's Closest Match</title>
#
#     <historical_event_1>
#         <year>1610</year>
#         <event>Galileo first observes Venus through a telescope, beginning humanity's detailed planetary exploration</event>
#     </historical_event_1>
#
#     <historical_event_2>
#         <year>1962</year>
#         <event>NASA's Mariner 2 mission provides first close-up measurements of Venus's planetary characteristics</event>
#     </historical_event_2>
#
#     Venus is the planet with a surface gravity most similar to Earth's. At 8.87 m/s², Venus's gravitational pull is about 90% of Earth's 9.8 m/s². This means if you weighed 100 pounds on Earth, you would weigh approximately 90 pounds on Venus.
#
#     Despite this gravitational similarity, Venus is dramatically different from our home planet. Its surface is an extreme environment of crushing atmospheric pressure and temperatures hot enough to melt lead. Thick sulfuric acid clouds and a runaway greenhouse effect make Venus inhospitable, rendering its near-Earth gravity an intriguing but ultimately irrelevant characteristic for potential human exploration.
#
#     This gravitational proximity reminds us that while planets might share some fundamental physical properties, their overall environments can be radically distinct.
# </article>
#
# None
#
# <?xml version="1.0" encoding="UTF-8"?>
# <article>
#     <title>Dwarf Planets: The Solar System's Smaller Siblings</title>
#
#     <historical_event_1>
#         <year>2006</year>
#         <event>The International Astronomical Union (IAU) officially defined the term "dwarf planet", dramatically changing our understanding of our solar system's planetary landscape</event>
#     </historical_event_1>
#
#     <historical_event_2>
#         <year>1930</year>
#         <event>Pluto was discovered by Clyde Tombaugh, which was originally considered the ninth planet but later reclassified as a dwarf planet</event>
#     </historical_event_2>
#
#     Eris, Haumea, Makemake, and Ceres are all dwarf planets - celestial bodies that orbit the sun and have enough mass to be nearly round, but haven't cleared their orbital neighborhood of other objects. Unlike full-sized planets, these smaller worlds inhabit the outer regions of our solar system, primarily in the Kuiper Belt and asteroid belt.
#
#     Ceres resides in the asteroid belt between Mars and Jupiter, while the others are located in the distant Kuiper Belt beyond Neptune. These fascinating worlds represent a crucial category of objects that help scientists understand the complex formation and evolution of our solar system.
#
#     Though smaller than traditional planets, dwarf planets are no less scientifically intriguing, offering windows into the early dynamics of planetary formation.
# </article>
#
# None
#
# <?xml version="1.0" encoding="UTF-8"?>
# <article>
#     <title>Earth's Seasonal Dance: A Cosmic Tilt Tale</title>
#
#     <historical_event_1>
#         <year>1543</year>
#         <event>Copernicus first proposed the heliocentric model, helping scientists understand planetary motion</event>
#     </historical_event_1>
#
#     <historical_event_2>
#         <year>1686</year>
#         <event>Isaac Newton explained gravitational forces that govern planetary rotations and orbits</event>
#     </historical_event_2>
#
#     Earth experiences seasons because of its 23.5-degree axial tilt. As our planet orbits the sun, this slight angle causes different hemispheres to receive varying amounts of direct sunlight throughout the year. When the Northern Hemisphere tilts toward the sun, it experiences summer, while the Southern Hemisphere simultaneously experiences winter.
#
#     Remarkably, other planets also have seasons! Mars has a similar axial tilt of about 25 degrees, creating seasonal patterns similar to Earth's. Uranus, however, has an extreme 98-degree tilt, causing radical seasonal shifts where entire hemispheres experience decades of continuous sunlight or darkness.
#
#     The complexity of planetary seasons reveals the intricate astronomical choreography happening in our solar system, reminding us that our own seasonal changes are part of a grand, cosmic dance of planetary motion.
# </article>
#
# None
#
# <?xml version="1.0" encoding="UTF-8"?>
# <article>
#     <title>Dancing Lights: The Science Behind the Aurora Borealis</title>
#
#     <historical_event_1>
#         <year>1619</year>
#         <event>Galileo Galilei first coined the term "aurora borealis", inspired by the Roman goddess of dawn</event>
#     </historical_event_1>
#
#     <historical_event_2>
#         <year>1957</year>
#         <event>Scientists during the International Geophysical Year confirmed the solar wind's role in creating auroras</event>
#     </historical_event_2>
#
#     The mesmerizing aurora borealis, or northern lights, are a breathtaking natural phenomenon caused by interactions between the Sun's charged particles and Earth's magnetic field. When energetic particles from solar winds collide with gases in our planet's upper atmosphere, they create stunning light displays.
#
#     These particles, primarily electrons and protons, are ejected from the Sun during solar storms. As they approach Earth, our planet's magnetic field channels them towards the polar regions. When these charged particles strike oxygen and nitrogen molecules at altitudes between 60 and 250 miles, they cause these molecules to become excited and emit colorful light.
#
#     Different atmospheric gases produce distinct colors: green from oxygen, red from high-altitude oxygen, and blue or purple from nitrogen. The result is a spectacular, ever-changing light show that has captivated humans for centuries.
# </article>
#
# None
#
# <?xml version="1.0" encoding="UTF-8"?>
# <article>
#     <title>Why the Sky Looks Blue: A Light-Scattering Mystery</title>
#
#     <historical_event_1>
#         <year>1859</year>
#         <event>John Tyndall first scientifically explains light scattering, laying groundwork for understanding blue sky phenomenon</event>
#     </historical_event_1>
#
#     <historical_event_2>
#         <year>1911</year>
#         <event>Lord Rayleigh mathematically describes how sunlight interacts with atmospheric molecules, confirming blue sky explanation</event>
#     </historical_event_2>
#
#     The mesmerizing blue of our sky isn't magic, but a remarkable physics phenomenon called Rayleigh scattering. Sunlight travels through the atmosphere as waves of different lengths, and shorter blue wavelengths get scattered more dramatically by tiny nitrogen and oxygen molecules.
#
#     Imagine light as a series of tennis balls bouncing through a crowd. Blue wavelengths are smaller and bounce around more easily, while longer red and orange wavelengths pass through more directly. This means blue light gets dispersed in all directions, creating the vast blue canopy we see overhead.
#
#     During sunrise and sunset, sunlight travels through more atmosphere, causing those wavelengths to scatter differently - which is why the sky transforms into stunning oranges and reds. Nature's light show is a testament to the elegant physics happening right above our heads.
# </article>
#
# None
#
# <?xml version="1.0" encoding="UTF-8"?>
# <article>
#     <title>The Amazing Language of Bees: Dancing in the Hive</title>
#
#     <historical_event_1>
#         <year>1944</year>
#         <event>Austrian scientist Karl von Frisch first decodes the bee waggle dance, revealing how honeybees communicate complex navigation information</event>
#     </historical_event_1>
#
#     <historical_event_2>
#         <year>1973</year>
#         <event>Von Frisch wins Nobel Prize in Physiology or Medicine for his groundbreaking research on bee communication</event>
#     </historical_event_2>
#
#     Honeybees have a remarkable communication system that allows them to share precise information about food sources without using words. Their primary method is the "waggle dance," a sophisticated choreography performed inside the hive.
#
#     When a bee discovers a rich nectar source, it returns and performs a dance on the honeycomb. The dance's angle indicates the direction of the food relative to the sun, while the duration of the waggle indicates distance. Other worker bees watch this performance and then fly directly to the described location.
#
#     This intricate communication system allows an entire colony to efficiently gather food, demonstrating that these tiny insects possess an incredibly complex and intelligent method of sharing critical survival information.
#
#     The waggle dance proves that communication in nature can be both elegant and precise, transcending human language in its simplicity and effectiveness.
# </article>
#
# None
#
# <?xml version="1.0" encoding="UTF-8"?>
# <article>
#     <title>The Tiniest Spark of Life: Exploring Cellular Foundations</title>
#
#     <historical_event_1>
#         <year>1665</year>
#         <event>Robert Hooke first observes cells using a primitive microscope, describing them as tiny "rooms" in plant tissue</event>
#     </historical_event_1>
#
#     <historical_event_2>
#         <year>1953</year>
#         <event>Watson and Crick discover DNA's double helix structure, revealing the molecular blueprint of life</event>
#     </historical_event_2>
#
#     The cell is universally recognized as the smallest unit of life. Unlike non-living molecules, cells can reproduce, metabolize energy, respond to stimuli, and adapt to their environment. While some might argue that viruses approach the boundary of life, they cannot reproduce without hijacking living cellular machinery.
#
#     Remarkably, some organisms like bacteria consist of just a single cell, demonstrating that complex life processes can occur in microscopic packages. Prokaryotic cells—such as those found in E. coli—represent the simplest functional living units, containing genetic material, ribosomes for protein production, and a cell membrane.
#
#     Modern microscopy now allows us to explore cellular structures with unprecedented detail, revealing the intricate molecular machinery that transforms simple chemical components into living, breathing organisms.
# </article>
#
# None
#
# <?xml version="1.0" encoding="UTF-8"?>
# <article>
#     <title>Nature's Green Factories: How Plants Feed Themselves</title>
#
#     <historical_event_1>
#         <year>1600s</year>
#         <event>Scientists first discovered that plants absorb sunlight to create energy</event>
#     </historical_event_1>
#
#     <historical_event_2>
#         <year>1845</year>
#         <event>Julius von Mayer identified photosynthesis as the process by which plants convert light into chemical energy</event>
#     </historical_event_2>
#
#     Plants are nature's incredible self-sustaining organisms, capable of manufacturing their own food through a remarkable process called photosynthesis. Using their leaves like solar panels, plants capture sunlight and transform it into chemical energy. Inside tiny structures called chloroplasts, plants combine water absorbed through their roots and carbon dioxide from the air to create glucose—their primary food source.
#
#     Chlorophyll, the pigment that gives leaves their green color, plays a crucial role by absorbing sunlight. As this energy breaks down water molecules, plants release oxygen as a byproduct—essentially breathing out the very air we need to survive. This ingenious process not only feeds the plant but also provides oxygen for other living creatures and helps remove carbon dioxide from the atmosphere.
#
#     Through photosynthesis, plants turn sunlight into a nutritious meal, demonstrating the incredible efficiency of nature's own food production system.
# </article>
#
# None
#
# <?xml version="1.0" encoding="UTF-8"?>
# <article>
#     <title>The Mysterious World of Dreams: Unraveling Nighttime Narratives</title>
#
#     <historical_event_1>
#         <year>1900</year>
#         <event>Sigmund Freud publishes "The Interpretation of Dreams", proposing that dreams represent unconscious desires and repressed thoughts</event>
#     </historical_event_1>
#
#     <historical_event_2>
#         <year>2009</year>
#         <event>Neuroscientists discover that dreams may play a crucial role in memory consolidation and emotional processing</event>
#     </historical_event_2>
#
#     Dreams remain one of science's most fascinating mysteries. While we don't fully understand their purpose, researchers have uncovered compelling theories. Dreams appear to serve multiple critical functions for our brain: they help process emotional experiences, consolidate memories, and potentially simulate potential real-world scenarios.
#
#     During REM sleep, our brain becomes incredibly active, creating vivid narratives that seem random but might be essential for psychological health. Some scientists believe dreaming is a form of mental rehearsal, allowing us to practice complex social interactions and problem-solving in a safe, consequence-free environment.
#
#     Intriguingly, all mammals dream, suggesting this neurological process has deep evolutionary significance. Whether they're bizarre adventures or mundane replays, dreams offer a window into our brain's remarkable capacity for creativity and adaptation.
# </article>
#
# None
#
# <?xml version="1.0" encoding="UTF-8"?>
# <article>
#     <title>Einstein's Revolutionary Theory of Relativity: Reimagining Space and Time</title>
#
#     <historical_event_1>
#         <year>1905</year>
#         <event>Albert Einstein introduces Special Relativity, fundamentally challenging classical physics by revealing that time and space are not absolute, but relative to an observer's motion.</event>
#     </historical_event_1>
#
#     <historical_event_2>
#         <year>1915</year>
#         <event>Einstein completes General Relativity, explaining gravity as a curvature of spacetime caused by massive objects, which revolutionized our understanding of the universe's fundamental structure.</event>
#     </historical_event_2>
# </article>
#
# The theory of relativity explains how space, time, and gravity are interconnected in ways that defy our everyday experience. Einstein discovered that time isn't a constant, universal flow, but can actually stretch and compress depending on an object's speed and gravitational environment.
#
# In simple terms, imagine two identical clocks - one on Earth and one on a spacecraft traveling near light speed. The clock on the spacecraft would tick more slowly, demonstrating that time itself is flexible. Similarly, massive objects like stars can bend light and warp spacetime, creating gravitational effects that challenge our traditional understanding of physics.
#
# These groundbreaking insights not only transformed scientific understanding but also enabled technologies we now take for granted, like GPS systems that account for relativistic time differences.
#
# None
#
# <?xml version="1.0" encoding="UTF-8"?>
# <article>
#     <title>The Fiery Science of Volcanic Eruptions</title>
#
#     <historical_event_1>
#         <year>1883</year>
#         <event>The catastrophic eruption of Krakatoa in Indonesia demonstrated the immense power of volcanic activity, causing global climate changes and killing over 36,000 people</event>
#     </historical_event_1>
#
#     <historical_event_2>
#         <year>1980</year>
#         <event>Mount St. Helens in Washington State erupted, dramatically reshaping the landscape and providing scientists with unprecedented insights into volcanic processes</event>
#     </historical_event_2>
#
#     Volcanoes erupt when molten rock, or magma, builds up tremendous pressure beneath the Earth's surface. Deep underground, extreme heat and pressure cause rocks to melt, creating magma chambers that gradually fill with hot, expanding gases and liquid rock. When the pressure becomes too great, the magma seeks escape through the path of least resistance - typically a volcanic vent or crack in the Earth's crust.
#
#     As magma rises, dissolved gases expand dramatically, creating explosive force. This can trigger spectacular eruptions where molten rock, ash, and superheated gases are violently ejected into the atmosphere. The specific characteristics of an eruption depend on factors like magma composition, gas content, and the volcano's geological structure.
#
#     Understanding these powerful natural phenomena helps scientists predict and mitigate potential volcanic hazards around the world.
# </article>
#
# None
#
# <?xml version="1.0" encoding="UTF-8"?>
# <article>
#     <title>The Cosmic Speed Limit: Understanding Light's Incredible Journey</title>
#
#     <historical_event_1>
#         <year>1905</year>
#         <event>Albert Einstein revolutionizes physics by proposing that the speed of light is constant and unchanging, a fundamental principle of his special theory of relativity</event>
#     </historical_event_1>
#
#     <historical_event_2>
#         <year>1983</year>
#         <event>Scientists precisely define the speed of light as 299,792,458 meters per second, establishing it as an exact measurement in scientific calculations</event>
#     </historical_event_2>
#
#     The speed of light is an extraordinary cosmic constant that represents the fastest possible speed in our universe. Traveling at approximately 186,282 miles per second, light can circle the Earth seven and a half times in just one second. This incredible velocity means that light from the sun takes about 8 minutes to reach Earth, and light from distant stars can take hundreds or thousands of years to arrive.
#
#     No known object with mass can travel faster than light, making it a fundamental speed limit of the universe. This remarkable speed enables everything from modern communications to our understanding of distant galaxies, serving as a critical benchmark in physics and astronomy.
# </article>
#
# None
#
# <?xml version="1.0" encoding="UTF-8"?>
# <article>
#     <title>The Invisible Force: Understanding Magnetism</title>
#
#     <historical_event_1>
#         <year>600 BCE</year>
#         <event>Ancient Greeks discover lodestone, a naturally magnetic mineral, sparking early curiosity about magnetic phenomena</event>
#     </historical_event_1>
#
#     <historical_event_2>
#         <year>1820</year>
#         <event>Hans Christian Oersted demonstrates the connection between electricity and magnetism, revolutionizing scientific understanding</event>
#     </historical_event_2>
#
#     Magnets work through the fundamental alignment of electrons within materials. At the atomic level, electrons spin and orbit around atomic nuclei, creating tiny magnetic fields. In most materials, these fields are randomly oriented, canceling each other out. But in magnetic materials like iron, these electron fields can align, producing a cohesive magnetic force.
#
#     Imagine these electron spins as miniature compass needles. When they point in the same direction, they generate a powerful, invisible field that can attract or repel other magnetic materials. This alignment happens naturally in certain elements and can be induced through external magnetic fields.
#
#     Permanent magnets maintain their magnetic properties because their electron spins remain consistently aligned, creating a stable magnetic field that can attract iron, nickel, and cobalt - enabling everything from refrigerator magnets to complex medical imaging technologies.
# </article>
#
# None
#
# <?xml version="1.0" encoding="UTF-8"?>
# <article>
#     <title>DNA: The Blueprint of Life</title>
#
#     <historical_event_1>
#         <year>1953</year>
#         <event>James Watson and Francis Crick discover the double helix structure of DNA, revolutionizing our understanding of genetics</event>
#     </historical_event_1>
#
#     <historical_event_2>
#         <year>2003</year>
#         <event>The Human Genome Project completes mapping all human genes, revealing the intricate instructions encoded in our DNA</event>
#     </historical_event_2>
#
#     DNA is nature's instruction manual for life. Like a complex blueprint, it contains the genetic information that determines everything from your eye color to how your body fights disease. Each DNA molecule is a unique sequence of chemical building blocks called nucleotides, which act as a code telling cells how to function, grow, and reproduce.
#
#     Think of DNA as a cookbook for your body. Just as a recipe guides a chef in creating a specific dish, DNA guides cells in creating proteins and performing essential functions. When cells divide, DNA is copied precisely, ensuring that genetic information passes from one generation to the next.
#
#     From determining inherited traits to protecting us against genetic disorders, DNA is the fundamental language of biological inheritance, connecting us to our ancestors and future generations through an intricate molecular script.
# </article>
#
# None
#
# <?xml version="1.0" encoding="UTF-8"?>
# <article>
#     <title>Exploring the Cosmic Menagerie: Types of Galaxies</title>
#
#     <historical_event_1>
#         <year>1926</year>
#         <event>Edwin Hubble first classified galaxies, revolutionizing our understanding of the universe</event>
#     </historical_event_1>
#
#     <historical_event_2>
#         <year>1994</year>
#         <event>Hubble Space Telescope provides unprecedented views of diverse galactic structures</event>
#     </historical_event_2>
#
#     Galaxies come in fascinating varieties, each with unique characteristics. The three main types are spiral, elliptical, and irregular galaxies.
#
#     Spiral galaxies, like our Milky Way, feature elegant rotating arms of stars and gas swirling around a central bulge. They're dynamic, actively forming new stars and containing younger stellar populations.
#
#     Elliptical galaxies appear as smooth, egg-shaped collections of older stars. These massive systems contain little active star formation and often result from galactic collisions.
#
#     Irregular galaxies lack defined structure, appearing chaotic and asymmetrical. They're typically smaller and contain abundant young stars, often resulting from gravitational interactions between galaxies.
#
#     Each galaxy type tells a unique story about cosmic evolution, revealing the complex and beautiful mechanisms that shape our universe's grand design.
# </article>
#
# None
#
# <?xml version="1.0" encoding="UTF-8"?>
# <article>
#     <title>The Great Winter Sleep: Understanding Animal Hibernation</title>
#
#     <historical_event_1>
#         <year>1832</year>
#         <event>Scientists first began systematically studying hibernation in European brown bears, discovering the complex physiological changes animals undergo during winter dormancy</event>
#     </historical_event_1>
#
#     <historical_event_2>
#         <year>1956</year>
#         <event>Researchers identified specific hormonal triggers that signal animals to enter hibernation, revealing the intricate biological mechanisms behind this survival strategy</event>
#     </historical_event_2>
#
#     Hibernation is nature's brilliant survival strategy for animals facing harsh winter conditions. When food becomes scarce and temperatures plummet, certain mammals dramatically slow their metabolism, reducing body temperature and heart rate to conserve energy.
#
#     Creatures like ground squirrels, bears, and bats enter a state of torpor where their energy consumption drops by up to 95%. During this period, they rely on fat reserves accumulated during warmer months. Their body essentially switches to an ultra-efficient "survival mode", allowing them to survive extreme cold and food shortages.
#
#     This remarkable adaptation demonstrates how evolution has equipped animals with ingenious mechanisms to overcome environmental challenges, turning what could be a deadly season into a period of strategic rest and renewal.
# </article>
#
# None
#
# <?xml version="1.0" encoding="UTF-8"?>
# <article>
#     <title>Vaccines: Your Body's Personal Defense Training Program</title>
#
#     <historical_event_1>
#         <year>1796</year>
#         <event>Edward Jenner develops the first vaccine against smallpox, demonstrating how introducing a weakened pathogen can protect against disease</event>
#     </historical_event_1>
#
#     <historical_event_2>
#         <year>1955</year>
#         <event>Jonas Salk creates the polio vaccine, dramatically reducing a devastating childhood disease worldwide</event>
#     </historical_event_2>
#
#     Vaccines work like a training manual for your immune system. They introduce a harmless version of a virus or bacteria - either weakened, killed, or partial - that teaches your body's defense mechanisms how to recognize and fight specific diseases without actually making you sick.
#
#     When the vaccine enters your body, your immune system creates specialized antibodies and memory cells. These act like wanted posters, helping white blood cells quickly identify and neutralize the real virus if you're ever exposed in the future. It's essentially a practice run that prepares your body's defense forces to respond rapidly and effectively.
#
#     By mimicking an infection without causing illness, vaccines enable your immune system to build a powerful, targeted defense strategy - transforming your body into a well-trained fortress against dangerous pathogens.
# </article>

# %% [markdown]
# ### Load previous results

# %% [markdown]
# First try all models file

# %%
if 0:
    import pickle

    with open(
        file=f"exp{experiment_num}_all_models_{experiment_date}.pkl", mode="rb"
    ) as f:
        data = pickle.load(f)

    # Inject into toplevel namespace
    namespace = locals()
    for key, value in data["models"].items():
        if key not in namespace:
            print(f"Loaded {key}")
            namespace[key] = value

# %%
if 0:
    import pickle

    # Load individual models
    output_idents = ["sys", "alt"]

    namespace = locals()
    for ident in output_idents:
        with open(
            file=f"exp{experiment_num}_xml_output_{ident}_{experiment_date}.pkl",
            mode="rb",
        ) as f:
            data = pickle.load(f)

        key = f"structure_support_by_model_{ident}"
        if key not in namespace:
            print(f"Loaded {key}")
            namespace[key] = data["structure_support_by_model"]

# %% [markdown]
# ## Hypothesis testing

# %% [markdown]
# Hypothesis:
#
# - H0: Different temperatures lead to different rates of XML schema conformance
# - H1: The proportions of conformance are the same

# %%
# Bonferroni correction
model_list = structure_support_by_model_t0.keys()
n_tests = len(model_list)
alpha = 0.05  # / n_tests

for model in model_list:

    contingency_table = {}
    for name, ss_results in results_list.items():
        num_true = 0
        num_total = 0
        for tname in ss_results[model].keys():
            num_true += ss_results[model][tname]["valid"] * len(questions)
            num_total += len(questions)

        contingency_table[name] = {"Passed": num_true, "Failed": num_total - num_true}

    ct = pd.DataFrame.from_dict(contingency_table, orient="index")

    # Ensure ordering to match hypotheses
    # Columns are experiments
    # Rows are outcomes
    # Column marginals are constant
    ct_n = ct[["Passed", "Failed"]].to_numpy().T

    print(f"\n{model}")
    print(sf := stats.fisher_exact(ct_n, alternative="greater"))
    print(sb := stats.barnard_exact(ct_n, alternative="greater"))
    if sb.pvalue < alpha:
        print(f"Hypothesis test passed: {sb.pvalue:.3g} < {alpha:.3g}")
# Out:
# Ollama_llama32
# SignificanceResult(statistic=np.float64(1.5681818181818181), pvalue=np.float64(0.14208888177506213))
# BarnardExactResult(statistic=np.float64(1.249303038696861), pvalue=np.float64(0.12258240508091653))
#
# Ollama_nemotron
# SignificanceResult(statistic=np.float64(1.6521739130434783), pvalue=np.float64(0.28396268931110596))
# BarnardExactResult(statistic=np.float64(0.8604859293176627), pvalue=np.float64(0.2645506113622348))
#
# Ollama_phi3
# SignificanceResult(statistic=np.float64(2.171112556929083), pvalue=np.float64(0.006510361002595765))
# BarnardExactResult(statistic=np.float64(2.6222244603662923), pvalue=np.float64(0.004495770764296521))
# Hypothesis test passed: 0.0045 < 0.05
#
# Ollama_phi4
# SignificanceResult(statistic=np.float64(0.0), pvalue=np.float64(1.0))
# BarnardExactResult(statistic=np.float64(-1.0025094142341715), pvalue=np.float64(1.0))
#
# Ollama_deepseekr1
# SignificanceResult(statistic=np.float64(1.1126126126126126), pvalue=np.float64(0.43520490196213557))
# BarnardExactResult(statistic=np.float64(0.3265986323710907), pvalue=np.float64(0.40962257002931984))
#
# fireworks_llama31
# SignificanceResult(statistic=np.float64(1.0), pvalue=np.float64(0.6163277826786353))
# BarnardExactResult(statistic=np.float64(0.0), pvalue=np.float64(1.0))
#
# fireworks_llama32
# SignificanceResult(statistic=np.float64(1.6730769230769231), pvalue=np.float64(0.12640858534972246))
# BarnardExactResult(statistic=np.float64(1.333514776259032), pvalue=np.float64(0.12226549369413986))
#
# fireworks_llama33
# SignificanceResult(statistic=np.float64(1.0), pvalue=np.float64(0.6893987705022575))
# BarnardExactResult(statistic=np.float64(0.0), pvalue=np.float64(1.0))
#
# fireworks_qwen25
# SignificanceResult(statistic=nan, pvalue=1.0)
# BarnardExactResult(statistic=np.float64(0.0), pvalue=np.float64(1.0))
#
# Anthropic_Sonnet_35
# SignificanceResult(statistic=nan, pvalue=1.0)
# BarnardExactResult(statistic=np.float64(0.0), pvalue=np.float64(1.0))
#
# Anthropic_Haiku_35
# SignificanceResult(statistic=np.float64(1.0), pvalue=np.float64(0.7512562814070352))
# BarnardExactResult(statistic=np.float64(0.0), pvalue=np.float64(1.0))
#
# Anthropic_Haiku_3
# SignificanceResult(statistic=np.float64(1.4301075268817205), pvalue=np.float64(0.3836722173213647))
# BarnardExactResult(statistic=np.float64(0.5954913341754107), pvalue=np.float64(0.29631226239677527))

# %% [markdown]
# ### Combined levels: does temperature change the conformance to XML ?

# %%
from scipy import stats

model_list = structure_support_by_model_t0.keys()

contingency_table = {}
for model in model_list:
    for name, ss_results in results_list.items():
        for tname in ss_results[model].keys():
            contingency_table[name] = contingency_table.get(
                name, {"Passed": 0, "Failed": 0}
            )
            num_true = ss_results[model][tname]["valid"] * len(questions)
            num_total = len(questions)

            contingency_table[name]["Passed"] += num_true
            contingency_table[name]["Failed"] += num_total - num_true

ct = pd.DataFrame.from_dict(contingency_table, orient="index")

# %% [markdown]
# From the contingency table alone we see that there is some differnece between the results for temperatures

# %%
ct
# Out:
#        Passed  Failed
# t=0     987.0   213.0
# t=0.8   949.0   251.0

# %%
# Chi-Squared Test for multiple groups
res = stats.chi2_contingency(ct)
print(f"\nChi-Squared Test:\nStatistic={res.statistic:.4f}, p={res.pvalue:.4g}")
# Out:
# Chi-Squared Test:
# Statistic=3.6576, p=0.05582

# %%
# Chi-Squared Test for multiple groups
res = stats.barnard_exact(ct)
print(f"Barnard exact test:\nStatistic={res.statistic:.4f}, p={res.pvalue:.4g}")
# Out:
# Barnard exact test:
# Statistic=1.9642, p=0.04995
