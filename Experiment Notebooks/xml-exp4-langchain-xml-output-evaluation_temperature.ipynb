# %% [markdown]
# ## Using LangChain to get structured outputs

# %% [markdown]
# ## Setup

# %%
import pickle
import pandas as pd
import tabulate
from scipy import stats
from langchain.prompts import ChatPromptTemplate
from langchain_anthropic import ChatAnthropic
from langchain_ollama import ChatOllama
from langchain_fireworks import ChatFireworks

from pydantic_structure_definitions import *

from experiment_xml import (
    pydantic_to_xml_instructions,
    run_xml_experiment,
)

# %%
ANTHROPIC_API_KEY = "<API KEY>"
FIREWORKS_API_KEY = "<API KEY>"

# %%
import streamlit as st

LANGSMITH_API_KEY = st.secrets["api_keys"]["LANGSMITH_API_KEY"]
ANTHROPIC_API_KEY = st.secrets["api_keys"]["ANTHROPIC_API_KEY"]
FIREWORKS_API_KEY = st.secrets["api_keys"]["FIREWORKS_API_KEY"]

# %%
experiment_date = "25-02-25"
experiment_num = "4"
n_iter = 1

# %% [markdown]
# Let's start by creating a LLM model to run our structured output queries. Use a temperature of 0 to improve structured output generation (but at the cost of "creativity").

# %% [markdown]
# ### Model setup

# %%
# LLM parameters
# temperature = 0.0
timeout = 30
num_ctx = 8192
num_predict = 4096

# %%
llm_models = []
llm_models_with_anthropic = []
for ii, temperature in enumerate([0, 0.8]):
    llm_models_ii = {
        "Ollama_llama32": ChatOllama(
            model="llama3.2",
            temperature=temperature,
            num_ctx=num_ctx,
            num_thread=1,
            num_predict=num_predict,
        ),
        "Ollama_nemotron": ChatOllama(
            model="nemotron-mini",
            temperature=temperature,
            num_ctx=num_ctx,
            num_thread=1,
            num_predict=num_predict,
        ),
        "Ollama_phi3": ChatOllama(
            model="phi3",
            temperature=temperature,
            num_ctx=num_ctx,
            num_thread=1,
            num_predict=num_predict,
        ),
        "Ollama_phi4": ChatOllama(
            model="phi4",
            temperature=temperature,
            num_ctx=num_ctx,
            num_thread=1,
            num_predict=num_predict,
        ),
        "Ollama_deepseekr1": ChatOllama(
            model="deepseek-r1",
            temperature=temperature,
            num_ctx=num_ctx,
            num_thread=1,
            num_predict=num_predict,
        ),
        "fireworks_llama31": ChatFireworks(
            model_name="accounts/fireworks/models/llama-v3p1-70b-instruct",
            api_key=FIREWORKS_API_KEY,
            temperature=temperature,
            timeout=timeout,
        ),
        "fireworks_llama32": ChatFireworks(
            model_name="accounts/fireworks/models/llama-v3p2-3b-instruct",
            api_key=FIREWORKS_API_KEY,
            temperature=temperature,
            timeout=timeout,
        ),
        "fireworks_llama33": ChatFireworks(
            model_name="accounts/fireworks/models/llama-v3p3-70b-instruct",
            api_key=FIREWORKS_API_KEY,
            temperature=temperature,
            timeout=timeout,
        ),
        "fireworks_qwen25": ChatFireworks(
            model_name="accounts/fireworks/models/qwen2p5-72b-instruct",
            api_key=FIREWORKS_API_KEY,
            temperature=temperature,
            timeout=timeout,
        ),
        # "fireworks_deepseekr1": ChatFireworks(
        #     model_name="accounts/fireworks/models/deepseek-r1",
        #     api_key=FIREWORKS_API_KEY,
        #     temperature=temperature,
        #     timeout=timeout,
        # ),
    }
    llm_models_with_anthropic_ii = {
        **llm_models_ii,
        "Anthropic_Sonnet_35": ChatAnthropic(
            model="claude-3-5-sonnet-20241022",
            api_key=ANTHROPIC_API_KEY,
            timeout=timeout,
            temperature=temperature,
        ),
        "Anthropic_Haiku_35": ChatAnthropic(
            model="claude-3-5-haiku-20241022",
            api_key=ANTHROPIC_API_KEY,
            timeout=timeout,
            temperature=temperature,
        ),
        "Anthropic_Haiku_3": ChatAnthropic(
            model="claude-3-haiku-20240307",
            api_key=ANTHROPIC_API_KEY,
            timeout=timeout,
            temperature=temperature,
        ),
    }
    llm_models.append(llm_models_ii)
    llm_models_with_anthropic.append(llm_models_with_anthropic_ii)

# %% [markdown]
# ### Problem setup and prompt

# %%
test_science_prompt_txt = """
You are a professional science writer tasked with responding to members of
the general public who write in asking questions about science.
Write an article responding to a writer's question for publication in a
science magazine intended for a general readership with a high-school education.
You should write clearly and compellingly, include all relavent context,
and provide motivating stories where applicable.

Your response must be less than 200 words.

The question given to you is the following:
{question}
"""

questions = [
    "What is the oldest recorded fossil?",
    "What is a black hole?",
    "How far away is the sun?",
    "Which other planet in the Solar System has a surface gravity closest to that of the Earth?",
    "Eris, Haumea, Makemake and Ceres are all examples of what?",
    "Why does earth have seasons? Do other planets exhibit seasons too?",
    "What causes the aurora borealis?",
    "Why is the sky blue?",
    "How do bees communicate?",
    "What is the smallest unit of life?",
    "How do plants make their own food?",
    "Why do we dream?",
    "What is the theory of relativity?",
    "How do volcanoes erupt?",
    "What is the speed of light?",
    "How do magnets work?",
    "What is the purpose of DNA?",
    "What are the different types of galaxies?",
    "Why do some animals hibernate?",
    "How do vaccines work?",
]

# %%
prompt_direct = ChatPromptTemplate.from_template(test_science_prompt_txt)

prompt_system_format = ChatPromptTemplate.from_messages(
    [
        (
            "system",
            "Return a publishable article in the requested format.\n{format_instructions}",
        ),
        ("human", test_science_prompt_txt),
    ]
)

prompt_system_plus_reminder_format = ChatPromptTemplate.from_messages(
    [
        (
            "system",
            "Return a publishable article in the requested format.\n{format_instructions}",
        ),
        (
            "human",
            test_science_prompt_txt + "\nYour response must be in valid XML.",
        ),
    ]
)

prompt_user_format = ChatPromptTemplate.from_template(
    test_science_prompt_txt + "\n{format_instructions}"
)

# %% [markdown]
# ### Schema using Pydantic XML

# %%
structured_formats_xml = [
    dict(pydantic=schema, format_instructions=pydantic_to_xml_instructions(schema))
    for schema in [
        ArticleResponse1XML,
        ArticleResponse1nointXML,
        ArticleResponse2XML,
        ArticleResponse3XML,
        ArticleResponse4XML,
    ]
]

structured_formats_xml_alt = [
    dict(pydantic=schema, format_instructions=pydantic_to_xml_instructions(schema))
    for schema in [
        ArticleResponse1XML,
        ArticleResponse2XMLalt,
        ArticleResponse3XML,
        ArticleResponse4XMLalt,
    ]
]

# %%
print(pydantic_to_xml_instructions(ArticleResponse2XMLalt))
# Out:
# You must respond only in XML using the following schema.
# Do not provide any output outside the first and last XML tags.
#
# <article>
#   <!--Structured article for publication answering a reader's question-->
#   <title>
#     {Title of the article - must be type str}
#   </title>
#   <answer>
#     {Answer the writer's question - must be type str}
#   </answer>
# <further_questions>
#   <!--A list of related questions of interest to the readers-->
# <!-- Next list element -->
#   <further_question>
#     {A related question of interest to readers - must be type str}
#   </further_question>
# <!-- First list element -->
#   <further_question>
#     {A related question of interest to readers - must be type str}
#   </further_question>
# <!-- Etc -->
#   <further_question>
#   ...
#   </further_question>
# </further_questions>
# </article>

# %% [markdown]
# ## Experiment
#
# Hypotheses:
#
# - Temperature influences the conformance to XML

# %% [markdown]
# First Temperature

# %%
if "structure_support_by_model_t0" not in locals():
    structure_support_by_model_t0 = {}

_ = run_xml_experiment(
    prompt_system_format,
    questions,
    llm_models_with_anthropic[0],
    structured_formats_xml,
    n_iter=1,
    results_out=structure_support_by_model_t0,
    save_file_name=f"exp{experiment_num}_xml_output_t0_{experiment_date}.pkl",
)
# Out:
# Model: Ollama_llama32  Output: ArticleResponse1XML   Pos: 1
# e.ee..e...eeeee.eeee
# Model: Ollama_llama32  Output: ArticleResponse1nointXML   Pos: 2
# ......e.............
# Model: Ollama_llama32  Output: ArticleResponse2XML   Pos: 3
# ....................
# Model: Ollama_llama32  Output: ArticleResponse3XML   Pos: 4
# .....e..............
# Model: Ollama_llama32  Output: ArticleResponse4XML   Pos: 5
# ....e...............
# Model: Ollama_nemotron  Output: ArticleResponse1XML   Pos: 6
# eeee..eeeeeeeeeeeeee
# Model: Ollama_nemotron  Output: ArticleResponse1nointXML   Pos: 7
# eeee..eeee.eeeeeeeee
# Model: Ollama_nemotron  Output: ArticleResponse2XML   Pos: 8
# eeee.eeeeeeeeeeeeeee
# Model: Ollama_nemotron  Output: ArticleResponse3XML   Pos: 9
# eeee.eeeeeeeeeeeeeee
# Model: Ollama_nemotron  Output: ArticleResponse4XML   Pos: 10
# eeee.eeeeeeeeeeeeeee
# Model: Ollama_phi3  Output: ArticleResponse1XML   Pos: 11
# e.eee..eee....ee...e
# Model: Ollama_phi3  Output: ArticleResponse1nointXML   Pos: 12
# ..eeee.......ee.....
# Model: Ollama_phi3  Output: ArticleResponse2XML   Pos: 13
# ..eeeee.e.e..e.....e
# Model: Ollama_phi3  Output: ArticleResponse3XML   Pos: 14
# eeeee.eeeee.eeee.ee.
# Model: Ollama_phi3  Output: ArticleResponse4XML   Pos: 15
# e..eee..e..e.eee.eee
# Model: Ollama_phi4  Output: ArticleResponse1XML   Pos: 16
# ...e................
# Model: Ollama_phi4  Output: ArticleResponse1nointXML   Pos: 17
# ....................
# Model: Ollama_phi4  Output: ArticleResponse2XML   Pos: 18
# ....................
# Model: Ollama_phi4  Output: ArticleResponse3XML   Pos: 19
# ....................
# Model: Ollama_phi4  Output: ArticleResponse4XML   Pos: 20
# ....................
# Model: Ollama_deepseekr1  Output: ArticleResponse1XML   Pos: 21
# ..e..e.ee.........ee
# Model: Ollama_deepseekr1  Output: ArticleResponse1nointXML   Pos: 22
# ...e.eee..ee......ee
# Model: Ollama_deepseekr1  Output: ArticleResponse2XML   Pos: 23
# ...e...e..e........e
# Model: Ollama_deepseekr1  Output: ArticleResponse3XML   Pos: 24
# ...e............e...
# Model: Ollama_deepseekr1  Output: ArticleResponse4XML   Pos: 25
# ...eee.....e........
# Model: fireworks_llama31  Output: ArticleResponse1XML   Pos: 26
# e.e..e..e.....ee....
# Model: fireworks_llama31  Output: ArticleResponse1nointXML   Pos: 27
# ....................
# Model: fireworks_llama31  Output: ArticleResponse2XML   Pos: 28
# ....................
# Model: fireworks_llama31  Output: ArticleResponse3XML   Pos: 29
# ....................
# Model: fireworks_llama31  Output: ArticleResponse4XML   Pos: 30
# ....................
# Model: fireworks_llama32  Output: ArticleResponse1XML   Pos: 31
# eee...e..eee.ee..eee
# Model: fireworks_llama32  Output: ArticleResponse1nointXML   Pos: 32
# ...........e........
# Model: fireworks_llama32  Output: ArticleResponse2XML   Pos: 33
# ....................
# Model: fireworks_llama32  Output: ArticleResponse3XML   Pos: 34
# ....................
# Model: fireworks_llama32  Output: ArticleResponse4XML   Pos: 35
# ....................
# Model: fireworks_llama33  Output: ArticleResponse1XML   Pos: 36
# e...................
# Model: fireworks_llama33  Output: ArticleResponse1nointXML   Pos: 37
# ....................
# Model: fireworks_llama33  Output: ArticleResponse2XML   Pos: 38
# ....................
# Model: fireworks_llama33  Output: ArticleResponse3XML   Pos: 39
# ....................
# Model: fireworks_llama33  Output: ArticleResponse4XML   Pos: 40
# ...............e....
# Model: fireworks_qwen25  Output: ArticleResponse1XML   Pos: 41
# ....................
# Model: fireworks_qwen25  Output: ArticleResponse1nointXML   Pos: 42
# ....................
# Model: fireworks_qwen25  Output: ArticleResponse2XML   Pos: 43
# ....................
# Model: fireworks_qwen25  Output: ArticleResponse3XML   Pos: 44
# ....................
# Model: fireworks_qwen25  Output: ArticleResponse4XML   Pos: 45
# ....................
# Model: fireworks_deepseekr1_70b  Output: ArticleResponse1XML   Pos: 46
# eeeeeeeeeeeeeeeeeeee
# Model: fireworks_deepseekr1_70b  Output: ArticleResponse1nointXML   Pos: 47
# eeeeeeeeeeeeeeeeeeee
# Model: fireworks_deepseekr1_70b  Output: ArticleResponse2XML   Pos: 48
# eeeeeeeeeeeeeeeeeeee
# Model: fireworks_deepseekr1_70b  Output: ArticleResponse3XML   Pos: 49
# eeeeeeeeeeeeeeeeeeee
# Model: fireworks_deepseekr1_70b  Output: ArticleResponse4XML   Pos: 50
# eeeeeeeeeeeeeeeeeeee
# Model: Anthropic_Sonnet_35  Output: ArticleResponse1XML   Pos: 51
# ....................
# Model: Anthropic_Sonnet_35  Output: ArticleResponse1nointXML   Pos: 52
# ....................
# Model: Anthropic_Sonnet_35  Output: ArticleResponse2XML   Pos: 53
# ....................
# Model: Anthropic_Sonnet_35  Output: ArticleResponse3XML   Pos: 54
# ....................
# Model: Anthropic_Sonnet_35  Output: ArticleResponse4XML   Pos: 55
# ....................
# Model: Anthropic_Haiku_35  Output: ArticleResponse1XML   Pos: 56
# .........e..........
# Model: Anthropic_Haiku_35  Output: ArticleResponse1nointXML   Pos: 57
# ....................
# Model: Anthropic_Haiku_35  Output: ArticleResponse2XML   Pos: 58
# ....................
# Model: Anthropic_Haiku_35  Output: ArticleResponse3XML   Pos: 59
# ....................
# Model: Anthropic_Haiku_35  Output: ArticleResponse4XML   Pos: 60
# ....................
# Model: Anthropic_Haiku_3  Output: ArticleResponse1XML   Pos: 61
# .....e..e.....e.e..e
# Model: Anthropic_Haiku_3  Output: ArticleResponse1nointXML   Pos: 62
# ....................
# Model: Anthropic_Haiku_3  Output: ArticleResponse2XML   Pos: 63
# ....................
# Model: Anthropic_Haiku_3  Output: ArticleResponse3XML   Pos: 64
# ....................
# Model: Anthropic_Haiku_3  Output: ArticleResponse4XML   Pos: 65
# ....................

# %%
if "structure_support_by_model_t08" not in locals():
    structure_support_by_model_t08 = {}

_ = run_xml_experiment(
    prompt_system_format,
    questions,
    llm_models_with_anthropic[1],
    structured_formats_xml,
    n_iter=1,
    results_out=structure_support_by_model_t08,
    save_file_name=f"exp{experiment_num}_xml_output_t08_{experiment_date}.pkl",
)
# Out:
# Model: Ollama_llama32  Output: ArticleResponse1XML   Pos: 1
# eeee.......eeeee.eee
# Model: Ollama_llama32  Output: ArticleResponse1nointXML   Pos: 2
# ....................
# Model: Ollama_llama32  Output: ArticleResponse2XML   Pos: 3
# .......e............
# Model: Ollama_llama32  Output: ArticleResponse3XML   Pos: 4
# .....e.......ee..e..
# Model: Ollama_llama32  Output: ArticleResponse4XML   Pos: 5
# ...ee..eee.e........
# Model: Ollama_nemotron  Output: ArticleResponse1XML   Pos: 6
# eeee.eeeeeeeeeee.eee
# Model: Ollama_nemotron  Output: ArticleResponse1nointXML   Pos: 7
# eeee.eeeee.eeeeeeeee
# Model: Ollama_nemotron  Output: ArticleResponse2XML   Pos: 8
# eeeeeeeeeeeeeeeeeeee
# Model: Ollama_nemotron  Output: ArticleResponse3XML   Pos: 9
# eeeeeeeeeeeeeeeeeeee
# Model: Ollama_nemotron  Output: ArticleResponse4XML   Pos: 10
# eeeee.eeeeeeeeeeeeee
# Model: Ollama_phi3  Output: ArticleResponse1XML   Pos: 11
# e.eee....e.e..eee..e
# Model: Ollama_phi3  Output: ArticleResponse1nointXML   Pos: 12
# ..e.e.e.ee.ee.eee...
# Model: Ollama_phi3  Output: ArticleResponse2XML   Pos: 13
# eeeeee.eeeee.e.e.eee
# Model: Ollama_phi3  Output: ArticleResponse3XML   Pos: 14
# .eeeeeee.eee.eeeeee.
# Model: Ollama_phi3  Output: ArticleResponse4XML   Pos: 15
# eeeeeeee.eeeeeeeeeee
# Model: Ollama_phi4  Output: ArticleResponse1XML   Pos: 16
# ....................
# Model: Ollama_phi4  Output: ArticleResponse1nointXML   Pos: 17
# ....................
# Model: Ollama_phi4  Output: ArticleResponse2XML   Pos: 18
# ....................
# Model: Ollama_phi4  Output: ArticleResponse3XML   Pos: 19
# ....................
# Model: Ollama_phi4  Output: ArticleResponse4XML   Pos: 20
# ....................
# Model: Ollama_deepseekr1  Output: ArticleResponse1XML   Pos: 21
# ..e..e.e..e.....ee..
# Model: Ollama_deepseekr1  Output: ArticleResponse1nointXML   Pos: 22
# ee.........e.....ee.
# Model: Ollama_deepseekr1  Output: ArticleResponse2XML   Pos: 23
# e.....ee..........e.
# Model: Ollama_deepseekr1  Output: ArticleResponse3XML   Pos: 24
# ...e...e..e.e.......
# Model: Ollama_deepseekr1  Output: ArticleResponse4XML   Pos: 25
# ..ee...e.ee......ee.
# Model: fireworks_llama31  Output: ArticleResponse1XML   Pos: 26
# e.ee.e..e.....e.....
# Model: fireworks_llama31  Output: ArticleResponse1nointXML   Pos: 27
# ....................
# Model: fireworks_llama31  Output: ArticleResponse2XML   Pos: 28
# ....................
# Model: fireworks_llama31  Output: ArticleResponse3XML   Pos: 29
# ....................
# Model: fireworks_llama31  Output: ArticleResponse4XML   Pos: 30
# ....................
# Model: fireworks_llama32  Output: ArticleResponse1XML   Pos: 31
# e.ee.e...eee.ee.e.ee
# Model: fireworks_llama32  Output: ArticleResponse1nointXML   Pos: 32
# .......e............
# Model: fireworks_llama32  Output: ArticleResponse2XML   Pos: 33
# ..ee................
# Model: fireworks_llama32  Output: ArticleResponse3XML   Pos: 34
# ..e............e....
# Model: fireworks_llama32  Output: ArticleResponse4XML   Pos: 35
# ...e.............ee.
# Model: fireworks_llama33  Output: ArticleResponse1XML   Pos: 36
# e....e..............
# Model: fireworks_llama33  Output: ArticleResponse1nointXML   Pos: 37
# ....................
# Model: fireworks_llama33  Output: ArticleResponse2XML   Pos: 38
# ....................
# Model: fireworks_llama33  Output: ArticleResponse3XML   Pos: 39
# ....................
# Model: fireworks_llama33  Output: ArticleResponse4XML   Pos: 40
# ....................
# Model: fireworks_qwen25  Output: ArticleResponse1XML   Pos: 41
# ....................
# Model: fireworks_qwen25  Output: ArticleResponse1nointXML   Pos: 42
# ....................
# Model: fireworks_qwen25  Output: ArticleResponse2XML   Pos: 43
# ....................
# Model: fireworks_qwen25  Output: ArticleResponse3XML   Pos: 44
# ....................
# Model: fireworks_qwen25  Output: ArticleResponse4XML   Pos: 45
# ....................
# Model: fireworks_deepseekr1_70b  Output: ArticleResponse1XML   Pos: 46
# eeeeeeeeeeeeeeeeeeee
# Model: fireworks_deepseekr1_70b  Output: ArticleResponse1nointXML   Pos: 47
# eeeeeeeeeeeeeeeeeeee
# Model: fireworks_deepseekr1_70b  Output: ArticleResponse2XML   Pos: 48
# eeeeeeeeeeeeeeeeeeee
# Model: fireworks_deepseekr1_70b  Output: ArticleResponse3XML   Pos: 49
# eeeeeeeeeeeeeeeeeeee
# Model: fireworks_deepseekr1_70b  Output: ArticleResponse4XML   Pos: 50
# eeeeeeeeeeeeeeeeeeee
# Model: Anthropic_Sonnet_35  Output: ArticleResponse1XML   Pos: 51
# ....................
# Model: Anthropic_Sonnet_35  Output: ArticleResponse1nointXML   Pos: 52
# ....................
# Model: Anthropic_Sonnet_35  Output: ArticleResponse2XML   Pos: 53
# ....................
# Model: Anthropic_Sonnet_35  Output: ArticleResponse3XML   Pos: 54
# ....................
# Model: Anthropic_Sonnet_35  Output: ArticleResponse4XML   Pos: 55
# ....................
# Model: Anthropic_Haiku_35  Output: ArticleResponse1XML   Pos: 56
# ....................
# Model: Anthropic_Haiku_35  Output: ArticleResponse1nointXML   Pos: 57
# ....................
# Model: Anthropic_Haiku_35  Output: ArticleResponse2XML   Pos: 58
# ....................
# Model: Anthropic_Haiku_35  Output: ArticleResponse3XML   Pos: 59
# .................e..
# Model: Anthropic_Haiku_35  Output: ArticleResponse4XML   Pos: 60
# ....................
# Model: Anthropic_Haiku_3  Output: ArticleResponse1XML   Pos: 61
# ..ee.e..e.e...e.e...
# Model: Anthropic_Haiku_3  Output: ArticleResponse1nointXML   Pos: 62
# ....................
# Model: Anthropic_Haiku_3  Output: ArticleResponse2XML   Pos: 63
# ....................
# Model: Anthropic_Haiku_3  Output: ArticleResponse3XML   Pos: 64
# ....................
# Model: Anthropic_Haiku_3  Output: ArticleResponse4XML   Pos: 65
# ....................

# %% [markdown]
# Save all models

# %%
namespace = locals()
all_model_outputs = [k for k in namespace.keys() if k.startswith("structure_support")]

with open(file=f"exp{experiment_num}_all_models_{experiment_date}.pkl", mode="wb") as f:
    data = dict(
        temperature=temperature,
        num_ctx=num_ctx,
        num_predict=num_predict,
        questions=questions,
        prompt=prompt_direct,
        models={k: namespace[k] for k in all_model_outputs},
    )
    pickle.dump(data, f)

# %% [markdown]
# ### Results table

# %%
results_list = {
    "t=0": structure_support_by_model_t0,
    "t=0.8": structure_support_by_model_t08,
}

df_results = {}
for name, ss_results in results_list.items():
    df_results[name] = pd.DataFrame.from_dict(
        {
            tuple(mname.split("_", maxsplit=1)): {
                tname: ss_results[mname][tname]["valid"] * 100
                for tname in ss_results[mname].keys()
            }
            for mname in ss_results.keys()
        },
        orient="index",
    )
    display(name)
# Out:
# 't=0'
# 't=0.8'

# %%
df = pd.concat(df_results).reorder_levels([1, 2, 0], axis=0).sort_index(axis=0)

with open(
    file=f"exp{experiment_num}_summary_df_{experiment_date}.json", mode="wb"
) as f:
    df.to_json(f)

# %%
df
# Out:
#                                 ArticleResponse1XML  ArticleResponse1nointXML  \
# Anthropic Haiku_3        t=0                   75.0                     100.0
#                          t=0.8                 65.0                     100.0
#           Haiku_35       t=0                   95.0                     100.0
#                          t=0.8                100.0                     100.0
#           Sonnet_35      t=0                  100.0                     100.0
#                          t=0.8                100.0                     100.0
# Ollama    deepseekr1     t=0                   70.0                      60.0
#                          t=0.8                 70.0                      75.0
#           llama32        t=0                   35.0                      95.0
#                          t=0.8                 40.0                     100.0
#           nemotron       t=0                   10.0                      15.0
#                          t=0.8                 10.0                      10.0
#           phi3           t=0                   50.0                      70.0
#                          t=0.8                 50.0                      50.0
#           phi4           t=0                   95.0                     100.0
#                          t=0.8                100.0                     100.0
# fireworks deepseekr1_70b t=0                    0.0                       0.0
#                          t=0.8                  0.0                       0.0
#           llama31        t=0                   70.0                     100.0
#                          t=0.8                 70.0                     100.0
#           llama32        t=0                   40.0                      95.0
#                          t=0.8                 40.0                      95.0
#           llama33        t=0                   95.0                     100.0
#                          t=0.8                 90.0                     100.0
#           qwen25         t=0                  100.0                     100.0
#                          t=0.8                100.0                     100.0
#
#                                 ArticleResponse2XML  ArticleResponse3XML  \
# Anthropic Haiku_3        t=0                  100.0                100.0
#                          t=0.8                100.0                100.0
#           Haiku_35       t=0                  100.0                100.0
#                          t=0.8                100.0                 95.0
#           Sonnet_35      t=0                  100.0                100.0
#                          t=0.8                100.0                100.0
# Ollama    deepseekr1     t=0                   80.0                 90.0
#                          t=0.8                 80.0                 80.0
#           llama32        t=0                  100.0                 95.0
#                          t=0.8                 95.0                 80.0
#           nemotron       t=0                    5.0                  5.0
#                          t=0.8                  0.0                  0.0
#           phi3           t=0                   55.0                 20.0
#                          t=0.8                 20.0                 20.0
#           phi4           t=0                  100.0                100.0
#                          t=0.8                100.0                100.0
# fireworks deepseekr1_70b t=0                    0.0                  0.0
#                          t=0.8                  0.0                  0.0
#           llama31        t=0                  100.0                100.0
#                          t=0.8                100.0                100.0
#           llama32        t=0                  100.0                100.0
#                          t=0.8                 90.0                 90.0
#           llama33        t=0                  100.0                100.0
#                          t=0.8                100.0                100.0
#           qwen25         t=0                  100.0                100.0
#                          t=0.8                100.0                100.0
#
#                                 ArticleResponse4XML
# Anthropic Haiku_3        t=0                  100.0
#                          t=0.8                100.0
#           Haiku_35       t=0                  100.0
#                          t=0.8                100.0
#           Sonnet_35      t=0                  100.0
#                          t=0.8                100.0
# Ollama    deepseekr1     t=0                   80.0
#                          t=0.8                 65.0
#           llama32        t=0                   95.0
#                          t=0.8                 70.0
#           nemotron       t=0                    5.0
#                          t=0.8                  5.0
#           phi3           t=0                   40.0
#                          t=0.8                  5.0
#           phi4           t=0                  100.0
#                          t=0.8                100.0
# fireworks deepseekr1_70b t=0                    0.0
#                          t=0.8                  0.0
#           llama31        t=0                  100.0
#                          t=0.8                100.0
#           llama32        t=0                  100.0
#                          t=0.8                 85.0
#           llama33        t=0                   95.0
#                          t=0.8                100.0
#           qwen25         t=0                  100.0
#                          t=0.8                100.0

# %%
import tabulate

print(
    tabulate.tabulate(
        df.reset_index(), headers="keys", tablefmt="pipe", showindex=False
    )
)
# Out:
# | level_0   | level_1        | level_2   |   ArticleResponse1XML |   ArticleResponse1nointXML |   ArticleResponse2XML |   ArticleResponse3XML |   ArticleResponse4XML |
# |:----------|:---------------|:----------|----------------------:|---------------------------:|----------------------:|----------------------:|----------------------:|
# | Anthropic | Haiku_3        | t=0       |                    75 |                        100 |                   100 |                   100 |                   100 |
# | Anthropic | Haiku_3        | t=0.8     |                    65 |                        100 |                   100 |                   100 |                   100 |
# | Anthropic | Haiku_35       | t=0       |                    95 |                        100 |                   100 |                   100 |                   100 |
# | Anthropic | Haiku_35       | t=0.8     |                   100 |                        100 |                   100 |                    95 |                   100 |
# | Anthropic | Sonnet_35      | t=0       |                   100 |                        100 |                   100 |                   100 |                   100 |
# | Anthropic | Sonnet_35      | t=0.8     |                   100 |                        100 |                   100 |                   100 |                   100 |
# | Ollama    | deepseekr1     | t=0       |                    70 |                         60 |                    80 |                    90 |                    80 |
# | Ollama    | deepseekr1     | t=0.8     |                    70 |                         75 |                    80 |                    80 |                    65 |
# | Ollama    | llama32        | t=0       |                    35 |                         95 |                   100 |                    95 |                    95 |
# | Ollama    | llama32        | t=0.8     |                    40 |                        100 |                    95 |                    80 |                    70 |
# | Ollama    | nemotron       | t=0       |                    10 |                         15 |                     5 |                     5 |                     5 |
# | Ollama    | nemotron       | t=0.8     |                    10 |                         10 |                     0 |                     0 |                     5 |
# | Ollama    | phi3           | t=0       |                    50 |                         70 |                    55 |                    20 |                    40 |
# | Ollama    | phi3           | t=0.8     |                    50 |                         50 |                    20 |                    20 |                     5 |
# | Ollama    | phi4           | t=0       |                    95 |                        100 |                   100 |                   100 |                   100 |
# | Ollama    | phi4           | t=0.8     |                   100 |                        100 |                   100 |                   100 |                   100 |
# | fireworks | deepseekr1_70b | t=0       |                     0 |                          0 |                     0 |                     0 |                     0 |
# | fireworks | deepseekr1_70b | t=0.8     |                     0 |                          0 |                     0 |                     0 |                     0 |
# | fireworks | llama31        | t=0       |                    70 |                        100 |                   100 |                   100 |                   100 |
# | fireworks | llama31        | t=0.8     |                    70 |                        100 |                   100 |                   100 |                   100 |
# | fireworks | llama32        | t=0       |                    40 |                         95 |                   100 |                   100 |                   100 |
# | fireworks | llama32        | t=0.8     |                    40 |                         95 |                    90 |                    90 |                    85 |
# | fireworks | llama33        | t=0       |                    95 |                        100 |                   100 |                   100 |                    95 |
# | fireworks | llama33        | t=0.8     |                    90 |                        100 |                   100 |                   100 |                   100 |
# | fireworks | qwen25         | t=0       |                   100 |                        100 |                   100 |                   100 |                   100 |
# | fireworks | qwen25         | t=0.8     |                   100 |                        100 |                   100 |                   100 |                   100 |

# %% [markdown]
# Let's combine these results over structures to have more power to determine the hypothesis

# %%
from hypothesis_testing import wilson_score_ci

# %%
results_list = {
    "t=0": structure_support_by_model_t0,
    "t=0.8": structure_support_by_model_t08,
}


def format_ci(p, num_total):
    avg, lb, ub = wilson_score_ci(p * num_total, num_total)
    # return f"{lb*100:.1f}% — {ub*100:.0f}% "
    return f"{avg*100:.0f}%"  # ±{max(avg-lb, ub-avg)*100:.0f}"


df_results = {}
for name, ss_results in results_list.items():
    df_results[name] = {
        tuple(mname.split("_", maxsplit=1)): format_ci(
            pd.Series(
                [
                    ss_results[mname][tname]["valid"]
                    for tname in ss_results[mname].keys()
                ]
            ).mean(),
            80,
        )
        for mname in ss_results.keys()
    }

pd.DataFrame.from_dict(df_results)
# Out:
#                        t=0 t=0.8
# Ollama    llama32      84%   77%
#           nemotron      8%    5%
#           phi3         47%   29%
#           phi4         99%  100%
#           deepseekr1   76%   74%
# fireworks llama31      94%   94%
#           llama32      87%   80%
#           llama33      98%   98%
#           qwen25      100%  100%
# Anthropic Sonnet_35   100%  100%
#           Haiku_35     99%   99%
#           Haiku_3      95%   93%

# %% [markdown]
# Approximate confidence interval

# %%
print(
    tabulate.tabulate(
        pd.DataFrame.from_dict(df_results).reset_index(),
        headers="keys",
        tablefmt="pipe",
        showindex=False,
    )
)
# Out:
# | level_0   | level_1    | t=0   | t=0.8   |
# |:----------|:-----------|:------|:--------|
# | Ollama    | llama32    | 84%   | 77%     |
# | Ollama    | nemotron   | 8%    | 5%      |
# | Ollama    | phi3       | 47%   | 29%     |
# | Ollama    | phi4       | 99%   | 100%    |
# | Ollama    | deepseekr1 | 76%   | 74%     |
# | fireworks | llama31    | 94%   | 94%     |
# | fireworks | llama32    | 87%   | 80%     |
# | fireworks | llama33    | 98%   | 98%     |
# | fireworks | qwen25     | 100%  | 100%    |
# | Anthropic | Sonnet_35  | 100%  | 100%    |
# | Anthropic | Haiku_35   | 99%   | 99%     |
# | Anthropic | Haiku_3    | 95%   | 93%     |

# %% [markdown]
# ### Error analysis

# %% [markdown]
# Extract all error messages & count

# %%
def analyse_errors_from_results(ss_results, method="code", combined=False):
    error_counts = {}
    for mname in ss_results.keys():
        error_counts[mname] = {}
        for tname in ss_results[mname].keys():
            # Count errors by failure code above
            if method == "code":
                error_types = pd.Series(
                    output["error_type"]
                    for output in ss_results[mname][tname]["outputs"]
                )
                error_codes = error_types.value_counts()

                for e_name, e_count in error_codes.items():
                    if combined:
                        error_counts[mname][e_name] = (
                            error_counts[mname].get(e_name, 0) + e_count
                        )
                    else:
                        error_counts[mname][(tname, e_name)] = e_count

            elif method == "parse":
                # Count errors by parsing error message
                errors = (
                    output["error_message"]
                    for output in ss_results[mname][tname]["outputs"]
                )
                for error in errors:
                    if error is None:
                        continue
                    if error.lower().find("opening and ending tag mismatch") >= 0:
                        error_str = "XML tag mismatch"
                    elif error.lower().find("extracterror") >= 0:
                        error_str = "Missing main tags"
                    elif error.lower().find("input should be a valid integer") >= 0:
                        error_str = "Validation error (int)"
                    elif error.lower().find("premature end of data in tag") >= 0:
                        error_str = "Premature end"
                    elif error.lower().find("field required") >= 0:
                        error_str = "Missing field"
                    elif error.lower().find("expected '>'") >= 0:
                        error_str = "Tag malformed"
                    elif (
                        error.lower().find("extra content at the end of the document")
                        >= 0
                    ):
                        error_str = "Tag malformed"
                    elif error.find("BadGatewayError") >= 0:
                        error_str = "Connection error"
                    elif error.find("XMLSyntaxError") >= 0:
                        error_str = "Other syntax error"
                    else:
                        error_str = error

                    if combined:
                        error_counts[mname][error_str] = (
                            error_counts[mname].get(error_str, 0) + 1
                        )

                    else:
                        error_counts[mname][(tname, error_str)] = (
                            error_counts[mname].get((tname, error_str), 0) + 1
                        )

            else:
                raise NameError(f"Method {method} not supported")

    return pd.DataFrame.from_dict(error_counts, orient="index")

# %%
analyse_errors_from_results(
    structure_support_by_model_t08, method="parse", combined=True
).fillna(0).sort_index(axis=1)
# Out:
#                     Missing field  Missing main tags  Other syntax error  \
# Ollama_llama32                4.0                4.0                 0.0
# Ollama_phi3                   7.0               32.0                 4.0
# Ollama_deepseekr1             1.0               11.0                 3.0
# fireworks_llama31             0.0                0.0                 0.0
# fireworks_llama32             1.0                5.0                 1.0
# fireworks_llama33             0.0                0.0                 0.0
# Anthropic_Haiku_3             0.0                0.0                 0.0
# Ollama_nemotron               1.0               94.0                 0.0
# Anthropic_Haiku_35            0.0                0.0                 0.0
#
#                     Premature end  Tag malformed  Validation error (int)  \
# Ollama_llama32                0.0            1.0                    12.0
# Ollama_phi3                   2.0            1.0                     3.0
# Ollama_deepseekr1             0.0            1.0                     1.0
# fireworks_llama31             0.0            0.0                     6.0
# fireworks_llama32             0.0            0.0                    11.0
# fireworks_llama33             0.0            0.0                     2.0
# Anthropic_Haiku_3             0.0            0.0                     7.0
# Ollama_nemotron               0.0            0.0                     0.0
# Anthropic_Haiku_35            0.0            0.0                     0.0
#
#                     XML tag mismatch
# Ollama_llama32                   2.0
# Ollama_phi3                     22.0
# Ollama_deepseekr1                9.0
# fireworks_llama31                0.0
# fireworks_llama32                2.0
# fireworks_llama33                0.0
# Anthropic_Haiku_3                0.0
# Ollama_nemotron                  0.0
# Anthropic_Haiku_35               1.0

# %%
analyse_errors_from_results(
    structure_support_by_model_t0, method="parse", combined=True
).fillna(0).sort_index(axis=1)
# Out:
#                     Missing field  Missing main tags  Other syntax error  \
# Ollama_llama32                1.0                0.0                 0.0
# Ollama_phi3                   6.0               21.0                 0.0
# Ollama_phi4                   0.0                0.0                 0.0
# Ollama_deepseekr1             1.0               18.0                 2.0
# fireworks_llama31             0.0                0.0                 0.0
# fireworks_llama32             0.0                0.0                 0.0
# fireworks_llama33             0.0                1.0                 0.0
# Anthropic_Haiku_35            0.0                0.0                 0.0
# Anthropic_Haiku_3             0.0                0.0                 0.0
# Ollama_nemotron               0.0               92.0                 0.0
#
#                     Tag malformed  Validation error (int)  XML tag mismatch
# Ollama_llama32                0.0                    12.0               3.0
# Ollama_phi3                   1.0                     3.0              22.0
# Ollama_phi4                   0.0                     1.0               0.0
# Ollama_deepseekr1             0.0                     2.0               1.0
# fireworks_llama31             0.0                     6.0               0.0
# fireworks_llama32             0.0                    11.0               2.0
# fireworks_llama33             0.0                     1.0               0.0
# Anthropic_Haiku_35            0.0                     1.0               0.0
# Anthropic_Haiku_3             0.0                     5.0               0.0
# Ollama_nemotron               0.0                     0.0               0.0

# %%
if 1:
    for output in structure_support_by_model_t08["Ollama_phi3"]["ArticleResponse1XML"][
        "outputs"
    ]:
        if output["error_type"] != "ok":
            print(output["error_message"], "\n")
            print(output["raw"].content)
# Out:
# ValidationError, 1 validation error for ArticleResponse1XML
# number
#   [line 4]: Input should be a valid integer, unable to parse string as an integer [type=int_parsing, input_value='3700 million years ago', input_type=str]
#
#  <article>
#     <title>Unveiling Earth's Deep Time Treasures: The Journey of Ancient Life in Fossils</title>
#     <answer>Dinosaurs may top most people’s minds when it comes to ancient life, but the fossil record tells a tale that begins even before their reign. Delving into our planet's past reveals stromatolites as Earth’s oldest known records of life; these lithified bacterial communities date back about 3.7 billion years ago in rocks from Western Australia and South Africa, serving not only as the earliest examples but also as some of its most convincing evidence for early microbial activity. These structures showcase how even the simplest organisms can influence their environment dramatically—in this case creating a habitat that facilitated further lifeforms to develop over time. The intricate layered patterns, formed by cyanobacteria and other tiny creatures trapped in mineral sediments, evidence an extraordinary interaction between Earth's geology and biological evolution long before complex multicellular organisms emerged.</answer>
#     <number>3700 million years ago</number>
#   </article>
# ValidationError, 2 validation errors for ArticleResponse1XML
# answer
#   [line 1]: Field required [type=missing, input_value={'title': "A Celestial De...ed", 'number': '8.5 AU'}, input_type=dict]
# number
#   [line 10]: Input should be a valid integer, unable to parse string as an integer [type=int_parsing, input_value='8.5 AU', input_type=str]
#
#  <article>
#     <title>A Celestial Detour: The Sun's Distance Unveiled</title>
#
#     In a cosmic journey that unfolds daily, our lives are intimately linked with the golden orb at its heart – the sun. It is this radiant sphere of plasma we call home in solar system science—a fascinating subject for us Earthlings to explore and understand! The distance between ourselves here on Earth and the energetic hub above has been a topic that piqued human curiosity throughout history, leading astronomers down an intriguing path. Let's embark together from ancient times with Eratosthenes’ ingenious early measurements using shadows to today where modern technology allows us precise calculations without leaving our planet! The sun is approximately 93 million miles away—a staggering expanse of space that translates into about 8 light minutes across. To grasp this scale, imagine a beam from the Sun reaching Earth in just over five minutes as it blazes through nearly 150 million kilometers or roughly eight and half Astronomical Units (AU) within our solar system's vastness—an incredible reminder of how interconnected we are with cosmic distances.
#
#     The sun’s distance is not constant, a fact that underscores the dynamism inherent in space travel for mankind to grasp fully appreciate its immensity and beauty! In addition, while this enormous glowing sphere appears as our unchanging beacon during daylight hours on Earth's surface each of us experience something unique: The sun rises when we look eastward at 6 AM local time. As the planet rotates towards a new dawn’s promise due to its axis tilt and orbital movement, this celestial dance ensures that for half an entire year (the summer solstice), our star seems never to set!
#
#     This journey from ancient estimations through modern astrophysics reveals not just numbers but a story of humanity’s quest towards greater understanding. The sun's 93 million-mile distance is more than merely an astronomical datum—it serves as testament that curiosity and scientific advancement are intrinsically intertwined in the ongoing exploration of our universe, inspiring generations to look upward with wonder!
#
#     <number>8.5 AU</number>
#   </article>
# ValidationError, 1 validation error for ArticleResponse1XML
# number
#   [line 4]: Input should be a valid integer, unable to parse string as an integer [type=int_parsing, input_value='0.38', input_type=str]
#
#  <article>
#     <title>Mars—Our Cosmic Doppelgänger</title>
#     <answer>Among all planets, Mars bears resemblance to our own when considering surface gravity. The Martian gravitational force pulls objects towards it with about 38% of Earth's strength due to its lower mass and smaller size.</answer>
#     <number>0.38</number>
# </article>
# RuntimeError, ExtractError: End or start strings not found
#
#  Title: "Dwarf Planets - The Outer Reaches' Distant Cousins"
#
# Answer: Eris, Haumea, Makemake, and Ceres share something remarkable in common as they represent the four most significant dwarf planets discovered orbiting our Solar System beyond Neptune. These celestial bodies are classified not just by size but also due to their individuality within this category of 'icy worlds.' Eris is known for being one of the brightest and largest among them, with a diameter about 2,700 kilometers—almost twice that of Pluto. Haumea distinguishes itself through its rapid rotation speed and elongated shape while Makemake captivates scientists due to an unusually red surface indicating complex organic compounds could exist on it or have recently existed there. Ceres, despite being the largest asteroid in our solar system—situated between Mars and Jupiter rather than as a dwarf planet like Eris, Haumea, and Makemake—shows signs of water ice beneath its surface which intrigues scientists pondering about potential past life.
#
# The discovery of these distant relatives in our Solar System is tied to the adventurous journey into space exploration undertaken by Pluto's discoverer, Clyde Tombaugh at Lowell Observatory and his team back in 1930 which led them beyond Neptune’s orbit. Over time with advanced technology like telescopes on powerful observatories or even the Hubble Space Telescope providing us a better look into our cosmic neighborhood, we found these objects to be unique yet intriguing members of our solar system family—frozen worlds that could potentially harbor secrets about life's possibilities beyond Earth. As you can see, while they orbit far from the Sun and have icy surfaces or even rock-ice mixtures, their discovery has expanded human understanding of planetary diversity in space as well as our place within it—a cosmic family portrait that is ever more colorful with each new find!
#
# Their unique characteristics make them fascinating subjects for scientific study and inspire wonder about the universe we are part of. Whether Eris’ brightness, Haumea's unusual spin-orbit relationship or Makemake’s reddish hue hinting at complex organics – these dwarf planets challenge our perceptions as mere ice balls floating in space and invite us to appreciate the diversity of cosmic life.
#
# Number: 4
# XMLSyntaxError, Opening and ending tag mismatch: article line 1 and answer, line 12, column 322 (<string>, line 12)
#
#  <article>
#     <title>Unlocking Life's Tiniest Mysteries - The Cell as Our Smallest Unit</title>
#
#     <answer>At its most fundamental level, all living organisms are composed of a marvelous microscopic entity called the cell. Cells come in vastly different shapes and sizes but share common features that mark them as vital units of life; these include an encapsulating membrane distinguishing their internal contents from their surrner environment, cytoplasm filled with various organelles performing specific functions for survival, DNA holding genetic instructions essential to reproduction, growth, maintenance, and functioning.
#
#     <number>1</number> The term 'cell' was first coined by the English scientist Robert Hooke in 1665 when he described a thin slice of cork under a microscope as resembling small rooms or "cells" from a monastery, and since then its role has been increasingly unraveled through decades of research. From tiny bacteria to complex multicellular entities like humans, the cell is life's basic building block - indispensable for all known forms of existence on Earth.</answer>
#
#     <number>2</number> While cells vary across species, from unicellular organisms such as amoebae to complex eukaryotic structures like human neurons in the brain, each is a self-contained world teeming with intricate mechanics and pathways vital for life.
#
#     <story><p>For instance, consider an ordinary day at Linda's home where her pet cat Whiskers had suddenly become lethargic - this prompted concern leading to the discovery of a flea infestation.</p></story>
#
#     <number>3</number> Microscopic examination of skin scrapings from poor Whiskers revealed not only parasites but also an army of white blood cells, as his body battled intruders - showcasing the immune response in action. Each cell plays its part against invaders and maintains homeostasis daily without fail.</answer>
#
#     <story><p>Dr. Patel's lab where research on stem cells illuminates how specialized tissues develop from a single, pluripotent source highlighted the miracine nature of our very own biology - demonstrating regenerative medicine’s potential for treating diseases.</p></story>
#
#     <number>4</number> Delving into evolutionary science reveals that even among microorganisms, unicellular blue-green algae or cyanobacteria thrive in diverse environments by adapting their cells to withstand extremes - a testament to the robustness of life at its smallest scales.
#
#     <number>5</number> The journey through time from single celled organisms billions years ago, as evidenced by fossils like stromatolites and microfossils in ancient rocks suggests cells have been shaping our world since the dawn of existence - evolving towards complexity. Today’s research unraveling cellular mysteries promises to revolutionize medicine with therapies targeted at correcting genetic anomalies within these fundamental units that define life itself.</answer>
#
#     <number>6</number></story> In essence, the humble cell serves as our most basic unit of biology. It’s where existence begins and persists in its myriad forms across kingdoms – a microscopic marvel with vast implications for health science, evolutionary theory, ecology, and beyond.</answer>
#
#     <number>7</number></story> Understanding cells at the molecular level unveils life’s inner workings - fostering hope in disease cures we once deemed impossible. Thus holds true: when it comes to exploring biology's depth, even its smallest components offer profound insights.</answer>
#
#     <number>8</number></story> So next time you marvel at life’s diversity from the vast savannah down to your pet Whiskers purring on your lap - remember that all these forms of existence hinge upon countless cells working in unison, each holding a world within itself – truly remarkable!</answer></article>
# XMLSyntaxError, xmlParseEntityRef: no name, line 4, column 605 (<string>, line 4)
#
#  <article>
#     <title>Demystifying Dreams: Unveiling The Science Behind Our Nightly Visions</title>
#
#     <answer>Have you ever found yourself lost in a sea of thoughts and images during slumber, wondering about the purpose behind our dreamscapes? You're not alone. Throughout history, humans have been curious why we experience such vivid daydreams each night. Dreaming is an integral part of human life that intertwines with various aspects like memory consolidation, emotional processing, and creativity enhancement. Scientists suggest dreams are the mind's way to sort through experiences by replaying them in symbolic scenarios allowing for problem-solving or coping mechanisms during sleep (Foulkes & Bootzin, 2018). Intriguingly, recent studies have linked REM sleep with memory formation and emotional regulation suggesting dreams assist us processing daily events. For example, a stressor can make it difficult to forget the event; thus, in dreams, we might repeatedly revisit this scenario which could lead to an 'emotional reset' (Horne & Zepf, 2017). The brain is incredibly busy during sleep as well - nearly half of our mental activity takes place here. Dreaming may be a byproduct of the mind doing essential housekeeping while we rest! Interestingly, dreams might have evolutionary roots too: it's believed that primordial creatures used dream-like states to rehearse survival instincts (Siegel & van der Knaap, 2018). So next time you wake up drenched in sweat from a nightmare or bathed in the warm glow of fond memories, know that your mind's weaving narratives is more than mere fantasy—it’s helping shape who you are.</answer>
#     <number>42</number>
#   </article>
# RuntimeError, ExtractError: End or start strings not found
#
#  Title: "Unraveling the Speed of Light - Illuminating an Invisible Marvel"
#
# Answer: The speed of light, a constant that has fascinated scientists and philosophers for centuries, stands as one of nature's most enigmatic constants. This elusive figure represents not just how fast something can travel through space but also symbolizes the ultimate barrier to our understanding of reality itself. Measured at approximately 299,792 kilometers per second or roughly 186,282 miles per hour in a vacuum—a speed that has prompted countless experiments and theories stretching back to Galileo's early observations with the telescope where he witnessed light from far-off stars. Light travels at its fastest possible rate yet remains invisible unless it is interacting with something, like our eyes or a camera lens focusing on photons captured by Isaac Newton in his prism experiments which unveiled that white sunlight was composed of multiple colors refracted distinctly.
#
# In 1675, Christiaan Huygens delved into light's velocity and its constant nature when he proposed a wave theory to explain why shadows are diffused edges rather than sharp points—a concept now understood as the behavior of waves spreading out from their source instead of traveling in straight lines like particles.
#
# Fast-forward to 1848, James Clerk Maxwell's equations unified electricity and magnetism theories while simultaneously revealing that light is an electromagnetic wave propagating at the speed 'c', later confirmed experimentally by Auguste de la Rue using a rotating magnetic field. Yet it wasn't until 1859, with Albert A. Michelson-Morley’s ingenious method of interferometry and subsequent null results that light was firmly established as being invariant in its speed irrespective of the observer or experimental setup—a revelation shattering preconceived notions about space's ether medium where waves were thought to travel.
#
# In essence, 'c', with a value roughly one million times faster than sound and nearly three hundred million miles per hour quicker than human-powered transport on Earth’s surface—is the maximum speed at which any information or physical object can traverse in our universe's standard space and time. Light sets this universal limit; nothing, not even itself (as demonstrated by Einstein), traveling faster cannot break its ceiling set forth centuries ago when Maxwell first postulated it as a constant of nature intertwined with the very fabric of spacetime where gravity bends reality around massive objects creating 'gravitational lenses'.
#
# So why does light's speed remain unattainable, and what implications arise from this cosmic speed limit? These questions propelled Einstein to develop his Special Relativity theory in 1905 which fundamentally altered our understanding of time and space. According to relativity principles, as an object approaches 'c', time dilates (slows down), effectively reaching a standstill at the moment when light’s speed is achieved—a thought-provoking consequence known as temporal dilation where minutes become mere seconds for those onboard nearing this cosmic limit.
#
# Furthermore, no matter how we perceive it or measure it, nothing can outpace 'c', cemented in physics' laws and the foundation of causality—effects cannot precede causes as they would if information traveled instantaneously at speeds beyond this boundary. Even so advanced technology like modern fiber optics communicates with delays due to light traveling mere fractions per second compared to electronic signals, a stark contrast between potentiality and physical reality despite the speed limit's seemingly universal rulefulness in our universe’s cosmic playbook.
#
# Intriguingly then, understanding 'c', human ingenuity constantly tests its limits whilst abiding by nature’s unyielding decree—an invisible marvel dictating movement at an impossible pace that remains a central pillar of modern physics and cosmology while also serving as our cosmic speed limit.
#
# [number: 3]
# ValidationError, 1 validation error for ArticleResponse1XML
# number
#   [line 1]: Field required [type=missing, input_value={'title': '"Magnetic Marv...s wonders.\n    \n    "}, input_type=dict]
#
#  <article>
#     <title>"Magnetic Marvels Unveiled"</title>
#
#     <answer>Once upon a time, in the realm of science where invisible forces rule and marvelous mysteries abound, there existed tiny actors that defied ordinary understanding - magnets. These enigmatic entities possess an inherent property called 'magnetism.' Discovered as early as ancient times by curious souls who noticed certain stones drew iron towards them naturally, scientists later unveiled the secrets of how these magnetic marvels operate through a fascinating dance of atoms. Atoms within magnets align in uniform direction creating distinct areas called 'poles,' one with an end known as north and south - similar to our Earth's North and South Poles, yet inside tiny chunks of matter!
#
#     When you see two opposing poles (north and south) come together, they attract each other in a magnetic embrace. Conversely, like charges repel with an invisible forceful push - north finds solace only near its kind due to the same property called 'electron spin.' This dance isn't just theoretical but observable through everyday items; hold two magnets close and experience this attraction or repulsion first-hand.
#
#     The secret behind their performance lies in domains, microscopic regions of aligned atomic spins that collectively generate a measurable force at the macroscale - your typical fridge door remains steadfastly attached due to its magnetic personality against Earth's own field! Aligning these tiny actors into one directional order involves heating and cooling or applying pressure.
#
#     Despite their domesticated appearance, they still follow a cosmic tale of attraction - not only with each other but also towards the mysterious forces that power our planet itself in phenomena like Earth's magnetic field! This invisible choreography is what makes magnets work: an intricate ballet guided by laws uncovered since their discovery, inviting us to explore further into nature’s wonders.
#
#     <number>42</number>
#   </answer>
# </article>
# ValidationError, 2 validation errors for ArticleResponse1XML
# answer
#   [line 1]: Field required [type=missing, input_value={'title': "Unlocking Life...ribonucleic Acid (DNA)"}, input_type=dict]
# number
#   [line 1]: Field required [type=missing, input_value={'title': "Unlocking Life...ribonucleic Acid (DNA)"}, input_type=dict]
#
#  <article>
#     <title>Unlocking Life's Code: The Purpose and Power of Deoxyribonucleic Acid (DNA)</title>
#   </article>
#
# <answer>
#      Deoxyribonucleic acid, or DNA as it is commonly known, serves a monumental role in all living organisms. It can be likened to the blueprint that holds our genetic instructions - essentially guiding how we look and function at every level of life. Discovered over 75 years ago by James Watson and Francis Crick, DNA has since unraveled secrets leading us toward understanding many diseases like cancer in ways previously unfathomable to the scientific community. A staggering one billion base pairs encased within each human cell's nucleus direct every aspect of our existence from eye color to how we respond when faced with pathogens, and even aspects about aging itself! DNA provides instructions for synthesizing proteins—our body’s workhorses that perform almost all biological functions. Through replication processes, it ensures the continuity of life across generations. The human genome has provided insight into evolutionary origins with fascinating tales linking distant species - like bacteria and humans! Despite its microscopic size, DNA holds stories as vast as our history itself which scientists continue to unravel today, inspiring awe in the complexity of life on Earth. It's not just about us but also offers hope for genetic therapies addressing previously intractable conditions and further understanding ourselves - both its vulnerabilities and strengths. The study of DNA is continuously expanding our comprehension towards unraveling mysteries embedded in the very fabric of life, fostering advancements benefiting human health and survival as we understand it better!
#   </answer>
#     <number>75</number>
# RuntimeError, ExtractError: End or start strings not found
#
#  Title: Unveiling Vaccine Magic - How Do They Work and Why We Need Them?
#
# Answer: Imagine a world where tiny warriors called 'vaccines' arm your body against invisible enemies like viruses, saving countless lives every day. This is the marvel of immunology! Let me explain how they work using our heroes - Edward Jenner and Louis Pasteur in 1796 to Jonas Salk in 1955.
# Vaccines are made from weakened or killed pathogens, like viruses causing illnesses such as polio, measles, flu etc., which stimulate our immune system without making us sick. They train white blood cells called 'T-cells' and B-lymphocytes to recognize these invaders - think of them as bodyguards for the first line defense against real threats!
# Jenner discovered smallpox vaccine using a harmless cow virus, teaching our immune system about its enemy. Today’s mRNA and recombinant technologies refined this concept without using live pathogens but still teach us their 'identity.' These tiny warriors train the body to produce antibodies tailored specifically for each invader they represent - like a soldier learning how to recognize an adversary's face!
# When these trained cells encounter real viruses, our immune system fights back robustly and quickly. It’s science in action – but it requires time & safety checks which is why vaccines take months for development with the most recent mRNA types like COVID-19 taking weeks to produce!
# Their creation also underscores a commitment towards global health equity - from WHO's polio campaign, eradicating this scourge in some regions or efforts ensuring essential vaccines reach even those farthest corners of the globe. So remember: these tiny warriors play an enormous role not just within our bodies but for a safer world!
# So next time you receive your jab - appreciate them as vital tools that empower us to protect ourselves and keep the battle against infectious diseases in control, ensuring healthier tomorrows. They are more than medical marvels; they’re champions of global wellbeing too!

# %% [markdown]
# ### Load previous results

# %% [markdown]
# First try all models file

# %%
if 0:
    import pickle

    with open(
        file=f"exp{experiment_num}_all_models_{experiment_date}.pkl", mode="rb"
    ) as f:
        data = pickle.load(f)

    # Inject into toplevel namespace
    namespace = locals()
    for key, value in data["models"].items():
        if key not in namespace:
            print(f"Loaded {key}")
            namespace[key] = value

# %%
if 0:
    import pickle

    # Load individual models
    output_idents = ["sys", "alt"]

    namespace = locals()
    for ident in output_idents:
        with open(
            file=f"exp{experiment_num}_xml_output_{ident}_{experiment_date}.pkl",
            mode="rb",
        ) as f:
            data = pickle.load(f)

        key = f"structure_support_by_model_{ident}"
        if key not in namespace:
            print(f"Loaded {key}")
            namespace[key] = data["structure_support_by_model"]

# %% [markdown]
# ## Hypothesis testing

# %% [markdown]
# Hypothesis:
#
# - H0: Different temperatures lead to different rates of XML schema conformance
# - H1: The proportions of conformance are the same

# %%
# Bonferroni correction
model_list = structure_support_by_model_t0.keys()
n_tests = len(model_list)
alpha = 0.05  # / n_tests

for model in model_list:

    contingency_table = {}
    for name, ss_results in results_list.items():
        num_true = 0
        num_total = 0
        for tname in ss_results[model].keys():
            num_true += ss_results[model][tname]["valid"] * len(questions)
            num_total += len(questions)

        contingency_table[name] = {"Passed": num_true, "Failed": num_total - num_true}

    ct = pd.DataFrame.from_dict(contingency_table, orient="index")

    # Ensure ordering to match hypotheses
    # Columns are experiments
    # Rows are outcomes
    # Column marginals are constant
    ct_n = ct[["Passed", "Failed"]].to_numpy().T

    print(f"\n{model}")
    print(sf := stats.fisher_exact(ct_n, alternative="greater"))
    print(sb := stats.barnard_exact(ct_n, alternative="greater"))
    if sb.pvalue < alpha:
        print(f"Hypothesis test passed: {sb.pvalue:.3g} < {alpha:.3g}")
# Out:
# Ollama_llama32
# SignificanceResult(statistic=np.float64(1.5681818181818181), pvalue=np.float64(0.14208888177506213))
# BarnardExactResult(statistic=np.float64(1.249303038696861), pvalue=np.float64(0.12258240508091653))
#
# Ollama_nemotron
# SignificanceResult(statistic=np.float64(1.6521739130434783), pvalue=np.float64(0.28396268931110596))
# BarnardExactResult(statistic=np.float64(0.8604859293176627), pvalue=np.float64(0.2645506113622348))
#
# Ollama_phi3
# SignificanceResult(statistic=np.float64(2.171112556929083), pvalue=np.float64(0.006510361002595765))
# BarnardExactResult(statistic=np.float64(2.6222244603662923), pvalue=np.float64(0.004495770764296521))
# Hypothesis test passed: 0.0045 < 0.05
#
# Ollama_phi4
# SignificanceResult(statistic=np.float64(0.0), pvalue=np.float64(1.0))
# BarnardExactResult(statistic=np.float64(-1.0025094142341715), pvalue=np.float64(1.0))
#
# Ollama_deepseekr1
# SignificanceResult(statistic=np.float64(1.1126126126126126), pvalue=np.float64(0.43520490196213557))
# BarnardExactResult(statistic=np.float64(0.3265986323710907), pvalue=np.float64(0.40962257002931984))
#
# fireworks_llama31
# SignificanceResult(statistic=np.float64(1.0), pvalue=np.float64(0.6163277826786353))
# BarnardExactResult(statistic=np.float64(0.0), pvalue=np.float64(1.0))
#
# fireworks_llama32
# SignificanceResult(statistic=np.float64(1.6730769230769231), pvalue=np.float64(0.12640858534972246))
# BarnardExactResult(statistic=np.float64(1.333514776259032), pvalue=np.float64(0.12226549369413986))
#
# fireworks_llama33
# SignificanceResult(statistic=np.float64(1.0), pvalue=np.float64(0.6893987705022575))
# BarnardExactResult(statistic=np.float64(0.0), pvalue=np.float64(1.0))
#
# fireworks_qwen25
# SignificanceResult(statistic=nan, pvalue=1.0)
# BarnardExactResult(statistic=np.float64(0.0), pvalue=np.float64(1.0))
#
# Anthropic_Sonnet_35
# SignificanceResult(statistic=nan, pvalue=1.0)
# BarnardExactResult(statistic=np.float64(0.0), pvalue=np.float64(1.0))
#
# Anthropic_Haiku_35
# SignificanceResult(statistic=np.float64(1.0), pvalue=np.float64(0.7512562814070352))
# BarnardExactResult(statistic=np.float64(0.0), pvalue=np.float64(1.0))
#
# Anthropic_Haiku_3
# SignificanceResult(statistic=np.float64(1.4301075268817205), pvalue=np.float64(0.3836722173213647))
# BarnardExactResult(statistic=np.float64(0.5954913341754107), pvalue=np.float64(0.29631226239677527))

# %% [markdown]
# ### Combined levels: does temperature change the conformance to XML ?

# %%
from scipy import stats

model_list = structure_support_by_model_t0.keys()

contingency_table = {}
for model in model_list:
    for name, ss_results in results_list.items():
        for tname in ss_results[model].keys():
            contingency_table[name] = contingency_table.get(
                name, {"Passed": 0, "Failed": 0}
            )
            num_true = ss_results[model][tname]["valid"] * len(questions)
            num_total = len(questions)

            contingency_table[name]["Passed"] += num_true
            contingency_table[name]["Failed"] += num_total - num_true

ct = pd.DataFrame.from_dict(contingency_table, orient="index")

# %% [markdown]
# From the contingency table alone we see that there is some differnece between the results for temperatures

# %%
ct
# Out:
#        Passed  Failed
# t=0     987.0   213.0
# t=0.8   949.0   251.0

# %%
# Chi-Squared Test for multiple groups
res = stats.chi2_contingency(ct)
print(f"\nChi-Squared Test:\nStatistic={res.statistic:.4f}, p={res.pvalue:.4g}")
# Out:
# Chi-Squared Test:
# Statistic=3.6576, p=0.05582

# %%
# Chi-Squared Test for multiple groups
res = stats.barnard_exact(ct)
print(f"Barnard exact test:\nStatistic={res.statistic:.4f}, p={res.pvalue:.4g}")
# Out:
# Barnard exact test:
# Statistic=1.9642, p=0.04995
