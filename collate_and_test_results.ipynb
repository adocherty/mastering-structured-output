# %%
import pickle
import pandas as pd
import tabulate
from pydantic_structure_definitions import *
from experiment_xml import (
    load_single_experiment,
    load_experiment_summary,
    analyse_xml_experiment,
)
from analyse_experiment import (
    wilson_score_ci,
    results_to_table,
    compare_m_experiments,
    format_ci_pm,
    format_diag,
    results_to_table,
)

# %%
# %load_ext autoreload
# %autoreload 1

# %%
# %cd "Experiment Outputs"
# Out:
# /home/andrew/Code/mastering-structured-output/Experiment Outputs

# %% [markdown]
# ### Experiment 6
#
# Hypothesis: Higher temperature worsens the conformance to XML schema

# %%
# Temperature 0 - sys, user, parsers experiment
# Includes Anthropic models
results_temp_sup = {}
experiment_date = "28-02-25"
experiment_num = "6"
metadata6 = load_experiment_summary(experiment_num, experiment_date, results_temp_sup)
# Out:
# Loaded structure_support_by_model_sys
# Loaded structure_support_by_model_user
# Loaded structure_support_by_model_parsers

# %%
print("\n".join(metadata6.get("hypotheses")))
# Out:
# 1. Do small models including Phi3 and Nemotron improve their output by providing more explicit instructions on the format at the end of the prompt?
# 2. Do output parsers perform worse for all models?
# 3. What is the performance of the models using user parsers?

# %%
temp_sup_table_1 = results_to_table(
    results_temp_sup, combine_levels=True, cell_format=format_ci_pm
)
temp_sup_table_1
# Out:
#                           sys     user  parsers
# Anthropic Haiku_3      95% ±6   95% ±6  52% ±11
#           Haiku_35     99% ±4  100% ±4  50% ±11
#           Sonnet_35   100% ±4  100% ±4  71% ±11
# Ollama    deepseekr1   76% ±9   81% ±9    9% ±8
#           llama32      84% ±8   87% ±8    5% ±7
#           nemotron      8% ±7  50% ±10    0% ±5
#           phi3        47% ±10  61% ±10    5% ±7
#           phi4         99% ±4   99% ±4  61% ±11
# fireworks llama31      95% ±6   95% ±6  42% ±11
#           llama32      87% ±8   90% ±7    0% ±5
#           llama33     100% ±4   98% ±5  31% ±11
#           qwen25      100% ±4  100% ±4  75% ±10

# %% [markdown]
# Reanalyse using different search modes

# %%
classes = generate_xml_classes(search_mode="unordered")

structured_formats_xml = [
    dict(pydantic=schema, format_instructions=None)
    for name, schema in classes.items()
    if name.startswith("ArticleResponse")
]
results_temp_sup_relaxed = {
    ex_name: analyse_xml_experiment(
        results_temp_sup[ex_name],
        structured_formats_xml,
        verbose=False,
    )
    for ex_name in results_temp_sup
}

# %%
temp_sup_table_2 = results_to_table(
    {
        "strict": results_temp_sup["structure_support_by_model_parsers"],
        "unordered": results_temp_sup_relaxed["structure_support_by_model_parsers"],
    },
    combine_levels=True,
    cell_format=format_ci_pm,
    markdown=True,
)
print(temp_sup_table_2)
# Out:
# | level_0   | level_1    | strict   | unordered   |
# |:----------|:-----------|:---------|:------------|
# | Anthropic | Haiku_3    | 52% ±11  | 54% ±11     |
# | Anthropic | Haiku_35   | 50% ±11  | 75% ±10     |
# | Anthropic | Sonnet_35  | 71% ±11  | 71% ±11     |
# | Ollama    | deepseekr1 | 9% ±8    | 9% ±8       |
# | Ollama    | llama32    | 5% ±7    | 20% ±10     |
# | Ollama    | nemotron   | 0% ±5    | 0% ±5       |
# | Ollama    | phi3       | 5% ±7    | 6% ±8       |
# | Ollama    | phi4       | 61% ±11  | 69% ±11     |
# | fireworks | llama31    | 42% ±11  | 57% ±11     |
# | fireworks | llama32    | 0% ±5    | 0% ±5       |
# | fireworks | llama33    | 31% ±11  | 31% ±11     |
# | fireworks | qwen25     | 75% ±10  | 75% ±10     |

# %%
temp_sup_table_1 = results_to_table(
    results_temp_sup,
    combine_levels=False,
    cell_format=format_ci_pm,
    subset=["structure_support_by_model_parsers"],
)
temp_sup_table_2 = results_to_table(
    results_temp_sup_relaxed,
    combine_levels=False,
    cell_format=format_ci_pm,
    subset=["structure_support_by_model_parsers"],
    compare_to=temp_sup_table_1,
    markdown=True,
)
print(temp_sup_table_2)
# Out:
# | level_0   | level_1    | ArticleResponse1nointXML   | ArticleResponse2XML   | ArticleResponse3XML   | ArticleResponse4XML   |
# |:----------|:-----------|:---------------------------|:----------------------|:----------------------|:----------------------|
# | Anthropic | Haiku_3    | **30% ±22**                | 100% ±16              | 85% ±21               | 0% ±16                |
# | Anthropic | Haiku_35   | **100% ±16**               | 100% ±16              | 100% ±16              | 0% ±16                |
# | Anthropic | Sonnet_35  | 100% ±16                   | 100% ±16              | 85% ±21               | 0% ±16                |
# | Ollama    | deepseekr1 | 10% ±20                    | 25% ±22               | 0% ±16                | 0% ±16                |
# | Ollama    | llama32    | **40% ±21**                | **40% ±21**           | 0% ±16                | 0% ±16                |
# | Ollama    | nemotron   | 0% ±16                     | 0% ±16                | 0% ±16                | 0% ±16                |
# | Ollama    | phi3       | 5% ±19                     | **20% ±22**           | 0% ±16                | 0% ±16                |
# | Ollama    | phi4       | **100% ±16**               | 100% ±16              | 75% ±22               | 0% ±16                |
# | fireworks | llama31    | 30% ±22                    | **100% ±16**          | **100% ±16**          | 0% ±16                |
# | fireworks | llama32    | 0% ±16                     | 0% ±16                | 0% ±16                | 0% ±16                |
# | fireworks | llama33    | 20% ±22                    | 100% ±16              | 5% ±19                | 0% ±16                |
# | fireworks | qwen25     | 100% ±16                   | 100% ±16              | 100% ±16              | 0% ±16                |

# %% [markdown]
# ### Experiment 4
#
# Hypothesis: Higher temperature worsens the conformance to XML schema

# %%
# Temperature 0/0.8 experiment
# Includes Anthropic models
results_temp = {}
experiment_date = "25-02-25"
experiment_num = "4"
metadata4 = load_experiment_summary(experiment_num, experiment_date, results_temp)
# Out:
# Loaded structure_support_by_model_t0
# Loaded structure_support_by_model_t08

# %%
compare_m_experiments(results_temp)
# Out:
#                           Fisher exact  Barnard exact  Outcome
# Ollama    phi3                0.006510       0.004496    False
# fireworks llama31             0.616328       1.000000    False
# Anthropic Haiku_3             0.383672       0.296312    False
# Ollama    nemotron            0.283963       0.264551    False
# Anthropic Sonnet_35           1.000000       1.000000    False
# fireworks llama32             0.126409       0.122265    False
#           llama33             0.689399       1.000000    False
#           deepseekr1_70b      1.000000       1.000000    False
# Anthropic Haiku_35            0.751256       1.000000    False
# Ollama    llama32             0.142089       0.122582    False
#           phi4                1.000000       1.000000    False
# fireworks qwen25              1.000000       1.000000    False
# Ollama    deepseekr1          0.435205       0.409623    False

# %%
temp_table_1 = results_to_table(
    results_temp, combine_levels=True, cell_format=format_ci_pm
)
temp_table_1
# Out:
#                                t0      t08
# Anthropic Haiku_3          95% ±6   93% ±7
#           Haiku_35         99% ±4   99% ±4
#           Sonnet_35       100% ±4  100% ±4
# Ollama    deepseekr1       76% ±9   74% ±9
#           llama32          84% ±8   77% ±9
#           nemotron          8% ±7    5% ±6
#           phi3            47% ±10  29% ±10
#           phi4             99% ±4  100% ±4
# fireworks deepseekr1_70b    0% ±4    0% ±4
#           llama31          94% ±6   94% ±6
#           llama32          87% ±8   80% ±9
#           llama33          98% ±5   98% ±5
#           qwen25          100% ±4  100% ±4

# %% [markdown]
# Reanalyse using different search modes

# %%
classes = generate_xml_classes(search_mode="unordered")

structured_formats_xml = [
    dict(pydantic=schema, format_instructions=None)
    for name, schema in classes.items()
    if name.startswith("ArticleResponse")
]
results_temp_relaxed = {
    ex_name: analyse_xml_experiment(
        results_temp[ex_name],
        structured_formats_xml,
        verbose=False,
    )
    for ex_name in results_temp
}

# %%
temp_table_2 = results_to_table(
    results_temp_relaxed,
    combine_levels=True,
    cell_format=format_ci_pm,
    compare_to=temp_table_1,
)
temp_table_2
# Out:
# <style type="text/css">
# #T_9a775_row4_col1, #T_9a775_row6_col1 {
#   color: red;
#   font-weight: bold;
# }
# </style>
# <table id="T_9a775">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9a775_level0_col0" class="col_heading level0 col0" >t0</th>
#       <th id="T_9a775_level0_col1" class="col_heading level0 col1" >t08</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9a775_level0_row0" class="row_heading level0 row0" rowspan="3">Anthropic</th>
#       <th id="T_9a775_level1_row0" class="row_heading level1 row0" >Haiku_3</th>
#       <td id="T_9a775_row0_col0" class="data row0 col0" >95% ±6</td>
#       <td id="T_9a775_row0_col1" class="data row0 col1" >93% ±7</td>
#     </tr>
#     <tr>
#       <th id="T_9a775_level1_row1" class="row_heading level1 row1" >Haiku_35</th>
#       <td id="T_9a775_row1_col0" class="data row1 col0" >99% ±4</td>
#       <td id="T_9a775_row1_col1" class="data row1 col1" >99% ±4</td>
#     </tr>
#     <tr>
#       <th id="T_9a775_level1_row2" class="row_heading level1 row2" >Sonnet_35</th>
#       <td id="T_9a775_row2_col0" class="data row2 col0" >100% ±4</td>
#       <td id="T_9a775_row2_col1" class="data row2 col1" >100% ±4</td>
#     </tr>
#     <tr>
#       <th id="T_9a775_level0_row3" class="row_heading level0 row3" rowspan="5">Ollama</th>
#       <th id="T_9a775_level1_row3" class="row_heading level1 row3" >deepseekr1</th>
#       <td id="T_9a775_row3_col0" class="data row3 col0" >76% ±9</td>
#       <td id="T_9a775_row3_col1" class="data row3 col1" >74% ±9</td>
#     </tr>
#     <tr>
#       <th id="T_9a775_level1_row4" class="row_heading level1 row4" >llama32</th>
#       <td id="T_9a775_row4_col0" class="data row4 col0" >84% ±8</td>
#       <td id="T_9a775_row4_col1" class="data row4 col1" >78% ±9</td>
#     </tr>
#     <tr>
#       <th id="T_9a775_level1_row5" class="row_heading level1 row5" >nemotron</th>
#       <td id="T_9a775_row5_col0" class="data row5 col0" >8% ±7</td>
#       <td id="T_9a775_row5_col1" class="data row5 col1" >5% ±6</td>
#     </tr>
#     <tr>
#       <th id="T_9a775_level1_row6" class="row_heading level1 row6" >phi3</th>
#       <td id="T_9a775_row6_col0" class="data row6 col0" >47% ±10</td>
#       <td id="T_9a775_row6_col1" class="data row6 col1" >30% ±10</td>
#     </tr>
#     <tr>
#       <th id="T_9a775_level1_row7" class="row_heading level1 row7" >phi4</th>
#       <td id="T_9a775_row7_col0" class="data row7 col0" >99% ±4</td>
#       <td id="T_9a775_row7_col1" class="data row7 col1" >100% ±4</td>
#     </tr>
#     <tr>
#       <th id="T_9a775_level0_row8" class="row_heading level0 row8" rowspan="5">fireworks</th>
#       <th id="T_9a775_level1_row8" class="row_heading level1 row8" >deepseekr1_70b</th>
#       <td id="T_9a775_row8_col0" class="data row8 col0" >0% ±4</td>
#       <td id="T_9a775_row8_col1" class="data row8 col1" >0% ±4</td>
#     </tr>
#     <tr>
#       <th id="T_9a775_level1_row9" class="row_heading level1 row9" >llama31</th>
#       <td id="T_9a775_row9_col0" class="data row9 col0" >94% ±6</td>
#       <td id="T_9a775_row9_col1" class="data row9 col1" >94% ±6</td>
#     </tr>
#     <tr>
#       <th id="T_9a775_level1_row10" class="row_heading level1 row10" >llama32</th>
#       <td id="T_9a775_row10_col0" class="data row10 col0" >87% ±8</td>
#       <td id="T_9a775_row10_col1" class="data row10 col1" >80% ±9</td>
#     </tr>
#     <tr>
#       <th id="T_9a775_level1_row11" class="row_heading level1 row11" >llama33</th>
#       <td id="T_9a775_row11_col0" class="data row11 col0" >98% ±5</td>
#       <td id="T_9a775_row11_col1" class="data row11 col1" >98% ±5</td>
#     </tr>
#     <tr>
#       <th id="T_9a775_level1_row12" class="row_heading level1 row12" >qwen25</th>
#       <td id="T_9a775_row12_col0" class="data row12 col0" >100% ±4</td>
#       <td id="T_9a775_row12_col1" class="data row12 col1" >100% ±4</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Experiment 3
#
# Hypothesis: Encapsulating lists improves the conformance to XML schema

# %%
# Testing list prompting
results_list = {}
experiment_date = "24-02-25"
experiment_num = "3"
metadata3 = load_experiment_summary(experiment_num, experiment_date, results_list)
# Out:
# Loaded structure_support_by_model_sys
# Loaded structure_support_by_model_alt

# %%
list_table_1 = results_to_table(
    results_list, combine_levels=True, cell_format=format_ci_pm
)
list_table_1
# Out:
#                           sys      alt
# Anthropic Haiku_3      94% ±8   95% ±7
#           Haiku_35    100% ±5  100% ±5
#           Sonnet_35   100% ±5  100% ±5
# Ollama    deepseekr1  65% ±11  61% ±11
#           llama32     61% ±11  74% ±11
#           nemotron      5% ±7    1% ±5
#           phi3        18% ±10   12% ±9
#           phi4         99% ±5  100% ±5
# fireworks llama31      90% ±9   85% ±9
#           llama32     79% ±10  80% ±10
#           llama33     100% ±5   98% ±6
#           qwen25      100% ±5  100% ±5

# %% [markdown]
# Reanalyse using different search modes

# %%
classes = generate_xml_classes(search_mode="unordered")
structured_formats_xml = [
    dict(pydantic=schema, format_instructions=None)
    for name, schema in classes.items()
    if name.startswith("ArticleResponse")
]
results_list_relaxed = {
    ex_name: analyse_xml_experiment(
        ex_results,
        structured_formats_xml,
        verbose=False,
    )
    for ex_name, ex_results in results_list.items()
}

# %%
results_to_table(
    results_list_relaxed,
    combine_levels=True,
    cell_format=format_ci_pm,
    compare_to=list_table_1,
)
# Out:
# <style type="text/css">
# #T_e8011_row4_col0, #T_e8011_row4_col1, #T_e8011_row6_col0 {
#   color: red;
#   font-weight: bold;
# }
# </style>
# <table id="T_e8011">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e8011_level0_col0" class="col_heading level0 col0" >sys</th>
#       <th id="T_e8011_level0_col1" class="col_heading level0 col1" >alt</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e8011_level0_row0" class="row_heading level0 row0" rowspan="3">Anthropic</th>
#       <th id="T_e8011_level1_row0" class="row_heading level1 row0" >Haiku_3</th>
#       <td id="T_e8011_row0_col0" class="data row0 col0" >94% ±8</td>
#       <td id="T_e8011_row0_col1" class="data row0 col1" >95% ±7</td>
#     </tr>
#     <tr>
#       <th id="T_e8011_level1_row1" class="row_heading level1 row1" >Haiku_35</th>
#       <td id="T_e8011_row1_col0" class="data row1 col0" >100% ±5</td>
#       <td id="T_e8011_row1_col1" class="data row1 col1" >100% ±5</td>
#     </tr>
#     <tr>
#       <th id="T_e8011_level1_row2" class="row_heading level1 row2" >Sonnet_35</th>
#       <td id="T_e8011_row2_col0" class="data row2 col0" >100% ±5</td>
#       <td id="T_e8011_row2_col1" class="data row2 col1" >100% ±5</td>
#     </tr>
#     <tr>
#       <th id="T_e8011_level0_row3" class="row_heading level0 row3" rowspan="5">Ollama</th>
#       <th id="T_e8011_level1_row3" class="row_heading level1 row3" >deepseekr1</th>
#       <td id="T_e8011_row3_col0" class="data row3 col0" >65% ±11</td>
#       <td id="T_e8011_row3_col1" class="data row3 col1" >61% ±11</td>
#     </tr>
#     <tr>
#       <th id="T_e8011_level1_row4" class="row_heading level1 row4" >llama32</th>
#       <td id="T_e8011_row4_col0" class="data row4 col0" >65% ±11</td>
#       <td id="T_e8011_row4_col1" class="data row4 col1" >78% ±10</td>
#     </tr>
#     <tr>
#       <th id="T_e8011_level1_row5" class="row_heading level1 row5" >nemotron</th>
#       <td id="T_e8011_row5_col0" class="data row5 col0" >5% ±7</td>
#       <td id="T_e8011_row5_col1" class="data row5 col1" >1% ±5</td>
#     </tr>
#     <tr>
#       <th id="T_e8011_level1_row6" class="row_heading level1 row6" >phi3</th>
#       <td id="T_e8011_row6_col0" class="data row6 col0" >19% ±10</td>
#       <td id="T_e8011_row6_col1" class="data row6 col1" >12% ±9</td>
#     </tr>
#     <tr>
#       <th id="T_e8011_level1_row7" class="row_heading level1 row7" >phi4</th>
#       <td id="T_e8011_row7_col0" class="data row7 col0" >99% ±5</td>
#       <td id="T_e8011_row7_col1" class="data row7 col1" >100% ±5</td>
#     </tr>
#     <tr>
#       <th id="T_e8011_level0_row8" class="row_heading level0 row8" rowspan="4">fireworks</th>
#       <th id="T_e8011_level1_row8" class="row_heading level1 row8" >llama31</th>
#       <td id="T_e8011_row8_col0" class="data row8 col0" >90% ±9</td>
#       <td id="T_e8011_row8_col1" class="data row8 col1" >85% ±9</td>
#     </tr>
#     <tr>
#       <th id="T_e8011_level1_row9" class="row_heading level1 row9" >llama32</th>
#       <td id="T_e8011_row9_col0" class="data row9 col0" >79% ±10</td>
#       <td id="T_e8011_row9_col1" class="data row9 col1" >80% ±10</td>
#     </tr>
#     <tr>
#       <th id="T_e8011_level1_row10" class="row_heading level1 row10" >llama33</th>
#       <td id="T_e8011_row10_col0" class="data row10 col0" >100% ±5</td>
#       <td id="T_e8011_row10_col1" class="data row10 col1" >98% ±6</td>
#     </tr>
#     <tr>
#       <th id="T_e8011_level1_row11" class="row_heading level1 row11" >qwen25</th>
#       <td id="T_e8011_row11_col0" class="data row11 col0" >100% ±5</td>
#       <td id="T_e8011_row11_col1" class="data row11 col1" >100% ±5</td>
#     </tr>
#   </tbody>
# </table>

# %%
compare_m_experiments(results_list)
# Out:
#                       Fisher exact  Barnard exact  Outcome
# Ollama    phi3            0.253618       0.264448    False
# fireworks llama31         0.237051       0.264448    False
# Anthropic Haiku_3         0.752466       1.000000    False
# Ollama    nemotron        0.183532       0.121823    False
# Anthropic Sonnet_35       1.000000       1.000000    False
# fireworks llama32         0.651807       1.000000    False
#           llama33         0.248428       0.105082    False
# Anthropic Haiku_35        1.000000       1.000000    False
# Ollama    llama32         0.968583       1.000000    False
#           phi4            1.000000       1.000000    False
# fireworks qwen25          1.000000       1.000000    False
# Ollama    deepseekr1      0.371640       0.332301    False

# %% [markdown]
# ### Experiment X
#
# Hypothesis: ???

# %%
# Testing system and user prompting & output parsers
results_sys_user = {}
experiment_date = "20-02-25"
experiment_num = "5"
load_single_experiment(experiment_num, experiment_date, "sys", results_sys_user)
load_single_experiment(experiment_num, experiment_date, "user", results_sys_user)
# Out:
# Loaded structure_support_by_model_sys
# Loaded structure_support_by_model_user

# %%
results_to_table(results_sys_user, combine_levels=True)
# Out:
#                       sys  user
# Ollama    deepseekr1  62%   79%
#           llama32     67%   76%
#           nemotron    27%   39%
#           phi3        16%   43%
#           phi4        99%   97%
# fireworks llama31     93%   94%
#           llama32     73%   86%
#           llama33     99%  100%

# %%
compare_m_experiments(
    results_sys_user, bonferroni=None, alternative="two-sided"
).sort_index(axis=0)
# Out:
#                       Fisher exact  Barnard exact  Outcome
# Ollama    deepseekr1      0.012750       0.008724     True
#           llama32         0.209961       0.210671    False
#           nemotron        0.097725       0.076838    False
#           phi3            0.000045       0.000027     True
#           phi4            0.621202       0.374089    False
# fireworks llama31         1.000000       0.852408    False
#           llama32         0.034734       0.024304     True
#           llama33         1.000000       0.529101    False

# %% [markdown]
# ### Experiment 2
#
# Hypothesis 1: XML schema conformance differs between system and user prompts
#
# Hypothesis 2: XML schema conformance differs between system and system + reminder prompting
#
# Hypothesis 3: Output parsers are worse than prompting for XML
#
# Note: No Quen2.5 or Anthropic models in this set

# %%
# Testing system and user prompting & output parsers
results_sys_other = {}
experiment_date = "21-02-25"
experiment_num = "5"
load_single_experiment(experiment_num, experiment_date, "sys", results_sys_other)
load_single_experiment(
    experiment_num, experiment_date, "sys_w_reminder", results_sys_other
)
load_single_experiment(experiment_num, experiment_date, "parser", results_sys_other)
load_single_experiment(experiment_num, experiment_date, "user", results_sys_other)
# Out:
# Loaded structure_support_by_model_sys
# Loaded structure_support_by_model_sys_w_reminder
# Loaded structure_support_by_model_parser
# Loaded structure_support_by_model_user

# %%
sys_other_table_1 = results_to_table(
    results_sys_other,
    combine_levels=True,
    cell_format=format_ci_pm,
    subset=[
        "structure_support_by_model_sys",
        "structure_support_by_model_sys_w_reminder",
        "structure_support_by_model_user",
    ],
)
sys_other_table_1
# Out:
#                           sys sys_w_reminder     user
# Ollama    deepseekr1  71% ±10         73% ±9   84% ±8
#           llama32     63% ±10        67% ±10   85% ±8
#           nemotron     11% ±8        63% ±10   27% ±9
#           phi3         25% ±9        36% ±10  37% ±10
#           phi4         97% ±5         98% ±5   99% ±4
# fireworks llama31      95% ±6         94% ±6   96% ±6
#           llama32      82% ±9         83% ±9   81% ±9
#           llama33      97% ±5         99% ±4   98% ±5

# %% [markdown]
# Reanalyse using different search modes

# %%
classes = generate_xml_classes(search_mode="unordered")
structured_formats_xml = [
    dict(pydantic=schema, format_instructions=None)
    for name, schema in classes.items()
    if name.startswith("ArticleResponse")
]
results_sys_other_relaxed = {
    ex_name: analyse_xml_experiment(
        ex_results,
        structured_formats_xml,
        verbose=False,
    )
    for ex_name, ex_results in results_sys_other.items()
}

# %%
results_to_table(
    results_sys_other_relaxed,
    combine_levels=True,
    cell_format=format_ci_pm,
    subset=[
        "structure_support_by_model_sys",
        "structure_support_by_model_sys_w_reminder",
        "structure_support_by_model_user",
    ],
    compare_to=sys_other_table_1,
)
# Out:
# <style type="text/css">
# #T_b1874_row0_col0, #T_b1874_row1_col1, #T_b1874_row3_col0, #T_b1874_row3_col1, #T_b1874_row3_col2, #T_b1874_row6_col1 {
#   color: red;
#   font-weight: bold;
# }
# </style>
# <table id="T_b1874">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b1874_level0_col0" class="col_heading level0 col0" >sys</th>
#       <th id="T_b1874_level0_col1" class="col_heading level0 col1" >sys_w_reminder</th>
#       <th id="T_b1874_level0_col2" class="col_heading level0 col2" >user</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b1874_level0_row0" class="row_heading level0 row0" rowspan="5">Ollama</th>
#       <th id="T_b1874_level1_row0" class="row_heading level1 row0" >deepseekr1</th>
#       <td id="T_b1874_row0_col0" class="data row0 col0" >72% ±9</td>
#       <td id="T_b1874_row0_col1" class="data row0 col1" >73% ±9</td>
#       <td id="T_b1874_row0_col2" class="data row0 col2" >84% ±8</td>
#     </tr>
#     <tr>
#       <th id="T_b1874_level1_row1" class="row_heading level1 row1" >llama32</th>
#       <td id="T_b1874_row1_col0" class="data row1 col0" >63% ±10</td>
#       <td id="T_b1874_row1_col1" class="data row1 col1" >76% ±9</td>
#       <td id="T_b1874_row1_col2" class="data row1 col2" >85% ±8</td>
#     </tr>
#     <tr>
#       <th id="T_b1874_level1_row2" class="row_heading level1 row2" >nemotron</th>
#       <td id="T_b1874_row2_col0" class="data row2 col0" >11% ±8</td>
#       <td id="T_b1874_row2_col1" class="data row2 col1" >63% ±10</td>
#       <td id="T_b1874_row2_col2" class="data row2 col2" >27% ±9</td>
#     </tr>
#     <tr>
#       <th id="T_b1874_level1_row3" class="row_heading level1 row3" >phi3</th>
#       <td id="T_b1874_row3_col0" class="data row3 col0" >26% ±9</td>
#       <td id="T_b1874_row3_col1" class="data row3 col1" >37% ±10</td>
#       <td id="T_b1874_row3_col2" class="data row3 col2" >39% ±10</td>
#     </tr>
#     <tr>
#       <th id="T_b1874_level1_row4" class="row_heading level1 row4" >phi4</th>
#       <td id="T_b1874_row4_col0" class="data row4 col0" >97% ±5</td>
#       <td id="T_b1874_row4_col1" class="data row4 col1" >98% ±5</td>
#       <td id="T_b1874_row4_col2" class="data row4 col2" >99% ±4</td>
#     </tr>
#     <tr>
#       <th id="T_b1874_level0_row5" class="row_heading level0 row5" rowspan="3">fireworks</th>
#       <th id="T_b1874_level1_row5" class="row_heading level1 row5" >llama31</th>
#       <td id="T_b1874_row5_col0" class="data row5 col0" >95% ±6</td>
#       <td id="T_b1874_row5_col1" class="data row5 col1" >94% ±6</td>
#       <td id="T_b1874_row5_col2" class="data row5 col2" >96% ±6</td>
#     </tr>
#     <tr>
#       <th id="T_b1874_level1_row6" class="row_heading level1 row6" >llama32</th>
#       <td id="T_b1874_row6_col0" class="data row6 col0" >82% ±9</td>
#       <td id="T_b1874_row6_col1" class="data row6 col1" >84% ±8</td>
#       <td id="T_b1874_row6_col2" class="data row6 col2" >81% ±9</td>
#     </tr>
#     <tr>
#       <th id="T_b1874_level1_row7" class="row_heading level1 row7" >llama33</th>
#       <td id="T_b1874_row7_col0" class="data row7 col0" >97% ±5</td>
#       <td id="T_b1874_row7_col1" class="data row7 col1" >99% ±4</td>
#       <td id="T_b1874_row7_col2" class="data row7 col2" >98% ±5</td>
#     </tr>
#   </tbody>
# </table>

# %%
compare_m_experiments(
    results_sys_other,
    bonferroni=3,
    alternative="two-sided",
    subset=[
        "structure_support_by_model_sys",
        "structure_support_by_model_user",
    ],
)
# Out:
#                       Fisher exact  Barnard exact  Outcome
# Ollama    phi3            0.092198       0.076838    False
# fireworks llama31         1.000000       0.819245    False
# Ollama    nemotron        0.006335       0.004019     True
# fireworks llama32         1.000000       0.915430    False
#           llama33         1.000000       0.752431    False
# Ollama    llama32         0.000627       0.000401     True
#           phi4            0.621202       0.374089    False
#           deepseekr1      0.041416       0.028925    False

# %%
compare_m_experiments(
    results_sys_other,
    bonferroni=3,
    alternative="two-sided",
    subset=[
        "structure_support_by_model_sys",
        "structure_support_by_model_sys_w_reminder",
    ],
)
# Out:
#                       Fisher exact  Barnard exact  Outcome
# Ollama    phi3        1.242213e-01   1.036390e-01    False
# fireworks llama31     1.000000e+00   8.381458e-01    False
# Ollama    nemotron    1.036357e-14   8.218392e-15     True
# fireworks llama32     1.000000e+00   9.130627e-01    False
#           llama33     6.212025e-01   3.740890e-01    False
# Ollama    llama32     6.566579e-01   5.926245e-01    False
#           phi4        1.000000e+00   7.524307e-01    False
#           deepseekr1  8.749655e-01   8.192451e-01    False

# %% [markdown]
# ## Combined results

# %% [markdown]
# #### Hypothesis 1: Do different models have different performance in XML output?

# %% [markdown]
# Collate similar experiments

# %%
combined_experiment_sys_user = {
    "user": [
        results_sys_user["structure_support_by_model_user"],
        results_temp_sup["structure_support_by_model_user"],
        results_sys_other["structure_support_by_model_user"],
    ],
}

# %%
classes = generate_xml_classes(search_mode="unordered")
structured_formats_xml = [
    dict(pydantic=schema, format_instructions=None)
    for name, schema in classes.items()
    if name.startswith("ArticleResponse")
]
combined_experiment_sys_user_relaxed = {
    ex_name: [
        analyse_xml_experiment(
            ex_single,
            structured_formats_xml,
            verbose=False,
        )
        for ex_single in ex_results
    ]
    for ex_name, ex_results in combined_experiment_sys_user.items()
}

# %%
res_table_1 = results_to_table(
    combined_experiment_sys_user,
    combine_levels=True,
    cell_format=format_ci_pm,
    markdown=False,
)
res_table_2 = results_to_table(
    combined_experiment_sys_user_relaxed,
    combine_levels=True,
    cell_format=format_ci_pm,
    markdown=True,
    compare_to=res_table_1,
)
print(res_table_2)
# Out:
# | level_0   | level_1        | user       | sys        |
# |:----------|:---------------|:-----------|:-----------|
# | Anthropic | Haiku_3        | 95% ±6     | 94% ±3     |
# | Anthropic | Haiku_35       | 100% ±4    | 99% ±2     |
# | Anthropic | Sonnet_35      | 100% ±4    | 100% ±1    |
# | Ollama    | deepseekr1     | 81% ±5     | 71% ±4     |
# | Ollama    | llama32        | **86% ±4** | **77% ±4** |
# | Ollama    | nemotron       | 39% ±6     | 11% ±3     |
# | Ollama    | phi3           | **48% ±6** | 32% ±4     |
# | Ollama    | phi4           | 98% ±2     | 99% ±1     |
# | fireworks | deepseekr1_70b | **nan**    | 0% ±2      |
# | fireworks | llama31        | 95% ±3     | 93% ±3     |
# | fireworks | llama32        | 86% ±4     | 81% ±4     |
# | fireworks | llama33        | 99% ±2     | 99% ±1     |
# | fireworks | qwen25         | 100% ±4    | 100% ±1    |

# %%
print(res_table_1)
# Out:
#                              user      sys
# Anthropic Haiku_3          95% ±6   94% ±3
#           Haiku_35        100% ±4   99% ±2
#           Sonnet_35       100% ±4  100% ±1
# Ollama    deepseekr1       81% ±5   71% ±4
#           llama32          83% ±5   75% ±4
#           nemotron         39% ±6   11% ±3
#           phi3             47% ±6   32% ±4
#           phi4             98% ±2   99% ±1
# fireworks deepseekr1_70b      NaN    0% ±2
#           llama31          95% ±3   93% ±3
#           llama32          86% ±4   81% ±4
#           llama33          99% ±2   99% ±1
#           qwen25          100% ±4  100% ±1

# %% [markdown]
# #### Hypothesis 2: Do different temperatures cause different compliance to XML?

# %% [markdown]
# Collate similar experiments
#
# - Experiment 4: t=0 & t=0.8
# - Experiment 6: t=0
# - Experiment 2: t=0.8

# %%
combined_experiments_temp = {
    "t=0": [
        results_temp["structure_support_by_model_t0"],
        results_temp_sup["structure_support_by_model_sys"],
        results_temp_sup["structure_support_by_model_user"],
    ],
    "t=0.8": [
        results_temp["structure_support_by_model_t08"],
        results_sys_other["structure_support_by_model_sys"],
        results_sys_other["structure_support_by_model_user"],
    ],
}

# %%
classes = generate_xml_classes(search_mode="unordered")
structured_formats_xml = [
    dict(pydantic=schema, format_instructions=None)
    for name, schema in classes.items()
    if name.startswith("ArticleResponse")
]
combined_experiment_temp_relaxed = {
    conf_name: [
        analyse_xml_experiment(
            ex_results,
            structured_formats_xml,
            verbose=False,
        )
        for ex_results in conf_data
    ]
    for conf_name, conf_data in combined_experiments_temp.items()
}

# %%
res_table_temp_1 = results_to_table(
    combined_experiments_temp,
    combine_levels=True,
    cell_format=format_ci_pm,
)
res_table_temp_2 = results_to_table(
    combined_experiment_temp_relaxed,
    combine_levels=True,
    cell_format=format_ci_pm,
    compare_to=res_table_temp_1,
)
res_table_temp_2
# Out:
# <style type="text/css">
# #T_52c7b_row3_col1, #T_52c7b_row4_col0, #T_52c7b_row6_col1 {
#   color: red;
#   font-weight: bold;
# }
# </style>
# <table id="T_52c7b">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_52c7b_level0_col0" class="col_heading level0 col0" >t=0</th>
#       <th id="T_52c7b_level0_col1" class="col_heading level0 col1" >t=0.8</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_52c7b_level0_row0" class="row_heading level0 row0" rowspan="3">Anthropic</th>
#       <th id="T_52c7b_level1_row0" class="row_heading level1 row0" >Haiku_3</th>
#       <td id="T_52c7b_row0_col0" class="data row0 col0" >95% ±3</td>
#       <td id="T_52c7b_row0_col1" class="data row0 col1" >93% ±7</td>
#     </tr>
#     <tr>
#       <th id="T_52c7b_level1_row1" class="row_heading level1 row1" >Haiku_35</th>
#       <td id="T_52c7b_row1_col0" class="data row1 col0" >99% ±2</td>
#       <td id="T_52c7b_row1_col1" class="data row1 col1" >99% ±4</td>
#     </tr>
#     <tr>
#       <th id="T_52c7b_level1_row2" class="row_heading level1 row2" >Sonnet_35</th>
#       <td id="T_52c7b_row2_col0" class="data row2 col0" >100% ±1</td>
#       <td id="T_52c7b_row2_col1" class="data row2 col1" >100% ±4</td>
#     </tr>
#     <tr>
#       <th id="T_52c7b_level0_row3" class="row_heading level0 row3" rowspan="5">Ollama</th>
#       <th id="T_52c7b_level1_row3" class="row_heading level1 row3" >deepseekr1</th>
#       <td id="T_52c7b_row3_col0" class="data row3 col0" >78% ±5</td>
#       <td id="T_52c7b_row3_col1" class="data row3 col1" >77% ±5</td>
#     </tr>
#     <tr>
#       <th id="T_52c7b_level1_row4" class="row_heading level1 row4" >llama32</th>
#       <td id="T_52c7b_row4_col0" class="data row4 col0" >87% ±4</td>
#       <td id="T_52c7b_row4_col1" class="data row4 col1" >75% ±5</td>
#     </tr>
#     <tr>
#       <th id="T_52c7b_level1_row5" class="row_heading level1 row5" >nemotron</th>
#       <td id="T_52c7b_row5_col0" class="data row5 col0" >22% ±5</td>
#       <td id="T_52c7b_row5_col1" class="data row5 col1" >14% ±4</td>
#     </tr>
#     <tr>
#       <th id="T_52c7b_level1_row6" class="row_heading level1 row6" >phi3</th>
#       <td id="T_52c7b_row6_col0" class="data row6 col0" >52% ±6</td>
#       <td id="T_52c7b_row6_col1" class="data row6 col1" >32% ±5</td>
#     </tr>
#     <tr>
#       <th id="T_52c7b_level1_row7" class="row_heading level1 row7" >phi4</th>
#       <td id="T_52c7b_row7_col0" class="data row7 col0" >99% ±2</td>
#       <td id="T_52c7b_row7_col1" class="data row7 col1" >99% ±2</td>
#     </tr>
#     <tr>
#       <th id="T_52c7b_level0_row8" class="row_heading level0 row8" rowspan="5">fireworks</th>
#       <th id="T_52c7b_level1_row8" class="row_heading level1 row8" >deepseekr1_70b</th>
#       <td id="T_52c7b_row8_col0" class="data row8 col0" >0% ±4</td>
#       <td id="T_52c7b_row8_col1" class="data row8 col1" >0% ±4</td>
#     </tr>
#     <tr>
#       <th id="T_52c7b_level1_row9" class="row_heading level1 row9" >llama31</th>
#       <td id="T_52c7b_row9_col0" class="data row9 col0" >95% ±3</td>
#       <td id="T_52c7b_row9_col1" class="data row9 col1" >95% ±3</td>
#     </tr>
#     <tr>
#       <th id="T_52c7b_level1_row10" class="row_heading level1 row10" >llama32</th>
#       <td id="T_52c7b_row10_col0" class="data row10 col0" >88% ±4</td>
#       <td id="T_52c7b_row10_col1" class="data row10 col1" >81% ±5</td>
#     </tr>
#     <tr>
#       <th id="T_52c7b_level1_row11" class="row_heading level1 row11" >llama33</th>
#       <td id="T_52c7b_row11_col0" class="data row11 col0" >99% ±2</td>
#       <td id="T_52c7b_row11_col1" class="data row11 col1" >98% ±2</td>
#     </tr>
#     <tr>
#       <th id="T_52c7b_level1_row12" class="row_heading level1 row12" >qwen25</th>
#       <td id="T_52c7b_row12_col0" class="data row12 col0" >100% ±1</td>
#       <td id="T_52c7b_row12_col1" class="data row12 col1" >100% ±4</td>
#     </tr>
#   </tbody>
# </table>

# %%
res = results_to_table(
    combined_experiments_temp,
    combine_levels=True,
    cell_format=format_ci_pm,
    markdown=True,
)
print(res)
# Out:
# | level_0   | level_1        | t=0     | t=0.8   |
# |:----------|:---------------|:--------|:--------|
# | Anthropic | Haiku_3        | 95% ±3  | 93% ±7  |
# | Anthropic | Haiku_35       | 99% ±2  | 99% ±4  |
# | Anthropic | Sonnet_35      | 100% ±1 | 100% ±4 |
# | Ollama    | deepseekr1     | 78% ±5  | 76% ±5  |
# | Ollama    | llama32        | 85% ±4  | 75% ±5  |
# | Ollama    | nemotron       | 22% ±5  | 14% ±4  |
# | Ollama    | phi3           | 52% ±6  | 30% ±5  |
# | Ollama    | phi4           | 99% ±2  | 99% ±2  |
# | fireworks | deepseekr1_70b | 0% ±4   | 0% ±4   |
# | fireworks | llama31        | 95% ±3  | 95% ±3  |
# | fireworks | llama32        | 88% ±4  | 81% ±5  |
# | fireworks | llama33        | 99% ±2  | 98% ±2  |
# | fireworks | qwen25         | 100% ±1 | 100% ±4 |

# %%
compare_m_experiments(
    combined_experiments_temp,
    bonferroni=True,
    alternative="two-sided",
).sort_index(axis=0)
# Out:
#                           Fisher exact  Barnard exact  Outcome
# Anthropic Haiku_3         4.517915e-01   5.831062e-01    False
#           Haiku_35        1.000000e+00   7.511386e-01    False
#           Sonnet_35       1.000000e+00   1.000000e+00    False
# Ollama    deepseekr1      7.711052e-01   7.242056e-01    False
#           llama32         2.974332e-03   2.244000e-03     True
#           nemotron        1.955380e-02   1.594044e-02    False
#           phi3            1.508677e-07   1.051415e-07     True
#           phi4            1.000000e+00   7.343370e-01    False
# fireworks deepseekr1_70b  1.000000e+00   1.000000e+00    False
#           llama31         1.000000e+00   9.104654e-01    False
#           llama32         2.368940e-02   1.908144e-02    False
#           llama33         5.450239e-01   3.743331e-01    False
#           qwen25          1.000000e+00   1.000000e+00    False

# %% [markdown]
# #### Hypothesis 3: Do different models work using format in the system prompt or user prompt?

# %% [markdown]
# Collate similar experiments

# %%
combined_experiment_sys_user = {
    "sys": [
        results_sys_user["structure_support_by_model_sys"],
        results_temp_sup["structure_support_by_model_sys"],
        results_sys_other["structure_support_by_model_sys"],
    ],
    "user": [
        results_sys_user["structure_support_by_model_user"],
        results_temp_sup["structure_support_by_model_user"],
        results_sys_other["structure_support_by_model_user"],
    ],
}

# %%
res = results_to_table(
    combined_experiment_sys_user,
    combine_levels=True,
    cell_format=format_ci_pm,
    markdown=True,
)
print(res)
# Out:
# | level_0   | level_1    | sys     | user    |
# |:----------|:-----------|:--------|:--------|
# | Anthropic | Haiku_3    | 95% ±6  | 95% ±6  |
# | Anthropic | Haiku_35   | 99% ±4  | 100% ±4 |
# | Anthropic | Sonnet_35  | 100% ±4 | 100% ±4 |
# | Ollama    | deepseekr1 | 70% ±5  | 81% ±5  |
# | Ollama    | llama32    | 71% ±5  | 83% ±5  |
# | Ollama    | nemotron   | 15% ±5  | 39% ±6  |
# | Ollama    | phi3       | 29% ±5  | 47% ±6  |
# | Ollama    | phi4       | 98% ±2  | 98% ±2  |
# | fireworks | llama31    | 94% ±3  | 95% ±3  |
# | fireworks | llama32    | 81% ±5  | 86% ±4  |
# | fireworks | llama33    | 99% ±2  | 99% ±2  |
# | fireworks | qwen25     | 100% ±4 | 100% ±4 |

# %%
compare_m_experiments(
    combined_experiment_sys_user,
    bonferroni=True,
    alternative="two-sided",
).sort_index(axis=0)
# Out:
#                       Fisher exact  Barnard exact  Outcome
# Anthropic Haiku_3     1.000000e+00   1.000000e+00    False
#           Haiku_35    1.000000e+00   5.291009e-01    False
#           Sonnet_35   1.000000e+00   1.000000e+00    False
# Ollama    deepseekr1  1.204980e-03   9.282922e-04     True
#           llama32     1.316218e-03   9.928911e-04     True
#           nemotron    1.346911e-10   1.147929e-10     True
#           phi3        1.166575e-05   8.196285e-06     True
#           phi4        1.000000e+00   1.000000e+00    False
# fireworks llama31     8.561652e-01   7.516218e-01    False
#           llama32     1.263373e-01   1.277870e-01    False
#           llama33     1.000000e+00   1.000000e+00    False
#           qwen25      1.000000e+00   1.000000e+00    False

# %% [markdown]
# #### Hypothesis 4: Do LangChain output parsers do as well as format examples for complex formats?

# %% [markdown]
# Collate similar experiments

# %%
combined_experiment_sys_parser = {
    "sys": [
        results_sys_other["structure_support_by_model_sys"],
        results_temp_sup["structure_support_by_model_sys"],
    ],
    "parser": [
        results_sys_other["structure_support_by_model_parser"],
        results_temp_sup["structure_support_by_model_parsers"],
    ],
}

# %%
res = results_to_table(
    combined_experiment_sys_parser,
    combine_levels=True,
    cell_format=format_ci_pm,
    markdown=True,
)
print(res)
# Out:
# | level_0   | level_1    | sys     | parser   |
# |:----------|:-----------|:--------|:---------|
# | Anthropic | Haiku_3    | 95% ±6  | 52% ±11  |
# | Anthropic | Haiku_35   | 99% ±4  | 50% ±11  |
# | Anthropic | Sonnet_35  | 100% ±4 | 71% ±11  |
# | Ollama    | deepseekr1 | 74% ±7  | 8% ±5    |
# | Ollama    | llama32    | 74% ±7  | 8% ±5    |
# | Ollama    | nemotron   | 10% ±5  | 0% ±5    |
# | Ollama    | phi3       | 36% ±7  | 4% ±4    |
# | Ollama    | phi4       | 98% ±3  | 61% ±11  |
# | fireworks | llama31    | 95% ±4  | 42% ±11  |
# | fireworks | llama32    | 84% ±6  | 0% ±5    |
# | fireworks | llama33    | 98% ±3  | 31% ±11  |
# | fireworks | qwen25     | 100% ±4 | 75% ±10  |

# %%
classes = generate_xml_classes(search_mode="unordered")
structured_formats_xml = [
    dict(pydantic=schema, format_instructions=None)
    for name, schema in classes.items()
    if name.startswith("ArticleResponse")
]
combined_experiment_sys_parser_relaxed = {
    conf_name: [
        analyse_xml_experiment(
            ex_results,
            structured_formats_xml,
            verbose=False,
        )
        for ex_results in conf_data
    ]
    for conf_name, conf_data in combined_experiment_sys_parser.items()
}
res_table_sys_parser_1 = results_to_table(
    combined_experiment_sys_parser,
    combine_levels=True,
    cell_format=format_ci_pm,
)
res_table_sys_parser_2 = results_to_table(
    combined_experiment_sys_parser_relaxed,
    combine_levels=True,
    cell_format=format_ci_pm,
    compare_to=res_table_sys_parser_1,
    markdown=True,
)
print(res_table_sys_parser_2)
# Out:
# | level_0   | level_1    | sys        | parser      |
# |:----------|:-----------|:-----------|:------------|
# | Anthropic | Haiku_3    | 95% ±6     | **54% ±11** |
# | Anthropic | Haiku_35   | 99% ±4     | **75% ±10** |
# | Anthropic | Sonnet_35  | 100% ±4    | 71% ±11     |
# | Ollama    | deepseekr1 | **74% ±6** | 8% ±5       |
# | Ollama    | llama32    | 74% ±7     | **18% ±7**  |
# | Ollama    | nemotron   | 10% ±5     | 0% ±5       |
# | Ollama    | phi3       | 36% ±7     | 4% ±4       |
# | Ollama    | phi4       | 98% ±3     | **69% ±11** |
# | fireworks | llama31    | 95% ±4     | **57% ±11** |
# | fireworks | llama32    | 84% ±6     | 0% ±5       |
# | fireworks | llama33    | 98% ±3     | 31% ±11     |
# | fireworks | qwen25     | 100% ±4    | 75% ±10     |

# %% [markdown]
# ## Error analysis

# %%
def analyse_errors_from_results(ss_results, method="code", combined=False):
    error_counts = {}
    for mname in ss_results.keys():
        error_counts[mname] = {}
        for tname in ss_results[mname].keys():
            # Count errors by failure code above
            if method == "code":
                error_types = pd.Series(
                    output["error_type"]
                    for output in ss_results[mname][tname]["outputs"]
                )
                error_codes = error_types.value_counts()

                for e_name, e_count in error_codes.items():
                    if combined:
                        error_counts[mname][e_name] = (
                            error_counts[mname].get(e_name, 0) + e_count
                        )
                    else:
                        error_counts[mname][(tname, e_name)] = e_count

            elif method == "parse":
                # Count errors by parsing error message
                errors = (
                    output["error_message"]
                    for output in ss_results[mname][tname]["outputs"]
                )
                for error in errors:
                    if error is None:
                        continue
                    if error.lower().find("opening and ending tag mismatch") >= 0:
                        error_str = "XML tag mismatch"
                    elif error.lower().find("extracterror") >= 0:
                        error_str = "Missing main tags"
                    elif error.lower().find("input should be a valid integer") >= 0:
                        error_str = "Validation error (int)"
                    elif error.lower().find("premature end of data in tag") >= 0:
                        error_str = "Premature end"
                    elif error.lower().find("field required") >= 0:
                        error_str = "Missing field"
                    elif error.lower().find("expected '>'") >= 0:
                        error_str = "Tag malformed"
                    elif (
                        error.lower().find("extra content at the end of the document")
                        >= 0
                    ):
                        error_str = "Tag malformed"
                    elif error.find("BadGatewayError") >= 0:
                        error_str = "Connection error"
                    elif error.find("XMLSyntaxError") >= 0:
                        error_str = "Other syntax error"
                    else:
                        error_str = error

                    if combined:
                        error_counts[mname][error_str] = (
                            error_counts[mname].get(error_str, 0) + 1
                        )

                    else:
                        error_counts[mname][(tname, error_str)] = (
                            error_counts[mname].get((tname, error_str), 0) + 1
                        )

            else:
                raise NameError(f"Method {method} not supported")

    return pd.DataFrame.from_dict(error_counts, orient="index")

# %% [markdown]
# Let's look at the errors in the sys/user/parsers experiment to determine what's going on for the worst models

# %%
analyse_errors_from_results(
    results_temp_sup["structure_support_by_model_user"], method="parse", combined=True
).fillna(0).sort_index(axis=1)
# Out:
#                    Connection error  Missing field  Missing main tags  \
# Ollama_llama32                  0.0            8.0                0.0
# Ollama_nemotron                 0.0            1.0               44.0
# Ollama_phi4                     0.0            0.0                0.0
# Ollama_deepseekr1               0.0            7.0                3.0
# fireworks_llama31               1.0            0.0                0.0
# fireworks_llama32               0.0            0.0                1.0
# Anthropic_Haiku_3               0.0            0.0                0.0
# Ollama_phi3                     0.0            5.0                4.0
# fireworks_llama33               1.0            0.0                0.0
#
#                    Other syntax error  Tag malformed  Validation error (int)  \
# Ollama_llama32                    0.0            0.0                     5.0
# Ollama_nemotron                   0.0            0.0                     5.0
# Ollama_phi4                       0.0            0.0                     1.0
# Ollama_deepseekr1                 5.0            0.0                     2.0
# fireworks_llama31                 0.0            0.0                     4.0
# fireworks_llama32                 0.0            0.0                     9.0
# Anthropic_Haiku_3                 0.0            0.0                     5.0
# Ollama_phi3                       3.0            4.0                     0.0
# fireworks_llama33                 0.0            0.0                     0.0
#
#                    XML tag mismatch
# Ollama_llama32                  0.0
# Ollama_nemotron                 0.0
# Ollama_phi4                     0.0
# Ollama_deepseekr1               2.0
# fireworks_llama31               0.0
# fireworks_llama32               0.0
# Anthropic_Haiku_3               0.0
# Ollama_phi3                    23.0
# fireworks_llama33               1.0

# %% [markdown]
# DeepSeek performance is poor, and for the system prompt most errors are due to missing main tags -- typically indicating the output is not XML. Confirmed.
#
# For the User prompt the XML is just badly generated with missing and corrupted tags.

# %%
for output in results_temp_sup["structure_support_by_model_user"]["Ollama_deepseekr1"][
    "ArticleResponse4XML"
]["outputs"]:
    if output["error_type"] != "ok":
        print("-" * 80)
        print(output["error_message"], "\n")
        if output["raw"] is not None:
            print(output["raw"].content)
        print()

# %% [markdown]
# Llama 3.2 on Fireworks is getting a big fat 0 for all levels with output parsers. Why's that?

# %%
for output in results_temp_sup["structure_support_by_model_parsers"][
    "fireworks_llama32"
]["ArticleResponse2XML"]["outputs"]:
    if output["error_type"] != "ok":
        print("-" * 80)
        print(output["error_message"], "\n")
        if output["raw"] is not None:
            print(output["raw"].content)
        print()
# Out:
# --------------------------------------------------------------------------------
# RuntimeError, ExtractError: End or start strings not found
#
# **The Oldest Recorded Fossil: A Window into the Past**
#
# Imagine walking through a barren, ancient landscape, surrounded by nothing but sand and rock. Yet, in this desolate environment, a tiny fragment of life has been preserved for over 3.5 billion years. This is the story of the oldest recorded fossil, a testament to the enduring power of life on Earth.
#
# The fossil in question is a 3.5 billion-year-old stromatolite, a layered structure created by ancient microorganisms. Discovered in Western Australia, this ancient relic is a window into the early history of life on our planet. The stromatolite, named "Stromatolites of the Apex Chert," is a remarkable find, providing insights into the evolution of life on Earth.
#
# This ancient fossil is a reminder that life has been present on our planet for an incredibly long time, long before the emergence of complex organisms. The discovery of this stromatolite has shed new light on the origins of life on Earth, and its significance will continue to inspire scientists and the public alike.
#
# --------------------------------------------------------------------------------
# RuntimeError, ExtractError: End or start strings not found
#
# **The Mysterious Black Hole**
#
# Imagine a region in space so dense and gravitationally powerful that nothing, not even light, can escape its pull. This is the realm of a black hole, a phenomenon that has fascinated scientists and the public alike for decades.
#
# A black hole is formed when a massive star collapses in on itself, causing a massive amount of matter to be compressed into an incredibly small space. This compression creates an intense gravitational field that warps the fabric of spacetime around the star. Any matter or radiation that gets too close to the black hole is trapped by this field, effectively being pulled into a one-way vortex.
#
# The term "black" refers to the fact that not even light can escape the black hole's gravitational pull, making it invisible to our telescopes. However, the effects of a black hole can be observed, such as the bending of light around it, known as gravitational lensing. Recent discoveries have also revealed that black holes can be found at the centers of galaxies, including our own Milky Way. The study of black holes continues to be an active area of research, offering insights into the mysteries of the universe and the behavior of matter under extreme conditions.
#
# --------------------------------------------------------------------------------
# RuntimeError, ExtractError: End or start strings not found
#
# **The Sun's Distance: A Cosmic Scale**
#
# Imagine standing on the surface of the Earth, feeling the warmth of the sun on your skin. But have you ever stopped to think about just how far away the sun is? The answer might surprise you.
#
# The sun is approximately 93 million miles (150 million kilometers) away from our planet. To put that in perspective, consider this: if you were to travel at the speed of a commercial airliner (around 500 miles per hour), it would take you over 177 years to reach the sun.
#
# But why does the sun seem so close? It's because we're used to its presence in our daily lives. We've grown accustomed to its warmth and light, and it's easy to forget just how vast the universe is. The sun is actually just one of eight planets in our solar system, and it's just one of billions of stars in the Milky Way galaxy.
#
# So the next time you feel the sun's rays on your skin, remember: you're just a tiny speck in an enormous universe, with the sun shining brightly at a distance of 93 million miles.
#
# --------------------------------------------------------------------------------
# RuntimeError, ExtractError: End or start strings not found
#
# **The Closest Match to Earth's Gravity**
#
# When we think of the planets in our Solar System, we often imagine them as vastly different from our own. But did you know that one planet has a surface gravity that's remarkably close to our own?
#
# The answer is Venus! With a surface gravity of about 90% of Earth's, Venus is the closest match in our Solar System. This means that if you weighed 100 pounds on Earth, you'd weigh about 90 pounds on Venus.
#
# But why is Venus so similar to Earth in terms of gravity? It's because both planets have similar masses and radii. This similarity is due to the way they formed in the early days of the Solar System. Venus is often referred to as Earth's "sister planet" because of their similarities.
#
# So, if you ever find yourself on a hypothetical trip to Venus, you can rest assured that you'll be experiencing a gravity that's almost as familiar as your own. Just don't forget to pack your spacesuit!
#
# --------------------------------------------------------------------------------
# RuntimeError, ExtractError: End or start strings not found
#
# **The Mysterious World of Dwarf Planets**
#
# In recent years, astronomers have discovered a new class of objects in our solar system that are challenging our understanding of the cosmos. Eris, Haumea, Makemake, and Ceres are four of these enigmatic bodies, and they all share a common characteristic: they are dwarf planets.
#
# So, what exactly are dwarf planets? Simply put, they are large enough to have rounded themselves through their own gravity, but have not cleared their orbits of other objects. In other words, they are not massive enough to dominate their orbits and have become the dominant objects in their regions.
#
# These dwarf planets are fascinating because they offer a glimpse into the early formation of our solar system. They are thought to be remnants from the time when the solar system was still in its formative stages. By studying these objects, scientists can gain insights into the processes that shaped our cosmic neighborhood. For example, Ceres, the largest of the four, is believed to be a remnant protoplanet that never grew large enough to become a full-fledged planet.
#
# --------------------------------------------------------------------------------
# RuntimeError, ExtractError: End or start strings not found
#
# **The Changing Seasons: Why Earth's Climate is Unique**
#
# As the calendar flips from summer to autumn, winter to spring, and back again, many of us take for granted the changing seasons that shape our lives. But have you ever wondered why Earth experiences these periodic shifts in climate?
#
# The answer lies in the Earth's tilt and orbit around the sun. Our planet's axis is tilted at an angle of about 23.5 degrees, which means that, as it rotates on its axis, different parts of the Earth are tilted towards or away from the sun. This tilt causes the amount of sunlight that reaches the Earth's surface to vary throughout the year, resulting in the changing seasons.
#
# But do other planets exhibit seasons too? The answer is yes! Many planets in our solar system experience seasonal changes, although the extent and characteristics of these seasons can vary greatly. For example, Mars has a thin atmosphere, which means its seasons are much more extreme than Earth's. On the other hand, Venus, with its thick atmosphere, has a relatively constant temperature, with no distinct seasons. The study of seasonal changes on other planets helps us better understand the complex relationships between a planet's atmosphere, orbit, and climate.
#
# --------------------------------------------------------------------------------
# RuntimeError, ExtractError: End or start strings not found
#
# **The Dancing Lights of the North: Unveiling the Secrets of the Aurora Borealis**
#
# Imagine witnessing a breathtaking spectacle of colored lights dancing across the night sky, as if the stars themselves were putting on a show. This is the enchanting phenomenon known as the Aurora Borealis, or Northern Lights. But what causes this mesmerizing display?
#
# The answer lies in the Earth's magnetic field and the solar wind. When charged particles from the sun, such as electrons and protons, collide with our planet's magnetic field, they excite the atoms and molecules in the atmosphere, causing them to emit light. The color of the aurora depends on the energy of the particles and the altitude at which they collide with the atmosphere.
#
# The Northern Lights are most commonly seen in the Northern Hemisphere, particularly at high latitudes such as Alaska, Canada, and Norway. The aurora borealis is a natural wonder that has captivated humans for centuries, inspiring myths and legends about the gods and spirits that dance in the sky. By understanding the science behind this phenomenon, we can appreciate the beauty and complexity of our planet's magnetic field and the solar wind that shape our atmosphere.
#
# --------------------------------------------------------------------------------
# RuntimeError, ExtractError: End or start strings not found
#
# **The Blue Sky: A Colorful Conundrum**
#
# Have you ever stopped to think about why the sky appears blue? It's a question that has puzzled people for centuries, and one that has fascinated scientists and philosophers alike. So, what's behind this beautiful blue hue?
#
# The answer lies in the way light interacts with the Earth's atmosphere. When sunlight enters our atmosphere, it encounters tiny molecules of gases such as nitrogen and oxygen. These molecules scatter the light in all directions, but they scatter shorter (blue) wavelengths more than longer (red) wavelengths. This is known as Rayleigh scattering, named after the British physicist who first described the phenomenon.
#
# As a result, our eyes perceive the blue light that is scattered in all directions, giving the sky its characteristic blue color. The color of the sky can vary depending on the time of day and atmospheric conditions, but the basic principle remains the same. So, the next time you gaze up at a blue sky, remember the tiny molecules of gas that are responsible for its beauty.
#
# --------------------------------------------------------------------------------
# RuntimeError, ExtractError: End or start strings not found
#
# **The Buzz on Bee Communication**
#
# Bees are some of the most fascinating creatures in the natural world, and their ability to communicate with each other is a remarkable example of evolutionary ingenuity. So, how do these tiny insects convey complex information to each other?
#
# Bees use a variety of methods to communicate, including dance, pheromones, and even sound. The most well-known form of bee communication is the "waggle dance," which is performed by honeybees to inform their fellow workers about the location of food sources. The dance involves a figure-eight pattern, with the bee vibrating its body to signal the direction and distance of the food.
#
# But that's not all - bees also use pheromones, or chemical signals, to communicate with each other. For example, when a forager bee returns to the hive with nectar, it releases a pheromone that signals to other bees that food is available. This complex system of communication allows bees to work together to gather food, build hives, and even warn each other of predators.
#
# By studying bee communication, scientists can gain insights into the intricate social structures of these incredible insects, and even develop new technologies inspired by their remarkable abilities.
#
# --------------------------------------------------------------------------------
# RuntimeError, ExtractError: End or start strings not found
#
# **The Tiny Building Blocks of Life**
#
# Have you ever wondered what makes something alive? Is it the movement, the growth, or the ability to respond to its environment? The answer lies at the smallest scale, where the fundamental building blocks of life reside.
#
# Meet the cell, the smallest unit of life. A cell is a tiny, self-contained world that can grow, reproduce, and respond to stimuli. It's the basic structural and functional unit of all living organisms, from bacteria to humans.
#
# Cells are incredibly diverse, with different shapes, sizes, and functions. Some cells are specialized to perform specific tasks, like photosynthesis in plant cells or muscle contraction in animal cells. Others are generalists, capable of adapting to changing environments.
#
# The discovery of cells revolutionized our understanding of life. In the 19th century, scientists like Matthias Schleiden and Theodor Schwann uncovered the cell theory, which states that all living organisms are composed of one or more cells. Today, we know that cells are the foundation of life, and their study has led to countless breakthroughs in medicine, biotechnology, and our understanding of the natural world.
#
# --------------------------------------------------------------------------------
# RuntimeError, ExtractError: End or start strings not found
#
# **How Plants Make Their Own Food**
#
# Have you ever stopped to think about how plants grow and thrive, even in the absence of sunlight? The answer lies in a remarkable process called photosynthesis.
#
# Photosynthesis is like a tiny factory inside the plant's leaves, where they use energy from sunlight, water, and carbon dioxide to produce their own food. This process is essential for life on Earth, as it provides the energy and organic compounds needed to support the food chain.
#
# Here's a simplified overview of how it works: plants absorb water and carbon dioxide through their roots and leaves, respectively. They then use energy from sunlight to convert these substances into glucose, a type of sugar that serves as their primary source of energy. This process also releases oxygen as a byproduct, which is released into the air for us to breathe.
#
# The next time you see a plant growing in your garden or a forest, remember that it's hard at work, using sunlight to fuel its own growth and development. This incredible process is a testament to the ingenuity and resilience of nature.
#
# --------------------------------------------------------------------------------
# RuntimeError, ExtractError: End or start strings not found
#
# **The Mysterious World of Dreams**
#
# Have you ever woken up from a dream feeling like you've been on a wild adventure, only to wonder what it was all about? You're not alone. For centuries, scientists and philosophers have been trying to unravel the mystery of dreams. So, why do we dream?
#
# Research suggests that dreams are a natural byproduct of our brain's attempt to process and consolidate memories, especially emotional ones. During REM sleep, our brain replays and revises previously experienced events, strengthening the connections between neurons. This process helps us learn and remember new information more effectively.
#
# But dreams can also be a reflection of our subconscious mind, revealing hidden fears, desires, and emotions. For example, a study found that people who are afraid of spiders are more likely to dream about spiders. This suggests that our brain is constantly working to resolve conflicts and make sense of our experiences, even when we're asleep.
#
# While we still don't fully understand the purpose of dreams, research has shown that they can be a valuable tool for self-discovery and creativity. So, the next time you wake up from a vivid dream, take a moment to reflect on what it might be trying to tell you about yourself.
#
# --------------------------------------------------------------------------------
# RuntimeError, ExtractError: End or start strings not found
#
# **The Theory of Relativity: A Mind-Bending Explanation**
#
# Imagine you're on a train, watching a tree pass by outside your window. You throw a ball straight up in the air - what happens? The ball comes down and lands in your hand, right? Now, imagine your friend is standing next to the tree, watching you on the train. From their perspective, the ball doesn't just go straight up and down - it also moves forward, because the train is moving.
#
# This thought experiment, proposed by Albert Einstein, is the foundation of his theory of relativity. In simple terms, relativity says that how we see the world depends on how we're moving and where we are. Time and space aren't fixed - they're connected and can appear different to different observers.
#
# Einstein's theory revolutionized our understanding of the universe, from the behavior of stars and planets to the nature of gravity itself. It's a fundamental concept in modern physics, and its impact continues to shape our understanding of the cosmos. By challenging our classical notions of space and time, relativity has opened doors to new discoveries and a deeper appreciation of the intricate workings of the universe.
#
# --------------------------------------------------------------------------------
# RuntimeError, ExtractError: End or start strings not found
#
# **Volcanoes: Unleashing the Fury of the Earth**
#
# Imagine a mountain that has been quiet for centuries, its slopes covered in lush green forests and its peak shrouded in mist. But beneath the surface, a cauldron of molten rock and gases is building up pressure. This is the story of a volcano, and the eruption that can change the landscape forever.
#
# So, how do volcanoes erupt? It all starts with magma, a mixture of molten rock, gases, and minerals that forms beneath the Earth's surface. As the magma chamber grows, the pressure increases, causing the magma to rise through a vent or fissure in the Earth's crust. As it emerges, the magma is released as lava, ash, and gas, creating a volcanic eruption.
#
# The eruption can be violent, spewing ash and rock into the air, or gentle, producing a slow flow of lava. Either way, the impact is significant, shaping the surrounding landscape and affecting the environment and human populations. The study of volcanoes is crucial for understanding the Earth's internal dynamics and predicting eruptions, helping us to prepare for and respond to these powerful natural events.
#
# --------------------------------------------------------------------------------
# RuntimeError, ExtractError: End or start strings not found
#
# **The Speed of Light: A Constant Companion to the Universe**
#
# Imagine you're on a train, hurtling through the countryside at high speed. You throw a ball straight up in the air, and it comes back down to your hand. Now, imagine your friend is standing on the platform, watching you whizz by. From their perspective, the ball doesn't just go straight up and down – it also moves forward, because the train is moving so fast.
#
# But here's the amazing thing about the speed of light: no matter how fast you're moving, or where you are in the universe, light always travels at the same speed – approximately 186,282 miles per second. This speed is a fundamental constant of the universe, and it's what allows us to see the world around us.
#
# The speed of light is so fast that it takes just 8 minutes and 20 seconds for a signal to travel from the Sun to Earth. This means that if a supernova were to explode in the nearest galaxy, we'd see it in our skies just 8 minutes later. The speed of light is a constant companion to the universe, and it's what makes the cosmos so fascinating and mysterious.
#
# --------------------------------------------------------------------------------
# RuntimeError, ExtractError: End or start strings not found
#
# **The Power of Magnetism**
#
# Have you ever wondered how magnets can attract certain metals and even stick to refrigerators? It all comes down to the fascinating world of magnetism.
#
# Magnets are objects that produce a magnetic field, which is a region around the magnet where magnetic forces can be detected. This field is created by the alignment of tiny particles called atoms, which are arranged in a specific way in the magnet's material. When these atoms are aligned, they generate a magnetic field that can interact with other magnetic fields or magnetic materials.
#
# The strength of a magnet's field depends on the type of material it's made of and its size. Some materials, like iron, are naturally magnetic, while others, like copper, are not. When a magnet is brought near a ferromagnetic material, like iron, the magnetic field induces magnetization in the material, causing it to become attracted to the magnet.
#
# The science behind magnetism has many practical applications, from holding together the wheels of your favorite bike to guiding ships through treacherous waters. Understanding how magnets work has also led to breakthroughs in medical imaging, data storage, and even space exploration. So next time you pick up a magnet, remember the tiny particles working together to create an incredible force that's all around us.
#
# --------------------------------------------------------------------------------
# RuntimeError, ExtractError: End or start strings not found
#
# **The Blueprint of Life: Unraveling the Purpose of DNA**
#
# Imagine a blueprint for the intricate machinery of life. That's exactly what DNA (deoxyribonucleic acid) is – the genetic blueprint that contains the instructions for the development and function of all living organisms. Composed of four chemical building blocks called nucleotides, DNA is a long, twisted molecule that stores the genetic information necessary for life.
#
# The purpose of DNA is multifaceted. It provides the instructions for the development and growth of an organism, from the formation of a fertilized egg to the maturation of a fully formed adult. DNA also plays a crucial role in the transmission of traits from one generation to the next, ensuring the continuation of species. Furthermore, DNA is the foundation for the incredible diversity of life on Earth, with its unique characteristics and adaptations.
#
# The discovery of DNA's structure and function by James Watson and Francis Crick in 1953 revolutionized our understanding of genetics and paved the way for numerous breakthroughs in fields such as medicine, agriculture, and biotechnology. Today, we continue to unravel the secrets of DNA, and its importance in our daily lives is undeniable.
#
# --------------------------------------------------------------------------------
# RuntimeError, ExtractError: End or start strings not found
#
# **The Galaxy Next Door: Exploring the Diverse Universe**
#
# Have you ever looked up at the night sky and wondered what lies beyond our own Milky Way galaxy? The universe is home to countless galaxies, each with its own unique characteristics. So, what are the different types of galaxies?
#
# There are four main types of galaxies: spiral, elliptical, irregular, and dwarf galaxies. Spiral galaxies, like our own Milky Way, are shaped like a pinwheel with a central bulge and spiral arms of stars, gas, and dust. Elliptical galaxies are egg-shaped and composed mainly of older stars. Irregular galaxies are chaotic and don't follow a regular shape, often the result of galaxy collisions. Dwarf galaxies are small and contain few stars.
#
# The diversity of galaxies is a testament to the complexity and beauty of the universe. By studying these different types of galaxies, scientists can gain insights into the formation and evolution of the cosmos. Who knows, the next great discovery about our galaxy or another galaxy might just come from a curious mind like yours!
#
# --------------------------------------------------------------------------------
# RuntimeError, ExtractError: End or start strings not found
#
# **Article: "The Winter Slumber: Why Some Animals Hibernate"**
#
# As the temperatures drop and the days grow shorter, some animals prepare for a long winter's nap. Hibernation, a state of deep sleep, is a unique adaptation that allows certain animals to conserve energy and survive the harsh winter months.
#
# Not all animals hibernate, but those that do, such as bears, bats, and chipmunks, have evolved this strategy to cope with food scarcity and extreme cold. During hibernation, their heart rate slows dramatically, from 40-50 beats per minute to just 8-10 beats per minute, and their body temperature drops to match the surrounding environment.
#
# This remarkable adaptation allows hibernating animals to survive for months without food or water. For example, black bears can hibernate for up to 5 months, while chipmunks can sleep for up to 7 months. By conserving energy, these animals can emerge in the spring, ready to start a new cycle of life.
#
# Hibernation is a remarkable example of the incredible diversity of life on our planet, and a testament to the incredible adaptability of animals. By studying these amazing creatures, we can gain a deeper appreciation for the natural world and the incredible strategies that animals use to survive and thrive.
#
# --------------------------------------------------------------------------------
# RuntimeError, ExtractError: End or start strings not found
#
# **Vaccines: The Heroes of Public Health**
#
# Imagine a world where diseases like measles, mumps, and whooping cough ravage communities, causing widespread suffering and even death. But thanks to vaccines, we've made tremendous progress in preventing these illnesses. So, how do vaccines work?
#
# Vaccines are like superheroes that train our immune systems to fight off specific diseases. Here's how: when a vaccine is administered, it contains a tiny, harmless piece of a pathogen (like a virus or bacteria) or a weakened form of the pathogen. This triggers our immune system to recognize the invader and mount a response.
#
# The immune system produces antibodies, which are like special forces that attack and neutralize the pathogen. This process is called immunization. As a result, our bodies develop a "memory" of the pathogen, allowing us to recognize and fight it off if we're exposed to it in the future.
#
# By harnessing the power of our immune system, vaccines have saved countless lives and protected public health. Today, vaccines are a cornerstone of modern medicine, and their impact is immeasurable. So, the next time you receive a vaccine, remember: you're not just getting a shot – you're getting a powerful tool to protect yourself and those around you.

# %%
results_temp_sup.keys()
# Out:
# dict_keys(['structure_support_by_model_sys', 'structure_support_by_model_user', 'structure_support_by_model_parsers'])

# %%
results_temp_sup["structure_support_by_model_user"]["fireworks_llama32"]
